# %% [markdown]
# <a href="https://colab.research.google.com/github/NhanPhamQuang/AI-Driven-Optimization-of-Bus-Scheduling-in-Ho-Chi-Minh-City/blob/main/T%E1%BB%95ng_h%E1%BB%A3p.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)

# %% [markdown]
# # Crawl bằng API

# %%
import requests
import json
import csv
from datetime import datetime

base_url = "https://api.xebuyt.net/businfo/getvarsbyroute/{}_1"

# Danh sách lưu kết quả chi tiết (mỗi chiều là 1 dòng)
detailed_results = []

print("BẮT ĐẦU LẤY THÔNG TIN CHI TIẾT CÁC TUYẾN...\n")

for route_id in range(1, 6):
    print("=" * 80)
    print(f"Đang request RouteId {route_id}")

    url = base_url.format(route_id)
    try:
        response = requests.get(url, timeout=8)
        print(f"HTTP {response.status_code}")

        if response.status_code == 200:
            text = response.text.strip()
            if text not in ["", "null", "[]", "{}"]:
                try:
                    data = response.json()
                    print(json.dumps(data, indent=2, ensure_ascii=False))

                    # === DUYỆT TỪNG CHIỀU (RouteVar) ===
                    for var in data:
                        detailed_results.append({
                            "RouteId": var.get("RouteId"),
                            "RouteNo": var.get("RouteNo"),
                            "RouteVarId": var.get("RouteVarId"),
                            "RouteVarName": var.get("RouteVarName"),
                            "RouteVarShortName": var.get("RouteVarShortName"),
                            "StartStop": var.get("StartStop"),
                            "EndStop": var.get("EndStop"),
                            "Distance": var.get("Distance"),
                            "RunningTime": var.get("RunningTime"),
                            "Outbound": var.get("Outbound")
                        })
                except json.JSONDecodeError:
                    print("(Không phải JSON hợp lệ)")
                    print(text)
            else:
                print("(Rỗng hoặc không có dữ liệu)")
        else:
            print(f"(Mã lỗi HTTP: {response.status_code})")

    except requests.exceptions.RequestException as e:
        print(f"Lỗi khi request RouteId {route_id}: {e}")

# === GHI KẾT QUẢ RA FILE CSV ===
csv_filename = "bus_routes_api.csv"

fieldnames = [
    "RouteId", "RouteNo", "RouteVarId", "RouteVarName", "RouteVarShortName",
    "StartStop", "EndStop", "Distance", "RunningTime", "Outbound"
]

with open(csv_filename, mode='w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(detailed_results)

# === TỔNG KẾT ===
total_routes = len(set(r["RouteId"] for r in detailed_results))
total_vars = len(detailed_results)

print("\n" + "=" * 80)
print("TỔNG KẾT")
print(f"Tổng số tuyến: {total_routes}")
print(f"Tổng số chiều (RouteVar): {total_vars}")
print(f"Chi tiết đã được lưu vào: {csv_filename}")
# Out:
# BẮT ĐẦU LẤY THÔNG TIN CHI TIẾT CÁC TUYẾN...
#
# ================================================================================
# Đang request RouteId 1
# HTTP 200
# [
#   {
#     "Distance": "7680",
#     "EndStop": "Bến xe Chợ Lớn",
#     "Outbound": "true",
#     "RouteId": "1",
#     "RouteNo": "1",
#     "RouteVarId": "1",
#     "RouteVarName": "Lượt đi: Bến Thành - BX Chợ Lớn",
#     "RouteVarShortName": "BX Chợ Lớn",
#     "RunningTime": "35",
#     "StartStop": "Công Trường Mê Linh"
#   },
#   {
#     "Distance": "9534",
#     "EndStop": "Công Trường Mê Linh",
#     "Outbound": "false",
#     "RouteId": "1",
#     "RouteNo": "1",
#     "RouteVarId": "2",
#     "RouteVarName": "Lượt về: BX Chợ Lớn - Bến Thành",
#     "RouteVarShortName": "Bến Thành",
#     "RunningTime": "30",
#     "StartStop": "Bến xe Chợ Lớn"
#   }
# ]
# ================================================================================
# Đang request RouteId 2
# HTTP 200
# [
#   {
#     "Distance": "13501",
#     "EndStop": "Bến xe Miền Tây",
#     "Outbound": "true",
#     "RouteId": "2",
#     "RouteNo": "2",
#     "RouteVarId": "3",
#     "RouteVarName": "Lượt đi: Bến Thành - BX Miền Tây",
#     "RouteVarShortName": "BX Miền Tây",
#     "RunningTime": "47",
#     "StartStop": "Công Trường Mê Linh"
#   },
#   {
#     "Distance": "13058",
#     "EndStop": "Công Trường Mê Linh",
#     "Outbound": "false",
#     "RouteId": "2",
#     "RouteNo": "2",
#     "RouteVarId": "4",
#     "RouteVarName": "Lượt về: BX Miền Tây - Bến Thành",
#     "RouteVarShortName": "Bến Thành",
#     "RunningTime": "47",
#     "StartStop": "Bến xe Miền Tây"
#   }
# ]
# ================================================================================
# Đang request RouteId 3
# HTTP 200
# [
#   {
#     "Distance": "17775",
#     "EndStop": "THẠNH LỘC",
#     "Outbound": "true",
#     "RouteId": "3",
#     "RouteNo": "3",
#     "RouteVarId": "5",
#     "RouteVarName": "Lượt đi: Bến Thành - Thạnh Lộc",
#     "RouteVarShortName": "Thạnh Lộc",
#     "RunningTime": "55",
#     "StartStop": "TĐH xe buýt Sài Gòn"
#   },
#   {
#     "Distance": "17693",
#     "EndStop": "TĐH xe buýt Sài Gòn",
#     "Outbound": "false",
#     "RouteId": "3",
#     "RouteNo": "3",
#     "RouteVarId": "6",
#     "RouteVarName": "Lượt về: Thạnh Lộc - Bến Thành",
#     "RouteVarShortName": "Bến Thành",
#     "RunningTime": "55",
#     "StartStop": "THẠNH LỘC"
#   }
# ]
# ================================================================================
# Đang request RouteId 4
# HTTP 200
# [
#   {
#     "Distance": "17063",
#     "EndStop": "Bến xe An Sương",
#     "Outbound": "true",
#     "RouteId": "4",
#     "RouteNo": "4",
#     "RouteVarId": "7",
#     "RouteVarName": "Lượt đi: Công viên 23/9 - An Sương",
#     "RouteVarShortName": "An Sương",
#     "RunningTime": "55",
#     "StartStop": "TĐH xe buýt Sài Gòn"
#   },
#   {
#     "Distance": "15243",
#     "EndStop": "TĐH xe buýt Sài Gòn",
#     "Outbound": "false",
#     "RouteId": "4",
#     "RouteNo": "4",
#     "RouteVarId": "8",
#     "RouteVarName": "Lượt về: An Sương - Công viên 23/9",
#     "RouteVarShortName": "Bến Thành",
#     "RunningTime": "50",
#     "StartStop": "Bến xe An Sương"
#   }
# ]
# ================================================================================
# Đang request RouteId 5
# HTTP 200
# [
#   {
#     "Distance": "25755",
#     "EndStop": "Big C",
#     "Outbound": "true",
#     "RouteId": "5",
#     "RouteNo": "5",
#     "RouteVarId": "9",
#     "RouteVarName": "Bến xe Chợ Lớn - Biên Hòa",
#     "RouteVarShortName": "Biên Hòa",
#     "RunningTime": "99",
#     "StartStop": "Bến xe Chợ Lớn"
#   },
#   {
#     "Distance": "25073",
#     "EndStop": "Bến xe Chợ Lớn",
#     "Outbound": "false",
#     "RouteId": "5",
#     "RouteNo": "5",
#     "RouteVarId": "10",
#     "RouteVarName": "Biên Hòa - Bến xe Chợ Lớn",
#     "RouteVarShortName": "Bến xe Chợ Lớn",
#     "RunningTime": "99",
#     "StartStop": "Big C"
#   }
# ]
#
# ================================================================================
# TỔNG KẾT
# Tổng số tuyến: 5
# Tổng số chiều (RouteVar): 10
# Chi tiết đã được lưu vào: bus_routes_api.csv

# %%
import requests
import json
import csv
import time
from datetime import datetime

# === CẤU HÌNH ===
CSV_INPUT = "bus_routes_api.csv"
OUTPUT_FILE = f"bus_stop_api_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"

# API
GET_STOPS_URL = "https://api.xebuyt.net/businfo/getstopsbyvar/{}_1/{}"

# Danh sách lưu toàn bộ trạm
all_stops = []

print("BẮT ĐẦU LẤY TRẠM DỪNG TỪ CSV...\n")

# === 1. ĐỌC CSV → LẤY CẶP (RouteId, RouteVarId) ===
route_vars = []
try:
    with open(CSV_INPUT, mode='r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        print(f"Các cột: {reader.fieldnames}")

        for row in reader:
            route_id = row.get("RouteId")
            route_var_id = row.get("RouteVarId")
            route_var_name = row.get("RouteVarName", "")

            if route_id and route_var_id:
                try:
                    route_vars.append({
                        "RouteId": int(route_id),
                        "RouteVarId": int(route_var_id),
                        "RouteVarName": route_var_name
                    })
                except ValueError:
                    continue
except FileNotFoundError:
    print(f"Không tìm thấy file: {CSV_INPUT}")
    exit()

# Loại trùng
unique_vars = { (rv["RouteId"], rv["RouteVarId"]): rv for rv in route_vars }
route_vars = list(unique_vars.values())

print(f"Tìm thấy {len(route_vars)} chiều tuyến để lấy trạm dừng.\n")

# === 2. DUYỆT TỪNG CHIỀU → LẤY TRẠM DỪNG ===
for idx, rv in enumerate(route_vars, 1):
    route_id = rv["RouteId"]
    route_var_id = rv["RouteVarId"]
    route_var_name = rv["RouteVarName"]

    print(f"[{idx}/{len(route_vars)}] [{route_id} | Var {route_var_id}] {route_var_name}")

    url = GET_STOPS_URL.format(route_id, route_var_id)
    print(f"   → Gọi: {url}")

    try:
        response = requests.get(url, timeout=12)
        if response.status_code == 200:
            try:
                stops_data = response.json()
                if isinstance(stops_data, list):
                    # Gắn thêm thông tin tuyến
                    for stop in stops_data:
                        stop["RouteId"] = route_id
                        stop["RouteVarId"] = route_var_id
                        stop["RouteVarName"] = route_var_name
                    all_stops.extend(stops_data)
                    print(f"   Thành công! {len(stops_data)} trạm")
                else:
                    print("   Dữ liệu không phải danh sách")
            except json.JSONDecodeError as e:
                print(f"   JSON lỗi: {e}")
                print(response.text[:200])
        else:
            print(f"   HTTP {response.status_code}")

    except Exception as e:
        print(f"   Lỗi: {e}")

    time.sleep(0.5)  # An toàn với server

# === 3. GHI RA FILE JSON ===
with open(OUTPUT_FILE, 'w', encoding='utf-8') as f:
    json.dump(all_stops, f, indent=2, ensure_ascii=False)

print("\n" + "="*80)
print("HOÀN TẤT!")
print(f"Tổng cộng: {len(all_stops)} trạm dừng")
print(f"Đã lưu vào: {OUTPUT_FILE}")
# Out:
# BẮT ĐẦU LẤY TRẠM DỪNG TỪ CSV...
#
# Các cột: ['RouteId', 'RouteNo', 'RouteVarId', 'RouteVarName', 'RouteVarShortName', 'StartStop', 'EndStop', 'Distance', 'RunningTime', 'Outbound']
# Tìm thấy 10 chiều tuyến để lấy trạm dừng.
#
# [1/10] [1 | Var 1] Lượt đi: Bến Thành - BX Chợ Lớn
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/1_1/1
#    Thành công! 29 trạm
# [2/10] [1 | Var 2] Lượt về: BX Chợ Lớn - Bến Thành
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/1_1/2
#    Thành công! 35 trạm
# [3/10] [2 | Var 3] Lượt đi: Bến Thành - BX Miền Tây
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/2_1/3
#    Thành công! 43 trạm
# [4/10] [2 | Var 4] Lượt về: BX Miền Tây - Bến Thành
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/2_1/4
#    Thành công! 37 trạm
# [5/10] [3 | Var 5] Lượt đi: Bến Thành - Thạnh Lộc
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/3_1/5
#    Thành công! 48 trạm
# [6/10] [3 | Var 6] Lượt về: Thạnh Lộc - Bến Thành
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/3_1/6
#    Thành công! 48 trạm
# [7/10] [4 | Var 7] Lượt đi: Công viên 23/9 - An Sương
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/4_1/7
#    Thành công! 50 trạm
# [8/10] [4 | Var 8] Lượt về: An Sương - Công viên 23/9
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/4_1/8
#    Thành công! 41 trạm
# [9/10] [5 | Var 9] Bến xe Chợ Lớn - Biên Hòa
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/5_1/9
#    Thành công! 59 trạm
# [10/10] [5 | Var 10] Biên Hòa - Bến xe Chợ Lớn
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/5_1/10
#    Thành công! 68 trạm
#
# ================================================================================
# HOÀN TẤT!
# Tổng cộng: 458 trạm dừng
# Đã lưu vào: bus_stop_api_20251028_193532.json

# %%
import requests
import json
import csv
import time
from datetime import datetime

# === CẤU HÌNH ===
CSV_INPUT = "bus_routes_api.csv"
CSV_OUTPUT = f"bus_stops_detailed_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"

# API
GET_STOPS_URL = "https://api.xebuyt.net/businfo/getstopsbyvar/{}_1/{}"

# Danh sách lưu toàn bộ trạm
all_stops = []

print("BẮT ĐẦU LẤY TRẠM DỪNG TỪ CSV VÀ XUẤT RA CSV...\n")

# === 1. ĐỌC CSV → LẤY CẶP (RouteId, RouteVarId) ===
route_vars = []
try:
    with open(CSV_INPUT, mode='r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        print(f"Các cột trong file đầu vào: {reader.fieldnames}")

        for row in reader:
            route_id = row.get("RouteId")
            route_var_id = row.get("RouteVarId")
            route_var_name = row.get("RouteVarName", "")
            route_no = row.get("RouteNo", "")

            if route_id and route_var_id:
                try:
                    route_vars.append({
                        "RouteId": int(route_id),
                        "RouteVarId": int(route_var_id),
                        "RouteVarName": route_var_name,
                        "RouteNo": route_no
                    })
                except ValueError:
                    continue
except FileNotFoundError:
    print(f"Không tìm thấy file: {CSV_INPUT}")
    exit()

# Loại trùng (RouteId + RouteVarId)
unique_vars = { (rv["RouteId"], rv["RouteVarId"]): rv for rv in route_vars }
route_vars = list(unique_vars.values())

print(f"Tìm thấy {len(route_vars)} chiều tuyến để lấy trạm dừng.\n")

# === 2. DUYỆT TỪNG CHIỀU → LẤY TRẠM DỪNG ===
for idx, rv in enumerate(route_vars, 1):
    route_id = rv["RouteId"]
    route_var_id = rv["RouteVarId"]
    route_var_name = rv["RouteVarName"]
    route_no = rv["RouteNo"]

    print(f"[{idx}/{len(route_vars)}] Tuyến {route_no} | {route_var_name}")

    url = GET_STOPS_URL.format(route_id, route_var_id)
    print(f"   → Gọi: {url}")

    try:
        response = requests.get(url, timeout=12)
        if response.status_code == 200:
            try:
                stops_data = response.json()
                if isinstance(stops_data, list):
                    # Gắn thêm thông tin tuyến
                    for stop in stops_data:
                        stop["RouteId"] = route_id
                        stop["RouteVarId"] = route_var_id
                        stop["RouteVarName"] = route_var_name
                        stop["RouteNo"] = route_no
                    all_stops.extend(stops_data)
                    print(f"   Thành công! {len(stops_data)} trạm")
                else:
                    print("   Dữ liệu không phải danh sách")
            except json.JSONDecodeError as e:
                print(f"   JSON lỗi: {e}")
        else:
            print(f"   HTTP {response.status_code}")

    except Exception as e:
        print(f"   Lỗi: {e}")

    time.sleep(0.5)

# === 3. GHI RA FILE CSV ===
fieldnames = [
    "RouteNo", "RouteId", "RouteVarId", "RouteVarName",
    "StopID", "Name", "AddressNo", "Lat", "Lng",
    "Code", "Street", "StopType", "Status", "Routes", "Search"
]

with open(CSV_OUTPUT, 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for stop in all_stops:
        row = {key: stop.get(key, "") for key in fieldnames}
        writer.writerow(row)

print("\n" + "="*80)
print("HOÀN TẤT!")
print(f"Tổng cộng: {len(all_stops)} trạm dừng")
print(f"Đã lưu file CSV: {CSV_OUTPUT}")
print("   → Mở bằng Excel, Google Sheets được ngay!")
# Out:
# BẮT ĐẦU LẤY TRẠM DỪNG TỪ CSV VÀ XUẤT RA CSV...
#
# Các cột trong file đầu vào: ['RouteId', 'RouteNo', 'RouteVarId', 'RouteVarName', 'RouteVarShortName', 'StartStop', 'EndStop', 'Distance', 'RunningTime', 'Outbound']
# Tìm thấy 10 chiều tuyến để lấy trạm dừng.
#
# [1/10] Tuyến 1 | Lượt đi: Bến Thành - BX Chợ Lớn
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/1_1/1
#    Thành công! 29 trạm
# [2/10] Tuyến 1 | Lượt về: BX Chợ Lớn - Bến Thành
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/1_1/2
#    Thành công! 35 trạm
# [3/10] Tuyến 2 | Lượt đi: Bến Thành - BX Miền Tây
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/2_1/3
#    Thành công! 43 trạm
# [4/10] Tuyến 2 | Lượt về: BX Miền Tây - Bến Thành
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/2_1/4
#    Thành công! 37 trạm
# [5/10] Tuyến 3 | Lượt đi: Bến Thành - Thạnh Lộc
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/3_1/5
#    Thành công! 48 trạm
# [6/10] Tuyến 3 | Lượt về: Thạnh Lộc - Bến Thành
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/3_1/6
#    Thành công! 48 trạm
# [7/10] Tuyến 4 | Lượt đi: Công viên 23/9 - An Sương
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/4_1/7
#    Thành công! 50 trạm
# [8/10] Tuyến 4 | Lượt về: An Sương - Công viên 23/9
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/4_1/8
#    Thành công! 41 trạm
# [9/10] Tuyến 5 | Bến xe Chợ Lớn - Biên Hòa
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/5_1/9
#    Thành công! 59 trạm
# [10/10] Tuyến 5 | Biên Hòa - Bến xe Chợ Lớn
#    → Gọi: https://api.xebuyt.net/businfo/getstopsbyvar/5_1/10
#    Thành công! 68 trạm
#
# ================================================================================
# HOÀN TẤT!
# Tổng cộng: 458 trạm dừng
# Đã lưu file CSV: bus_stops_detailed_20251028_194200.csv
#    → Mở bằng Excel, Google Sheets được ngay!

# %% [markdown]
# # Crawl bằng HTML

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# URL của trang web
url = 'https://xebuyt.net/tuyen-xe-buyt'

# Gửi request để lấy nội dung trang
response = requests.get(url)
response.raise_for_status()  # Kiểm tra lỗi nếu có

# Parse HTML với BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Tìm div chứa danh sách tuyến
div_result = soup.find('div', id='divResult')

# Tìm tất cả các thẻ <a> với class 'cms-button'
route_links = div_result.find_all('a', class_='cms-button')

# Danh sách để lưu dữ liệu (chỉ lấy tối đa 5 tuyến đầu tiên)
data = []

# Duyệt qua tối đa 5 link đầu tiên
for link in route_links[:5]:  # <-- Chỉ lấy 5 phần tử đầu
    # Lấy href
    href = link.get('href')
    full_url = 'https://xebuyt.net' + href if href.startswith('/') else href

    # Lấy số tuyến từ span.icon
    route_number = link.find('span', class_='icon').get_text(strip=True)

    # Lấy tên tuyến từ div.routetrip
    route_name = link.find('div', class_='routetrip').get_text(strip=True)

    # Thêm vào danh sách
    data.append({
        'Route_Number': route_number,
        'Route_Name': route_name,
        'URL': full_url
    })

# Lưu vào file CSV
filename = 'tuyen_xe_buyt.csv'
with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Route_Number', 'Route_Name', 'URL']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerows(data)

print(f'Đã lưu 5 tuyến xe buýt đầu tiên vào file {filename}. Tổng số tuyến: {len(data)}')

# Hiển thị dưới dạng DataFrame (tùy chọn)
df = pd.DataFrame(data)
df
# Out:
# Đã lưu 5 tuyến xe buýt đầu tiên vào file tuyen_xe_buyt.csv. Tổng số tuyến: 5
#   Route_Number                     Route_Name  \
# 0           01          Bến Thành- BX Chợ Lớn
# 1           02         Bến Thành- BX Miền Tây
# 2           03           Bến Thành- Thạnh Lộc
# 3           04  Bến Thành- Cộng Hòa- An Sương
# 4           05      Bến xe Chợ Lớn - Biên Hòa
#
#                                                  URL
# 0   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 1  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html
# 2        https://xebuyt.net/ben-thanh-thanh-loc.html
# 3  https://xebuyt.net/ben-thanh-cong-hoa-an-suong...
# 4    https://xebuyt.net/ben-xe-cho-lon-bien-hoa.html

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re

# Đọc file CSV đã tạo trước đó
csv_filename = 'tuyen_xe_buyt.csv'
df = pd.read_csv(csv_filename)

# Danh sách để lưu dữ liệu mở rộng
extended_data = []

# Headers cho CSV mới
headers = [
    'Route_Number', 'Route_Name', 'URL',
    'Operator', 'Operating_Type', 'Distance', 'Vehicle_Type', 'Operating_Hours',
    'Ticket_Price', 'Number_of_Trips', 'Trip_Time', 'Frequency'
]

# Duyệt qua từng hàng trong DataFrame
for index, row in df.iterrows():
    route_number = row['Route_Number']
    route_name = row['Route_Name']
    url = row['URL']

    print(f"Đang scrape tuyến {route_number}: {route_name}")

    try:
        # Gửi request
        response = requests.get(url)
        response.raise_for_status()

        # Parse HTML
        soup = BeautifulSoup(response.content, 'html.parser')

        # Tìm div rouInfo và table
        rou_info_div = soup.find('div', id='rouInfo')
        if not rou_info_div:
            print(f"Không tìm thấy div#rouInfo cho tuyến {route_number}")
            continue

        table = rou_info_div.find('table', class_='tbl100')
        if not table:
            print(f"Không tìm thấy table cho tuyến {route_number}")
            continue

        # Khởi tạo giá trị mặc định
        operator = ''
        operating_type = ''
        distance = ''
        vehicle_type = ''
        operating_hours = ''
        ticket_price = ''
        number_of_trips = ''
        trip_time = ''
        frequency = ''

        # Duyệt qua các hàng trong table
        rows = table.find('tbody').find_all('tr')
        for tr in rows:
            tds = tr.find_all('td')
            if len(tds) < 2:
                continue

            label_td = tds[0].get_text(strip=True)
            content = tds[1].get_text(separator='\n').strip()

            # Xử lý Đơn vị đảm nhận (có thể ở hàng riêng)
            if 'Đơn vị đảm nhận' in label_td:
                operator = content

            # Bỏ qua hàng spacing
            if not label_td and not content:
                continue

            # Xử lý ul lists ở hàng cuối (cột 2 và 3)
            if len(tds) >= 3 and not label_td:  # Hàng có ul lists
                left_ul = tds[1].find('ul')
                right_ul = tds[2].find('ul') if len(tds) > 2 else None

                if left_ul:
                    left_items = [li.get_text(strip=True) for li in left_ul.find_all('li')]
                    for item in left_items:
                        if 'Loại hình hoạt động' in item:
                            operating_type = item.replace('Loại hình hoạt động:', '').strip()
                        elif 'Cự ly' in item:
                            distance = item.replace('Cự ly:', '').strip()
                        elif 'Loại xe' in item:
                            vehicle_type = item.replace('Loại xe:', '').strip()
                        elif 'Thời gian hoạt động' in item:
                            operating_hours = item.replace('Thời gian hoạt động:', '').strip()

                if right_ul:
                    right_items = [li.get_text(separator='\n').strip() for li in right_ul.find_all('li')]
                    for item in right_items:
                        if 'Giá vé' in item:
                            ticket_price = item.replace('Giá vé:', '').strip()
                        elif 'Số chuyến' in item:
                            number_of_trips = item.replace('Số chuyến:', '').strip()
                        elif 'Thời gian chuyến' in item:
                            trip_time = item.replace('Thời gian chuyến:', '').strip()
                        elif 'Giãn cách chuyến' in item:
                            frequency = item.replace('Giãn cách chuyến:', '').strip()

        # Thêm vào danh sách
        extended_data.append({
            'Route_Number': route_number,
            'Route_Name': route_name,
            'URL': url,
            'Operator': operator,
            'Operating_Type': operating_type,
            'Distance': distance,
            'Vehicle_Type': vehicle_type,
            'Operating_Hours': operating_hours,
            'Ticket_Price': ticket_price,
            'Number_of_Trips': number_of_trips,
            'Trip_Time': trip_time,
            'Frequency': frequency
        })

    except Exception as e:
        print(f"Lỗi khi scrape tuyến {route_number}: {e}")
        # Vẫn thêm dữ liệu với giá trị rỗng
        extended_data.append({
            'Route_Number': route_number,
            'Route_Name': route_name,
            'URL': url,
            'Operator': '',
            'Operating_Type': '',
            'Distance': '',
            'Vehicle_Type': '',
            'Operating_Hours': '',
            'Ticket_Price': '',
            'Number_of_Trips': '',
            'Trip_Time': '',
            'Frequency': ''
        })

    # Delay để tránh overload server
    time.sleep(1)

# Tạo DataFrame và lưu vào CSV mới
extended_df = pd.DataFrame(extended_data)
output_filename = 'tuyen_xe_buyt_detailed.csv'
extended_df.to_csv(output_filename, index=False, encoding='utf-8')

print(f'Dữ liệu chi tiết đã được lưu vào file {output_filename}. Tổng số tuyến: {len(extended_data)}')

# Hiển thị DataFrame (comment nếu không cần)
extended_df.head()
# Out:
# Đang scrape tuyến 1: Bến Thành- BX Chợ Lớn
# Đang scrape tuyến 2: Bến Thành- BX Miền Tây
# Đang scrape tuyến 3: Bến Thành- Thạnh Lộc
# Đang scrape tuyến 4: Bến Thành- Cộng Hòa- An Sương
# Đang scrape tuyến 5: Bến xe Chợ Lớn - Biên Hòa
# Dữ liệu chi tiết đã được lưu vào file tuyen_xe_buyt_detailed.csv. Tổng số tuyến: 5
#    Route_Number                     Route_Name  \
# 0             1          Bến Thành- BX Chợ Lớn
# 1             2         Bến Thành- BX Miền Tây
# 2             3           Bến Thành- Thạnh Lộc
# 3             4  Bến Thành- Cộng Hòa- An Sương
# 4             5      Bến xe Chợ Lớn - Biên Hòa
#
#                                                  URL  \
# 0   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 1  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html
# 2        https://xebuyt.net/ben-thanh-thanh-loc.html
# 3  https://xebuyt.net/ben-thanh-cong-hoa-an-suong...
# 4    https://xebuyt.net/ben-xe-cho-lon-bien-hoa.html
#
#                                             Operator  \
# 0  Công ty Cổ phần Xe khách Sài Gòn, ĐT: (08) 38....
# 1  Công ty TNHH Vận tải Ngôi sao Sài Gòn, ĐT: (08...
# 2  Công ty TNHH Vận tải Ngôi sao Sài Gòn, ĐT: (08...
# 3  Công ty TNHH Vận tải Ngôi sao Sài Gòn, ĐT: (08...
# 4  Hợp tác xã vận tải xe buýt Quyết Thắng, ĐT: (0...
#
#               Operating_Type  Distance  Vehicle_Type Operating_Hours  \
# 0     Phổ thông - Có trợ giá    8.6 km       80 chỗ   05:00 - 20:30
# 1     Phổ thông - Có trợ giá  13.65 km  30 - 80 chỗ   04:45 - 18:30
# 2     Phổ thông - Có trợ giá  18.05 km  26 - 55 chỗ   04:15 - 20:45
# 3     Phổ thông - Có trợ giá   16.6 km  30 - 55 chỗ   05:00 - 20:30
# 4  Phổ thông - Không trợ giá     38 km  30 - 80 chỗ   04:50 - 17:50
#
#                                         Ticket_Price    Number_of_Trips  \
# 0  &nbsp- Vé lượt: 5,000 VNĐ\n     &nbsp- Vé lượt...  240 chuyến/ngày
# 1  &nbsp- Vé lượt: 5,000 VNĐ\n     &nbsp- Vé lượt...  180 chuyến/ngày
# 2  &nbsp- Vé lượt: 6,000 VNĐ\n     &nbsp- Vé lượt...  312 chuyến/ngày
# 3  &nbsp- Vé lượt: 5,000 VNĐ\n     &nbsp- Vé lượt...  303 chuyến/ngày
# 4                                                      72 chuyến/ngày
#
#        Trip_Time      Frequency
# 0  30 - 35 phút   6 - 10 phút
# 1  45 - 50 phút   8 - 12 phút
# 2  55 - 65 phút   4 - 12 phút
# 3  50 - 65 phút   5 - 10 phút
# 4  60 - 95 phút  20 - 25 phút

# %%
extended_df.columns
# Out:
# Index(['Route_Number', 'Route_Name', 'URL', 'Operator', 'Operating_Type',
#        'Distance', 'Vehicle_Type', 'Operating_Hours', 'Ticket_Price',
#        'Number_of_Trips', 'Trip_Time', 'Frequency'],
#       dtype='object')

# %%
import requests
from bs4 import BeautifulSoup
import html
import pandas as pd
import time
from pprint import pprint  # Để debug nếu cần

# Đọc file CSV đã tạo trước đó
csv_filename = 'tuyen_xe_buyt.csv'
try:
    df = pd.read_csv(csv_filename)
    print(f"Đã đọc thành công {len(df)} tuyến từ file {csv_filename}")
except FileNotFoundError:
    print(f"Không tìm thấy file {csv_filename}. Vui lòng chạy code scrape URL trước!")
    exit()

# Danh sách để lưu dữ liệu lộ trình (mỗi stop là một row)
route_stops_data = []

# Giới hạn số tuyến để test (bỏ comment nếu muốn scrape tất cả)
# df = df.head(5)  # Chỉ scrape 5 tuyến đầu để test

print(f"Bắt đầu scrape lộ trình cho {len(df)} tuyến...")

# Duyệt qua từng hàng trong DataFrame
for index, row in df.iterrows():
    route_number = row['Route_Number']
    route_name = row['Route_Name']
    url = row['URL']

    print(f"\n--- Đang scrape lộ trình tuyến {route_number}: {route_name} ---")
    print(f"URL: {url}")

    try:
        # Gửi yêu cầu HTTP để lấy nội dung trang web
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Kiểm tra lỗi HTTP

        # Giải mã HTML để xử lý các ký tự đặc biệt
        html_content = html.unescape(response.text)

        # Sử dụng BeautifulSoup để phân tích HTML
        soup = BeautifulSoup(html_content, 'html.parser')
        print(f"✅ Đã parse HTML thành công. Độ dài content: {len(response.text)}")

        # Khởi tạo danh sách stops cho tuyến này
        stops_data = []

        # Biến để xác định hướng hiện tại
        current_direction = None

        # Duyệt qua các element h3 và table theo thứ tự
        for element in soup.find_all(['h3', 'table']):
            if element.name == 'h3':
                # Cập nhật hướng dựa trên tiêu đề (tìm các pattern phổ biến như "Đi [Điểm cuối]")
                header_text = element.get_text(strip=True)
                if "Đi" in header_text:
                    # Lấy phần sau "Đi " làm tên hướng
                    direction_name = header_text.replace("Đi ", "").strip()
                    current_direction = direction_name
                    print(f"  ✅ Phát hiện hướng mới: {current_direction}")
                else:
                    current_direction = None
            elif element.name == 'table' and current_direction:
                # Tìm tất cả các hàng trong bảng
                rows = element.find_all('tr')
                stop_count = 0
                for row in rows:
                    cols = row.find_all('td')
                    if len(cols) >= 2:
                        # Lấy thứ tự stop (từ cột 1, thường là <div> với A/1/2/.../B)
                        order_col = cols[0].find('div')
                        stop_order = order_col.get_text(strip=True) if order_col else str(stop_count + 1)

                        # Lấy tên stop từ cột 2
                        stop_name = cols[1].get_text(strip=True)

                        if stop_name and stop_name != '':  # Bỏ qua stop rỗng
                            # Thêm vào danh sách
                            stops_data.append({
                                'Route_Number': route_number,
                                'Route_Name': route_name,
                                'URL': url,
                                'Direction': current_direction,
                                'Stop_Order': stop_order,
                                'Stop_Name': stop_name
                            })
                            stop_count += 1
                            if stop_count <= 3:  # Chỉ print 3 stops đầu mỗi hướng để tránh spam
                                print(f"    Stop {stop_order}: {stop_name}")
                            if stop_count == 4:
                                print(f"    ... (và {len(rows) - stop_count + 1} stops khác)")

                print(f"  ✅ Thu thập {stop_count} stops cho hướng '{current_direction}'")

        # Thêm stops của tuyến này vào danh sách tổng
        route_stops_data.extend(stops_data)
        total_stops_this_route = len(stops_data)
        print(f"✅ Hoàn thành tuyến {route_number}: {total_stops_this_route} stops tổng cộng")

        # Debug: In preview stops nếu cần (comment nếu không muốn)
        # pprint(stops_data, indent=2)

    except requests.exceptions.RequestException as e:
        print(f"❌ Lỗi HTTP cho tuyến {route_number}: {e}")
    except Exception as e:
        print(f"❌ Lỗi khi xử lý dữ liệu tuyến {route_number}: {e}")
        import traceback
        traceback.print_exc()  # In chi tiết lỗi để debug

    # Delay để tránh overload server
    # time.sleep(2)

print(f"\n--- Kết thúc scrape ---")
print(f"Tổng số stops thu thập được: {len(route_stops_data)}")

if len(route_stops_data) == 0:
    print("❌ Không có dữ liệu nào! Kiểm tra log trên để debug.")
    print("Có thể một số tuyến không có lộ trình, hoặc HTML thay đổi.")

# Tạo DataFrame và lưu vào CSV mới
if len(route_stops_data) > 0:
    route_stops_df = pd.DataFrame(route_stops_data)
    output_filename = 'tuyen_xe_buyt_lotrinh.csv'
    route_stops_df.to_csv(output_filename, index=False, encoding='utf-8')

    print(f"✅ Dữ liệu lộ trình đã được lưu vào file {output_filename}")

    # Hiển thị preview DataFrame (top 20 rows)
    print("\n--- Preview DataFrame (top 20 rows) ---")
    print(route_stops_df.head(20).to_string(index=False))

    # Thống kê nhanh
    print(f"\n--- Thống kê ---")
    print(f"- Tổng tuyến có dữ liệu: {route_stops_df['Route_Number'].nunique()}")
    print(f"- Hướng phổ biến nhất: {route_stops_df['Direction'].value_counts().head(1)}")
else:
    print("❌ Không lưu file vì không có dữ liệu.")
# Out:
# Đã đọc thành công 5 tuyến từ file tuyen_xe_buyt.csv
# Bắt đầu scrape lộ trình cho 5 tuyến...
#
# --- Đang scrape lộ trình tuyến 1: Bến Thành- BX Chợ Lớn ---
# URL: https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# ✅ Đã parse HTML thành công. Độ dài content: 52658
#   ✅ Phát hiện hướng mới: BX Chợ Lớn
#     Stop A: Công Trường Mê Linh
#     Stop 1: Bến Bạch Đằng
#     Stop 2: Cục Hải Quan Thành Phố
#     ... (và 26 stops khác)
#   ✅ Thu thập 29 stops cho hướng 'BX Chợ Lớn'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Bến xe Chợ Lớn
#     Stop 1: Chu Văn An
#     Stop 2: Tháp Mười
#     ... (và 32 stops khác)
#   ✅ Thu thập 35 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 05:35
#     Stop 2: 05:10 - 05:45
#     Stop 3: 05:20 - 05:55
#     ... (và 117 stops khác)
#   ✅ Thu thập 120 stops cho hướng 'BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 05:30
#     Stop 2: 05:10 - 05:40
#     Stop 3: 05:20 - 05:50
#     ... (và 117 stops khác)
#   ✅ Thu thập 120 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 1: 304 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 2: Bến Thành- BX Miền Tây ---
# URL: https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html
# ✅ Đã parse HTML thành công. Độ dài content: 52394
#   ✅ Phát hiện hướng mới: BX Miền Tây
#     Stop A: Công Trường Mê Linh
#     Stop 1: Bến Bạch Đằng
#     Stop 2: Cục Hải Quan Thành Phố
#     ... (và 40 stops khác)
#   ✅ Thu thập 43 stops cho hướng 'BX Miền Tây'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Bến xe Miền Tây
#     Stop 1: 49-51 (317), Kinh Dương Vương
#     Stop 2: Dương Tự Quản
#     ... (và 34 stops khác)
#   ✅ Thu thập 37 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: BX Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'BX Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:45 - 05:30
#     Stop 2: 04:57 - 05:42
#     Stop 3: 05:09 - 05:54
#     ... (và 87 stops khác)
#   ✅ Thu thập 90 stops cho hướng 'BX Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:45 - 05:30
#     Stop 2: 04:57 - 05:42
#     Stop 3: 05:09 - 05:54
#     ... (và 87 stops khác)
#   ✅ Thu thập 90 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 2: 260 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 3: Bến Thành- Thạnh Lộc ---
# URL: https://xebuyt.net/ben-thanh-thanh-loc.html
# ✅ Đã parse HTML thành công. Độ dài content: 67605
#   ✅ Phát hiện hướng mới: Thạnh Lộc
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Tôn Thất Tùng
#     Stop 2: Nguyễn Thị Nghĩa
#     ... (và 45 stops khác)
#   ✅ Thu thập 48 stops cho hướng 'Thạnh Lộc'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: THẠNH LỘC
#     Stop 1: Trường Điện Lực 2
#     Stop 2: Chợ Thạnh Xuân
#     ... (và 45 stops khác)
#   ✅ Thu thập 48 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: Thạnh Lộc(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Thạnh Lộc(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:55 - 05:50
#     Stop 2: 05:03 - 05:58
#     Stop 3: 05:11 - 06:06
#     ... (và 153 stops khác)
#   ✅ Thu thập 156 stops cho hướng 'Thạnh Lộc(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:15 - 05:10
#     Stop 2: 04:27 - 05:22
#     Stop 3: 04:37 - 05:32
#     ... (và 153 stops khác)
#   ✅ Thu thập 156 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 3: 408 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 4: Bến Thành- Cộng Hòa- An Sương ---
# URL: https://xebuyt.net/ben-thanh-cong-hoa-an-suong.html
# ✅ Đã parse HTML thành công. Độ dài content: 65800
#   ✅ Phát hiện hướng mới: An Sương
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Tôn Thất Tùng
#     Stop 2: Nguyễn Thị Nghĩa
#     ... (và 47 stops khác)
#   ✅ Thu thập 50 stops cho hướng 'An Sương'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Bến xe An Sương
#     Stop 1: Chợ Chiều
#     Stop 2: Bitis
#     ... (và 38 stops khác)
#   ✅ Thu thập 41 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:30 - 06:25
#     Stop 2: 05:38 - 06:33
#     Stop 3: 05:44 - 06:39
#     ... (và 147 stops khác)
#   ✅ Thu thập 150 stops cho hướng 'An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 05:50
#     Stop 2: 05:08 - 05:58
#     Stop 3: 05:16 - 06:06
#     ... (và 150 stops khác)
#   ✅ Thu thập 153 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 4: 394 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 5: Bến xe Chợ Lớn - Biên Hòa ---
# URL: https://xebuyt.net/ben-xe-cho-lon-bien-hoa.html
# ✅ Đã parse HTML thành công. Độ dài content: 56251
#   ✅ Phát hiện hướng mới: Biên Hòa
#     Stop A: Bến xe Chợ Lớn
#     Stop 1: Chu Văn An
#     Stop 2: Chợ Kim Biên
#     ... (và 56 stops khác)
#   ✅ Thu thập 59 stops cho hướng 'Biên Hòa'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn
#     Stop A: Big C
#     Stop 1: Chùa Từ Quang
#     Stop 2: Đường số 8
#     ... (và 65 stops khác)
#   ✅ Thu thập 68 stops cho hướng 'Bến xe Chợ Lớn'
#   ✅ Phát hiện hướng mới: Biên Hòa(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Biên Hòa(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:50 - 06:25
#     Stop 2: 05:10 - 06:45
#     Stop 3: 05:30 - 07:05
#     ... (và 33 stops khác)
#   ✅ Thu thập 36 stops cho hướng 'Biên Hòa(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:50 - 06:25
#     Stop 2: 05:10 - 06:45
#     Stop 3: 05:30 - 07:05
#     ... (và 33 stops khác)
#   ✅ Thu thập 36 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 5: 199 stops tổng cộng
#
# --- Kết thúc scrape ---
# Tổng số stops thu thập được: 1565
# ✅ Dữ liệu lộ trình đã được lưu vào file tuyen_xe_buyt_lotrinh.csv
#
# --- Preview DataFrame (top 20 rows) ---
#  Route_Number            Route_Name                                              URL  Direction Stop_Order                         Stop_Name
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          A               Công Trường Mê Linh
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          1                     Bến Bạch Đằng
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          2            Cục Hải Quan Thành Phố
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          3                            Chợ Cũ
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          4                  Trường Cao Thắng
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          5                 Công ty Đường sắt
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          6                     Bến Thành B
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          7             Trường Ernst Thalmann
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          8                 KTX Trần Hưng Đạo
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          9                      Rạp Hưng Đạo
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         10            Bệnh viện Răng Hàm Mặt
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         11                      Trần Đình Xu
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         12                    Tổng Cty Samco
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         13                         Chợ Nanci
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         14                       Nguyễn Biểu
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         15 Trường Cao đẳng Kinh tế Đối ngoại
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         16                   Trần Bình Trọng
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         17  Bệnh viện Chấn thương Chỉnh hình
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         18                     Rạp Đồng Tháp
#             1 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         19                       Rạp Đống Đa
#
# --- Thống kê ---
# - Tổng tuyến có dữ liệu: 5
# - Hướng phổ biến nhất: Direction
# Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)    519
# Name: count, dtype: int64

# %%
import pandas as pd

# Thiết lập để hiển thị toàn bộ DataFrame (tắt giới hạn hàng và cột)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# Hiển thị DataFrame

route_stops_df.head(300)
# Out:
#      Route_Number             Route_Name  \
# 0               1  Bến Thành- BX Chợ Lớn
# 1               1  Bến Thành- BX Chợ Lớn
# 2               1  Bến Thành- BX Chợ Lớn
# 3               1  Bến Thành- BX Chợ Lớn
# 4               1  Bến Thành- BX Chợ Lớn
# 5               1  Bến Thành- BX Chợ Lớn
# 6               1  Bến Thành- BX Chợ Lớn
# 7               1  Bến Thành- BX Chợ Lớn
# 8               1  Bến Thành- BX Chợ Lớn
# 9               1  Bến Thành- BX Chợ Lớn
# 10              1  Bến Thành- BX Chợ Lớn
# 11              1  Bến Thành- BX Chợ Lớn
# 12              1  Bến Thành- BX Chợ Lớn
# 13              1  Bến Thành- BX Chợ Lớn
# 14              1  Bến Thành- BX Chợ Lớn
# 15              1  Bến Thành- BX Chợ Lớn
# 16              1  Bến Thành- BX Chợ Lớn
# 17              1  Bến Thành- BX Chợ Lớn
# 18              1  Bến Thành- BX Chợ Lớn
# 19              1  Bến Thành- BX Chợ Lớn
# 20              1  Bến Thành- BX Chợ Lớn
# 21              1  Bến Thành- BX Chợ Lớn
# 22              1  Bến Thành- BX Chợ Lớn
# 23              1  Bến Thành- BX Chợ Lớn
# 24              1  Bến Thành- BX Chợ Lớn
# 25              1  Bến Thành- BX Chợ Lớn
# 26              1  Bến Thành- BX Chợ Lớn
# 27              1  Bến Thành- BX Chợ Lớn
# 28              1  Bến Thành- BX Chợ Lớn
# 29              1  Bến Thành- BX Chợ Lớn
# 30              1  Bến Thành- BX Chợ Lớn
# 31              1  Bến Thành- BX Chợ Lớn
# 32              1  Bến Thành- BX Chợ Lớn
# 33              1  Bến Thành- BX Chợ Lớn
# 34              1  Bến Thành- BX Chợ Lớn
# 35              1  Bến Thành- BX Chợ Lớn
# 36              1  Bến Thành- BX Chợ Lớn
# 37              1  Bến Thành- BX Chợ Lớn
# 38              1  Bến Thành- BX Chợ Lớn
# 39              1  Bến Thành- BX Chợ Lớn
# 40              1  Bến Thành- BX Chợ Lớn
# 41              1  Bến Thành- BX Chợ Lớn
# 42              1  Bến Thành- BX Chợ Lớn
# 43              1  Bến Thành- BX Chợ Lớn
# 44              1  Bến Thành- BX Chợ Lớn
# 45              1  Bến Thành- BX Chợ Lớn
# 46              1  Bến Thành- BX Chợ Lớn
# 47              1  Bến Thành- BX Chợ Lớn
# 48              1  Bến Thành- BX Chợ Lớn
# 49              1  Bến Thành- BX Chợ Lớn
# 50              1  Bến Thành- BX Chợ Lớn
# 51              1  Bến Thành- BX Chợ Lớn
# 52              1  Bến Thành- BX Chợ Lớn
# 53              1  Bến Thành- BX Chợ Lớn
# 54              1  Bến Thành- BX Chợ Lớn
# 55              1  Bến Thành- BX Chợ Lớn
# 56              1  Bến Thành- BX Chợ Lớn
# 57              1  Bến Thành- BX Chợ Lớn
# 58              1  Bến Thành- BX Chợ Lớn
# 59              1  Bến Thành- BX Chợ Lớn
# 60              1  Bến Thành- BX Chợ Lớn
# 61              1  Bến Thành- BX Chợ Lớn
# 62              1  Bến Thành- BX Chợ Lớn
# 63              1  Bến Thành- BX Chợ Lớn
# 64              1  Bến Thành- BX Chợ Lớn
# 65              1  Bến Thành- BX Chợ Lớn
# 66              1  Bến Thành- BX Chợ Lớn
# 67              1  Bến Thành- BX Chợ Lớn
# 68              1  Bến Thành- BX Chợ Lớn
# 69              1  Bến Thành- BX Chợ Lớn
# 70              1  Bến Thành- BX Chợ Lớn
# 71              1  Bến Thành- BX Chợ Lớn
# 72              1  Bến Thành- BX Chợ Lớn
# 73              1  Bến Thành- BX Chợ Lớn
# 74              1  Bến Thành- BX Chợ Lớn
# 75              1  Bến Thành- BX Chợ Lớn
# 76              1  Bến Thành- BX Chợ Lớn
# 77              1  Bến Thành- BX Chợ Lớn
# 78              1  Bến Thành- BX Chợ Lớn
# 79              1  Bến Thành- BX Chợ Lớn
# 80              1  Bến Thành- BX Chợ Lớn
# 81              1  Bến Thành- BX Chợ Lớn
# 82              1  Bến Thành- BX Chợ Lớn
# 83              1  Bến Thành- BX Chợ Lớn
# 84              1  Bến Thành- BX Chợ Lớn
# 85              1  Bến Thành- BX Chợ Lớn
# 86              1  Bến Thành- BX Chợ Lớn
# 87              1  Bến Thành- BX Chợ Lớn
# 88              1  Bến Thành- BX Chợ Lớn
# 89              1  Bến Thành- BX Chợ Lớn
# 90              1  Bến Thành- BX Chợ Lớn
# 91              1  Bến Thành- BX Chợ Lớn
# 92              1  Bến Thành- BX Chợ Lớn
# 93              1  Bến Thành- BX Chợ Lớn
# 94              1  Bến Thành- BX Chợ Lớn
# 95              1  Bến Thành- BX Chợ Lớn
# 96              1  Bến Thành- BX Chợ Lớn
# 97              1  Bến Thành- BX Chợ Lớn
# 98              1  Bến Thành- BX Chợ Lớn
# 99              1  Bến Thành- BX Chợ Lớn
# 100             1  Bến Thành- BX Chợ Lớn
# 101             1  Bến Thành- BX Chợ Lớn
# 102             1  Bến Thành- BX Chợ Lớn
# 103             1  Bến Thành- BX Chợ Lớn
# 104             1  Bến Thành- BX Chợ Lớn
# 105             1  Bến Thành- BX Chợ Lớn
# 106             1  Bến Thành- BX Chợ Lớn
# 107             1  Bến Thành- BX Chợ Lớn
# 108             1  Bến Thành- BX Chợ Lớn
# 109             1  Bến Thành- BX Chợ Lớn
# 110             1  Bến Thành- BX Chợ Lớn
# 111             1  Bến Thành- BX Chợ Lớn
# 112             1  Bến Thành- BX Chợ Lớn
# 113             1  Bến Thành- BX Chợ Lớn
# 114             1  Bến Thành- BX Chợ Lớn
# 115             1  Bến Thành- BX Chợ Lớn
# 116             1  Bến Thành- BX Chợ Lớn
# 117             1  Bến Thành- BX Chợ Lớn
# 118             1  Bến Thành- BX Chợ Lớn
# 119             1  Bến Thành- BX Chợ Lớn
# 120             1  Bến Thành- BX Chợ Lớn
# 121             1  Bến Thành- BX Chợ Lớn
# 122             1  Bến Thành- BX Chợ Lớn
# 123             1  Bến Thành- BX Chợ Lớn
# 124             1  Bến Thành- BX Chợ Lớn
# 125             1  Bến Thành- BX Chợ Lớn
# 126             1  Bến Thành- BX Chợ Lớn
# 127             1  Bến Thành- BX Chợ Lớn
# 128             1  Bến Thành- BX Chợ Lớn
# 129             1  Bến Thành- BX Chợ Lớn
# 130             1  Bến Thành- BX Chợ Lớn
# 131             1  Bến Thành- BX Chợ Lớn
# 132             1  Bến Thành- BX Chợ Lớn
# 133             1  Bến Thành- BX Chợ Lớn
# 134             1  Bến Thành- BX Chợ Lớn
# 135             1  Bến Thành- BX Chợ Lớn
# 136             1  Bến Thành- BX Chợ Lớn
# 137             1  Bến Thành- BX Chợ Lớn
# 138             1  Bến Thành- BX Chợ Lớn
# 139             1  Bến Thành- BX Chợ Lớn
# 140             1  Bến Thành- BX Chợ Lớn
# 141             1  Bến Thành- BX Chợ Lớn
# 142             1  Bến Thành- BX Chợ Lớn
# 143             1  Bến Thành- BX Chợ Lớn
# 144             1  Bến Thành- BX Chợ Lớn
# 145             1  Bến Thành- BX Chợ Lớn
# 146             1  Bến Thành- BX Chợ Lớn
# 147             1  Bến Thành- BX Chợ Lớn
# 148             1  Bến Thành- BX Chợ Lớn
# 149             1  Bến Thành- BX Chợ Lớn
# 150             1  Bến Thành- BX Chợ Lớn
# 151             1  Bến Thành- BX Chợ Lớn
# 152             1  Bến Thành- BX Chợ Lớn
# 153             1  Bến Thành- BX Chợ Lớn
# 154             1  Bến Thành- BX Chợ Lớn
# 155             1  Bến Thành- BX Chợ Lớn
# 156             1  Bến Thành- BX Chợ Lớn
# 157             1  Bến Thành- BX Chợ Lớn
# 158             1  Bến Thành- BX Chợ Lớn
# 159             1  Bến Thành- BX Chợ Lớn
# 160             1  Bến Thành- BX Chợ Lớn
# 161             1  Bến Thành- BX Chợ Lớn
# 162             1  Bến Thành- BX Chợ Lớn
# 163             1  Bến Thành- BX Chợ Lớn
# 164             1  Bến Thành- BX Chợ Lớn
# 165             1  Bến Thành- BX Chợ Lớn
# 166             1  Bến Thành- BX Chợ Lớn
# 167             1  Bến Thành- BX Chợ Lớn
# 168             1  Bến Thành- BX Chợ Lớn
# 169             1  Bến Thành- BX Chợ Lớn
# 170             1  Bến Thành- BX Chợ Lớn
# 171             1  Bến Thành- BX Chợ Lớn
# 172             1  Bến Thành- BX Chợ Lớn
# 173             1  Bến Thành- BX Chợ Lớn
# 174             1  Bến Thành- BX Chợ Lớn
# 175             1  Bến Thành- BX Chợ Lớn
# 176             1  Bến Thành- BX Chợ Lớn
# 177             1  Bến Thành- BX Chợ Lớn
# 178             1  Bến Thành- BX Chợ Lớn
# 179             1  Bến Thành- BX Chợ Lớn
# 180             1  Bến Thành- BX Chợ Lớn
# 181             1  Bến Thành- BX Chợ Lớn
# 182             1  Bến Thành- BX Chợ Lớn
# 183             1  Bến Thành- BX Chợ Lớn
# 184             1  Bến Thành- BX Chợ Lớn
# 185             1  Bến Thành- BX Chợ Lớn
# 186             1  Bến Thành- BX Chợ Lớn
# 187             1  Bến Thành- BX Chợ Lớn
# 188             1  Bến Thành- BX Chợ Lớn
# 189             1  Bến Thành- BX Chợ Lớn
# 190             1  Bến Thành- BX Chợ Lớn
# 191             1  Bến Thành- BX Chợ Lớn
# 192             1  Bến Thành- BX Chợ Lớn
# 193             1  Bến Thành- BX Chợ Lớn
# 194             1  Bến Thành- BX Chợ Lớn
# 195             1  Bến Thành- BX Chợ Lớn
# 196             1  Bến Thành- BX Chợ Lớn
# 197             1  Bến Thành- BX Chợ Lớn
# 198             1  Bến Thành- BX Chợ Lớn
# 199             1  Bến Thành- BX Chợ Lớn
# 200             1  Bến Thành- BX Chợ Lớn
# 201             1  Bến Thành- BX Chợ Lớn
# 202             1  Bến Thành- BX Chợ Lớn
# 203             1  Bến Thành- BX Chợ Lớn
# 204             1  Bến Thành- BX Chợ Lớn
# 205             1  Bến Thành- BX Chợ Lớn
# 206             1  Bến Thành- BX Chợ Lớn
# 207             1  Bến Thành- BX Chợ Lớn
# 208             1  Bến Thành- BX Chợ Lớn
# 209             1  Bến Thành- BX Chợ Lớn
# 210             1  Bến Thành- BX Chợ Lớn
# 211             1  Bến Thành- BX Chợ Lớn
# 212             1  Bến Thành- BX Chợ Lớn
# 213             1  Bến Thành- BX Chợ Lớn
# 214             1  Bến Thành- BX Chợ Lớn
# 215             1  Bến Thành- BX Chợ Lớn
# 216             1  Bến Thành- BX Chợ Lớn
# 217             1  Bến Thành- BX Chợ Lớn
# 218             1  Bến Thành- BX Chợ Lớn
# 219             1  Bến Thành- BX Chợ Lớn
# 220             1  Bến Thành- BX Chợ Lớn
# 221             1  Bến Thành- BX Chợ Lớn
# 222             1  Bến Thành- BX Chợ Lớn
# 223             1  Bến Thành- BX Chợ Lớn
# 224             1  Bến Thành- BX Chợ Lớn
# 225             1  Bến Thành- BX Chợ Lớn
# 226             1  Bến Thành- BX Chợ Lớn
# 227             1  Bến Thành- BX Chợ Lớn
# 228             1  Bến Thành- BX Chợ Lớn
# 229             1  Bến Thành- BX Chợ Lớn
# 230             1  Bến Thành- BX Chợ Lớn
# 231             1  Bến Thành- BX Chợ Lớn
# 232             1  Bến Thành- BX Chợ Lớn
# 233             1  Bến Thành- BX Chợ Lớn
# 234             1  Bến Thành- BX Chợ Lớn
# 235             1  Bến Thành- BX Chợ Lớn
# 236             1  Bến Thành- BX Chợ Lớn
# 237             1  Bến Thành- BX Chợ Lớn
# 238             1  Bến Thành- BX Chợ Lớn
# 239             1  Bến Thành- BX Chợ Lớn
# 240             1  Bến Thành- BX Chợ Lớn
# 241             1  Bến Thành- BX Chợ Lớn
# 242             1  Bến Thành- BX Chợ Lớn
# 243             1  Bến Thành- BX Chợ Lớn
# 244             1  Bến Thành- BX Chợ Lớn
# 245             1  Bến Thành- BX Chợ Lớn
# 246             1  Bến Thành- BX Chợ Lớn
# 247             1  Bến Thành- BX Chợ Lớn
# 248             1  Bến Thành- BX Chợ Lớn
# 249             1  Bến Thành- BX Chợ Lớn
# 250             1  Bến Thành- BX Chợ Lớn
# 251             1  Bến Thành- BX Chợ Lớn
# 252             1  Bến Thành- BX Chợ Lớn
# 253             1  Bến Thành- BX Chợ Lớn
# 254             1  Bến Thành- BX Chợ Lớn
# 255             1  Bến Thành- BX Chợ Lớn
# 256             1  Bến Thành- BX Chợ Lớn
# 257             1  Bến Thành- BX Chợ Lớn
# 258             1  Bến Thành- BX Chợ Lớn
# 259             1  Bến Thành- BX Chợ Lớn
# 260             1  Bến Thành- BX Chợ Lớn
# 261             1  Bến Thành- BX Chợ Lớn
# 262             1  Bến Thành- BX Chợ Lớn
# 263             1  Bến Thành- BX Chợ Lớn
# 264             1  Bến Thành- BX Chợ Lớn
# 265             1  Bến Thành- BX Chợ Lớn
# 266             1  Bến Thành- BX Chợ Lớn
# 267             1  Bến Thành- BX Chợ Lớn
# 268             1  Bến Thành- BX Chợ Lớn
# 269             1  Bến Thành- BX Chợ Lớn
# 270             1  Bến Thành- BX Chợ Lớn
# 271             1  Bến Thành- BX Chợ Lớn
# 272             1  Bến Thành- BX Chợ Lớn
# 273             1  Bến Thành- BX Chợ Lớn
# 274             1  Bến Thành- BX Chợ Lớn
# 275             1  Bến Thành- BX Chợ Lớn
# 276             1  Bến Thành- BX Chợ Lớn
# 277             1  Bến Thành- BX Chợ Lớn
# 278             1  Bến Thành- BX Chợ Lớn
# 279             1  Bến Thành- BX Chợ Lớn
# 280             1  Bến Thành- BX Chợ Lớn
# 281             1  Bến Thành- BX Chợ Lớn
# 282             1  Bến Thành- BX Chợ Lớn
# 283             1  Bến Thành- BX Chợ Lớn
# 284             1  Bến Thành- BX Chợ Lớn
# 285             1  Bến Thành- BX Chợ Lớn
# 286             1  Bến Thành- BX Chợ Lớn
# 287             1  Bến Thành- BX Chợ Lớn
# 288             1  Bến Thành- BX Chợ Lớn
# 289             1  Bến Thành- BX Chợ Lớn
# 290             1  Bến Thành- BX Chợ Lớn
# 291             1  Bến Thành- BX Chợ Lớn
# 292             1  Bến Thành- BX Chợ Lớn
# 293             1  Bến Thành- BX Chợ Lớn
# 294             1  Bến Thành- BX Chợ Lớn
# 295             1  Bến Thành- BX Chợ Lớn
# 296             1  Bến Thành- BX Chợ Lớn
# 297             1  Bến Thành- BX Chợ Lớn
# 298             1  Bến Thành- BX Chợ Lớn
# 299             1  Bến Thành- BX Chợ Lớn
#
#                                                   URL  \
# 0    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 1    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 2    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 3    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 4    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 5    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 6    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 7    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 8    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 9    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 10   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 11   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 12   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 13   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 14   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 15   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 16   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 17   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 18   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 19   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 20   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 21   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 22   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 23   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 24   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 25   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 26   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 27   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 28   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 29   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 30   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 31   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 32   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 33   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 34   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 35   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 36   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 37   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 38   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 39   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 40   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 41   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 42   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 43   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 44   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 45   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 46   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 47   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 48   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 49   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 50   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 51   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 52   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 53   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 54   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 55   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 56   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 57   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 58   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 59   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 60   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 61   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 62   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 63   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 64   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 65   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 66   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 67   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 68   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 69   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 70   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 71   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 72   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 73   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 74   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 75   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 76   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 77   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 78   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 79   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 80   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 81   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 82   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 83   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 84   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 85   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 86   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 87   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 88   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 89   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 90   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 91   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 92   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 93   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 94   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 95   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 96   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 97   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 98   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 99   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 100  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 101  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 102  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 103  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 104  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 105  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 106  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 107  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 108  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 109  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 110  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 111  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 112  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 113  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 114  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 115  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 116  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 117  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 118  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 119  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 120  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 121  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 122  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 123  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 124  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 125  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 126  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 127  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 128  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 129  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 130  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 131  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 132  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 133  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 134  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 135  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 136  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 137  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 138  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 139  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 140  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 141  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 142  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 143  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 144  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 145  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 146  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 147  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 148  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 149  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 150  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 151  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 152  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 153  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 154  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 155  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 156  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 157  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 158  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 159  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 160  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 161  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 162  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 163  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 164  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 165  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 166  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 167  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 168  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 169  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 170  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 171  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 172  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 173  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 174  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 175  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 176  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 177  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 178  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 179  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 180  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 181  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 182  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 183  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 184  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 185  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 186  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 187  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 188  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 189  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 190  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 191  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 192  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 193  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 194  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 195  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 196  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 197  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 198  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 199  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 200  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 201  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 202  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 203  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 204  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 205  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 206  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 207  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 208  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 209  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 210  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 211  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 212  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 213  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 214  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 215  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 216  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 217  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 218  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 219  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 220  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 221  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 222  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 223  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 224  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 225  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 226  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 227  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 228  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 229  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 230  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 231  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 232  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 233  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 234  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 235  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 236  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 237  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 238  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 239  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 240  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 241  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 242  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 243  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 244  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 245  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 246  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 247  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 248  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 249  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 250  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 251  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 252  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 253  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 254  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 255  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 256  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 257  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 258  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 259  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 260  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 261  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 262  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 263  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 264  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 265  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 266  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 267  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 268  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 269  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 270  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 271  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 272  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 273  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 274  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 275  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 276  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 277  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 278  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 279  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 280  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 281  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 282  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 283  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 284  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 285  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 286  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 287  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 288  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 289  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 290  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 291  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 292  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 293  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 294  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 295  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 296  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 297  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 298  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 299  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
#
#                                                           Direction  \
# 0                                                        BX Chợ Lớn
# 1                                                        BX Chợ Lớn
# 2                                                        BX Chợ Lớn
# 3                                                        BX Chợ Lớn
# 4                                                        BX Chợ Lớn
# 5                                                        BX Chợ Lớn
# 6                                                        BX Chợ Lớn
# 7                                                        BX Chợ Lớn
# 8                                                        BX Chợ Lớn
# 9                                                        BX Chợ Lớn
# 10                                                       BX Chợ Lớn
# 11                                                       BX Chợ Lớn
# 12                                                       BX Chợ Lớn
# 13                                                       BX Chợ Lớn
# 14                                                       BX Chợ Lớn
# 15                                                       BX Chợ Lớn
# 16                                                       BX Chợ Lớn
# 17                                                       BX Chợ Lớn
# 18                                                       BX Chợ Lớn
# 19                                                       BX Chợ Lớn
# 20                                                       BX Chợ Lớn
# 21                                                       BX Chợ Lớn
# 22                                                       BX Chợ Lớn
# 23                                                       BX Chợ Lớn
# 24                                                       BX Chợ Lớn
# 25                                                       BX Chợ Lớn
# 26                                                       BX Chợ Lớn
# 27                                                       BX Chợ Lớn
# 28                                                       BX Chợ Lớn
# 29                                                        Bến Thành
# 30                                                        Bến Thành
# 31                                                        Bến Thành
# 32                                                        Bến Thành
# 33                                                        Bến Thành
# 34                                                        Bến Thành
# 35                                                        Bến Thành
# 36                                                        Bến Thành
# 37                                                        Bến Thành
# 38                                                        Bến Thành
# 39                                                        Bến Thành
# 40                                                        Bến Thành
# 41                                                        Bến Thành
# 42                                                        Bến Thành
# 43                                                        Bến Thành
# 44                                                        Bến Thành
# 45                                                        Bến Thành
# 46                                                        Bến Thành
# 47                                                        Bến Thành
# 48                                                        Bến Thành
# 49                                                        Bến Thành
# 50                                                        Bến Thành
# 51                                                        Bến Thành
# 52                                                        Bến Thành
# 53                                                        Bến Thành
# 54                                                        Bến Thành
# 55                                                        Bến Thành
# 56                                                        Bến Thành
# 57                                                        Bến Thành
# 58                                                        Bến Thành
# 59                                                        Bến Thành
# 60                                                        Bến Thành
# 61                                                        Bến Thành
# 62                                                        Bến Thành
# 63                                                        Bến Thành
# 64   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 65   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 66   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 67   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 68   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 69   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 70   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 71   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 72   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 73   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 74   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 75   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 76   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 77   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 78   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 79   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 80   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 81   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 82   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 83   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 84   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 85   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 86   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 87   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 88   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 89   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 90   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 91   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 92   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 93   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 94   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 95   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 96   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 97   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 98   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 99   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 100  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 101  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 102  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 103  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 104  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 105  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 106  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 107  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 108  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 109  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 110  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 111  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 112  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 113  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 114  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 115  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 116  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 117  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 118  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 119  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 120  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 121  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 122  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 123  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 124  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 125  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 126  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 127  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 128  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 129  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 130  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 131  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 132  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 133  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 134  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 135  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 136  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 137  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 138  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 139  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 140  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 141  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 142  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 143  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 144  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 145  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 146  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 147  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 148  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 149  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 150  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 151  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 152  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 153  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 154  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 155  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 156  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 157  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 158  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 159  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 160  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 161  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 162  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 163  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 164  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 165  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 166  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 167  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 168  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 169  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 170  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 171  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 172  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 173  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 174  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 175  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 176  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 177  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 178  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 179  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 180  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 181  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 182  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 183  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 184   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 185   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 186   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 187   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 188   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 189   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 190   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 191   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 192   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 193   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 194   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 195   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 196   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 197   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 198   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 199   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 200   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 201   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 202   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 203   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 204   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 205   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 206   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 207   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 208   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 209   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 210   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 211   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 212   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 213   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 214   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 215   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 216   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 217   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 218   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 219   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 220   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 221   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 222   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 223   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 224   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 225   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 226   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 227   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 228   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 229   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 230   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 231   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 232   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 233   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 234   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 235   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 236   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 237   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 238   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 239   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 240   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 241   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 242   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 243   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 244   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 245   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# ...
# 296   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 297   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 298   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 299   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#
#     Stop_Order                          Stop_Name
# 0            A                Công Trường Mê Linh
# 1            1                      Bến Bạch Đằng
# 2            2             Cục Hải Quan Thành Phố
# 3            3                             Chợ Cũ
# 4            4                   Trường Cao Thắng
# 5            5                  Công ty Đường sắt
# 6            6                      Bến Thành B
# 7            7              Trường Ernst Thalmann
# 8            8                  KTX Trần Hưng Đạo
# 9            9                       Rạp Hưng Đạo
# 10          10             Bệnh viện Răng Hàm Mặt
# 11          11                       Trần Đình Xu
# 12          12                     Tổng Cty Samco
# 13          13                          Chợ Nanci
# 14          14                        Nguyễn Biểu
# 15          15  Trường Cao đẳng Kinh tế Đối ngoại
# 16          16                    Trần Bình Trọng
# 17          17   Bệnh viện Chấn thương Chỉnh hình
# 18          18                      Rạp Đồng Tháp
# 19          19                        Rạp Đống Đa
# 20          20                         Đồng Khánh
# 21          21                 Nhà Văn hóa Quận 5
# 22          22                          Ngô Quyền
# 23          23                             Tản Đà
# 24          24                   Triệu Quang Phục
# 25          25                    Bưu điện Quận 5
# 26          26                 Hải Thượng Lãn Ông
# 27          27                       Chợ Kim Biên
# 28           B                     Bến xe Chợ Lớn
# 29           A                     Bến xe Chợ Lớn
# 30           1                         Chu Văn An
# 31           2                          Tháp Mười
# 32           3                       Chợ Kim Biên
# 33           4                    Bưu điện Quận 5
# 34           5                      Rạp Đại Quang
# 35           6                      Lương Nhữ Học
# 36           7                   Triệu Quang Phục
# 37           8   Đại học Sư phạm Thể dục thể thao
# 38           9          Siêu thị Điện máy Chợ Lớn
# 39          10                          Ngô Quyền
# 40          11               Chung cư Nguyễn Trãi
# 41          12                  Siêu thị Điện máy
# 42          13                 Nhà Văn hóa Quận 5
# 43          14                         Đồng Khánh
# 44          15                            An Bình
# 45          16                      Rạp Đồng Tháp
# 46          17   Bệnh viện Chấn Thương Chỉnh hình
# 47          18                    Trần Bình Trọng
# 48          19                        Nguyễn Biểu
# 49          20                          Chợ Nanci
# 50          21                     Tổng Cty Samco
# 51          22                            Sở PCCC
# 52          23                         Hồ Hảo Hớn
# 53          24             Bệnh Viện Răng Hàm Mặt
# 54          25                  Rạp Trần Hưng Đạo
# 55          26                  KTX Trần Hưng Đạo
# 56          27                         Nguyễn Kim
# 57          28                      Bến Thành E
# 58          29                           Hàm Nghi
# 59          30                             Chợ Củ
# 60          31                        Hồ Tùng Mậu
# 61          32                      Bến Bạch Đằng
# 62          33                Công Trường Mê Linh
# 63           B                Công Trường Mê Linh
# 64           1                      05:00 - 05:35
# 65           2                      05:10 - 05:45
# 66           3                      05:20 - 05:55
# 67           4                      05:30 - 06:05
# 68           5                      05:38 - 06:13
# 69           6                      05:46 - 06:21
# 70           7                      05:54 - 06:29
# 71           8                      06:02 - 06:37
# 72           9                      06:08 - 06:43
# 73          10                      06:14 - 06:49
# 74          11                      06:20 - 06:55
# 75          12                      06:26 - 07:01
# 76          13                      06:32 - 07:07
# 77          14                      06:38 - 07:13
# 78          15                      06:44 - 07:19
# 79          16                      06:50 - 07:25
# 80          17                      06:56 - 07:31
# 81          18                      07:02 - 07:37
# 82          19                      07:08 - 07:43
# 83          20                      07:14 - 07:49
# 84          21                      07:22 - 07:57
# 85          22                      07:30 - 08:05
# 86          23                      07:38 - 08:13
# 87          24                      07:46 - 08:21
# 88          25                      07:54 - 08:29
# 89          26                      08:02 - 08:37
# 90          27                      08:10 - 08:45
# 91          28                      08:18 - 08:53
# 92          29                      08:26 - 09:01
# 93          30                      08:34 - 09:09
# 94          31                      08:42 - 09:17
# 95          32                      08:50 - 09:25
# 96          33                      08:58 - 09:33
# 97          34                      09:06 - 09:41
# 98          35                      09:14 - 09:49
# 99          36                      09:22 - 09:57
# 100         37                      09:30 - 10:05
# 101         38                      09:38 - 10:13
# 102         39                      09:46 - 10:21
# 103         40                      09:54 - 10:29
# 104         41                      10:02 - 10:37
# 105         42                      10:10 - 10:45
# 106         43                      10:18 - 10:53
# 107         44                      10:24 - 10:59
# 108         45                      10:30 - 11:05
# 109         46                      10:36 - 11:11
# 110         47                      10:42 - 11:17
# 111         48                      10:48 - 11:23
# 112         49                      10:54 - 11:29
# 113         50                      11:00 - 11:35
# 114         51                      11:06 - 11:41
# 115         52                      11:12 - 11:47
# 116         53                      11:18 - 11:53
# 117         54                      11:26 - 12:01
# 118         55                      11:34 - 12:09
# 119         56                      11:42 - 12:17
# 120         57                      11:50 - 12:25
# 121         58                      11:58 - 12:33
# 122         59                      12:06 - 12:41
# 123         60                      12:16 - 12:51
# 124         61                      12:26 - 13:01
# 125         62                      12:36 - 13:11
# 126         63                      12:46 - 13:21
# 127         64                      12:56 - 13:31
# 128         65                      13:06 - 13:41
# 129         66                      13:14 - 13:49
# 130         67                      13:22 - 13:57
# 131         68                      13:30 - 14:05
# 132         69                      13:38 - 14:13
# 133         70                      13:46 - 14:21
# 134         71                      13:54 - 14:29
# 135         72                      14:02 - 14:37
# 136         73                      14:10 - 14:45
# 137         74                      14:18 - 14:53
# 138         75                      14:26 - 15:01
# 139         76                      14:34 - 15:09
# 140         77                      14:42 - 15:17
# 141         78                      14:50 - 15:25
# 142         79                      14:58 - 15:33
# 143         80                      15:06 - 15:41
# 144         81                      15:14 - 15:49
# 145         82                      15:22 - 15:57
# 146         83                      15:30 - 16:05
# 147         84                      15:38 - 16:13
# 148         85                      15:46 - 16:21
# 149         86                      15:54 - 16:29
# 150         87                      16:02 - 16:37
# 151         88                      16:08 - 16:43
# 152         89                      16:14 - 16:49
# 153         90                      16:20 - 16:55
# 154         91                      16:26 - 17:01
# 155         92                      16:32 - 17:07
# 156         93                      16:38 - 17:13
# 157         94                      16:44 - 17:19
# 158         95                      16:50 - 17:25
# 159         96                      16:56 - 17:31
# 160         97                      17:02 - 17:37
# 161         98                      17:08 - 17:43
# 162         99                      17:14 - 17:49
# 163        100                      17:22 - 17:57
# 164        101                      17:30 - 18:05
# 165        102                      17:38 - 18:13
# 166        103                      17:46 - 18:21
# 167        104                      17:54 - 18:29
# 168        105                      18:02 - 18:37
# 169        106                      18:10 - 18:45
# 170        107                      18:20 - 18:55
# 171        108                      18:30 - 19:05
# 172        109                      18:40 - 19:15
# 173        110                      18:50 - 19:25
# 174        111                      19:00 - 19:35
# 175        112                      19:10 - 19:45
# 176        113                      19:20 - 19:55
# 177        114                      19:30 - 20:05
# 178        115                      19:40 - 20:15
# 179        116                      19:50 - 20:25
# 180        117                      20:00 - 20:35
# 181        118                      20:10 - 20:45
# 182        119                      20:20 - 20:55
# 183        120                      20:30 - 21:05
# 184          1                      05:00 - 05:30
# 185          2                      05:10 - 05:40
# 186          3                      05:20 - 05:50
# 187          4                      05:30 - 06:00
# 188          5                      05:40 - 06:10
# 189          6                      05:48 - 06:18
# 190          7                      05:56 - 06:26
# 191          8                      06:04 - 06:34
# 192          9                      06:12 - 06:42
# 193         10                      06:20 - 06:50
# 194         11                      06:26 - 06:56
# 195         12                      06:32 - 07:02
# 196         13                      06:38 - 07:08
# 197         14                      06:44 - 07:14
# 198         15                      06:50 - 07:20
# 199         16                      06:56 - 07:26
# 200         17                      07:02 - 07:32
# 201         18                      07:08 - 07:38
# 202         19                      07:14 - 07:44
# 203         20                      07:20 - 07:50
# 204         21                      07:28 - 07:58
# 205         22                      07:36 - 08:06
# 206         23                      07:44 - 08:14
# 207         24                      07:52 - 08:22
# 208         25                      08:00 - 08:30
# 209         26                      08:08 - 08:38
# 210         27                      08:16 - 08:46
# 211         28                      08:24 - 08:54
# 212         29                      08:32 - 09:02
# 213         30                      08:40 - 09:10
# 214         31                      08:48 - 09:18
# 215         32                      08:56 - 09:26
# 216         33                      09:04 - 09:34
# 217         34                      09:12 - 09:42
# 218         35                      09:20 - 09:50
# 219         36                      09:28 - 09:58
# 220         37                      09:36 - 10:06
# 221         38                      09:44 - 10:14
# 222         39                      09:52 - 10:22
# 223         40                      10:00 - 10:30
# 224         41                      10:08 - 10:38
# 225         42                      10:16 - 10:46
# 226         43                      10:24 - 10:54
# 227         44                      10:30 - 11:00
# 228         45                      10:36 - 11:06
# 229         46                      10:42 - 11:12
# 230         47                      10:48 - 11:18
# 231         48                      10:54 - 11:24
# 232         49                      11:00 - 11:30
# 233         50                      11:06 - 11:36
# 234         51                      11:12 - 11:42
# 235         52                      11:18 - 11:48
# 236         53                      11:24 - 11:54
# 237         54                      11:32 - 12:02
# 238         55                      11:40 - 12:10
# 239         56                      11:48 - 12:18
# 240         57                      11:56 - 12:26
# 241         58                      12:04 - 12:34
# 242         59                      12:14 - 12:44
# 243         60                      12:24 - 12:54
# 244         61                      12:34 - 13:04
# 245         62                      12:44 - 13:14
# 246         63                      12:54 - 13:24
# 247         64                      13:04 - 13:34
# 248         65                      13:14 - 13:44
# 249         66                      13:22 - 13:52
# 250         67                      13:30 - 14:00
# 251         68                      13:38 - 14:08
# 252         69                      13:46 - 14:16
# 253         70                      13:54 - 14:24
# 254         71                      14:02 - 14:32
# 255         72                      14:10 - 14:40
# 256         73                      14:18 - 14:48
# 257         74                      14:26 - 14:56
# 258         75                      14:34 - 15:04
# 259         76                      14:42 - 15:12
# 260         77                      14:50 - 15:20
# 261         78                      14:58 - 15:28
# 262         79                      15:06 - 15:36
# 263         80                      15:14 - 15:44
# 264         81                      15:22 - 15:52
# 265         82                      15:30 - 16:00
# 266         83                      15:38 - 16:08
# 267         84                      15:46 - 16:16
# 268         85                      15:54 - 16:24
# 269         86                      16:02 - 16:32
# 270         87                      16:08 - 16:38
# 271         88                      16:14 - 16:44
# 272         89                      16:20 - 16:50
# 273         90                      16:26 - 16:56
# 274         91                      16:32 - 17:02
# 275         92                      16:38 - 17:08
# 276         93                      16:44 - 17:14
# 277         94                      16:50 - 17:20
# 278         95                      16:56 - 17:26
# 279         96                      17:02 - 17:32
# 280         97                      17:08 - 17:38
# 281         98                      17:14 - 17:44
# 282         99                      17:20 - 17:50
# 283        100                      17:28 - 17:58
# 284        101                      17:36 - 18:06
# 285        102                      17:44 - 18:14
# 286        103                      17:52 - 18:22
# 287        104                      18:00 - 18:30
# 288        105                      18:08 - 18:38
# 289        106                      18:16 - 18:46
# 290        107                      18:24 - 18:54
# 291        108                      18:32 - 19:02
# 292        109                      18:40 - 19:10
# 293        110                      18:50 - 19:20
# 294        111                      19:00 - 19:30
# 295        112                      19:10 - 19:40
# 296        113                      19:20 - 19:50
# 297        114                      19:30 - 20:00
# 298        115                      19:40 - 20:10
# 299        116                      19:50 - 20:20

# %%
import re
import pandas as pd

# Tạo timetable_df (nếu chưa có)
if 'timetable_df' not in globals():
    timetable_df = pd.DataFrame(columns=route_stops_df.columns)
    print("✅ Tạo timetable_df")
# 1) Chuẩn hóa cột Stop_Name sang string và thay các loại gạch nối về '-'
route_stops_df['Stop_Name'] = (
    route_stops_df['Stop_Name']
    .astype(str)
    .str.replace(r'[–—−]', '-', regex=True)  # en/em dash, minus
    .str.strip()
)

# 2) Regex nhận diện "biểu đồ giờ": HH:MM - HH:MM (24h), cho phép khoảng trắng linh hoạt
time_range_regex = r'^(?:[01]?\d|2[0-3]):[0-5]\d\s*-\s*(?:[01]?\d|2[0-3]):[0-5]\d$'

mask_is_timetable = route_stops_df['Stop_Name'].str.fullmatch(time_range_regex, na=False)

# 3) Tạo/append sang timetable_df
try:
    timetable_df  # check đã tồn tại chưa
except NameError:
    timetable_df = route_stops_df.loc[mask_is_timetable].copy()
else:
    timetable_df = pd.concat(
        [timetable_df, route_stops_df.loc[mask_is_timetable]],
        ignore_index=True
    )

# 4) Xóa các dòng đã move khỏi route_stops_df
route_stops_df = route_stops_df.loc[~mask_is_timetable].copy()

# (tuỳ chọn) reset index cho đẹp
timetable_df.reset_index(drop=True, inplace=True)
route_stops_df.reset_index(drop=True, inplace=True)
# Out:
# ✅ Tạo timetable_df

# %%
timetable_df.head()
# Out:
#   Route_Number             Route_Name  \
# 0            1  Bến Thành- BX Chợ Lớn
# 1            1  Bến Thành- BX Chợ Lớn
# 2            1  Bến Thành- BX Chợ Lớn
# 3            1  Bến Thành- BX Chợ Lớn
# 4            1  Bến Thành- BX Chợ Lớn
#
#                                                 URL  \
# 0  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 1  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 2  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 3  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 4  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
#
#                                                         Direction Stop_Order  \
# 0  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)          1
# 1  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)          2
# 2  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)          3
# 3  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)          4
# 4  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)          5
#
#        Stop_Name
# 0  05:00 - 05:35
# 1  05:10 - 05:45
# 2  05:20 - 05:55
# 3  05:30 - 06:05
# 4  05:38 - 06:13

# %%
import requests
from bs4 import BeautifulSoup
import html
import pandas as pd
import re
import time

# ===== Helper: tách info & biểu đồ giờ trong 1 panel (một chiều "Đi ...") =====
def parse_timetable_panel(header_h3):
    """
    Input: thẻ <h3> của một chiều (ví dụ: 'Đi An Sương')
    Output:
        direction (str),
        info (dict): Trips_Count, Trip_Duration, Operating_Time (có thể None nếu không tìm được),
        trips (list[dict]): [{Order, Start, End, Raw}]
    """
    # Lấy tên chiều (text trực tiếp của h3, bỏ phần <span> ngày)
    direction = header_h3.find(string=True, recursive=False)
    direction = direction.strip() if direction else header_h3.get_text(strip=True)

    panel = header_h3.find_next_sibling("div", class_="ui-accordion-content")
    info = {"Trips_Count": None, "Trip_Duration": None, "Operating_Time": None}
    trips = []

    if not panel:
        return direction, info, trips

    # 1) Lấy bảng info đầu panel (nếu có)
    info_table = panel.find("table")
    if info_table:
        for td in info_table.find_all("td"):
            text = td.get_text(strip=True)
            if text.startswith("Số chuyến:"):
                m = re.search(r"Số chuyến:\s*(\d+)", text)
                if m:
                    info["Trips_Count"] = int(m.group(1))
            elif text.startswith("Thời gian chuyến:"):
                # Ví dụ: "Thời gian chuyến: 50 - 65 phút"
                info["Trip_Duration"] = text.split(":", 1)[-1].strip()
            elif text.startswith("Thời gian hoạt động:"):
                # Ví dụ: "Thời gian hoạt động: 05:30 - 20:30"
                info["Operating_Time"] = text.split(":", 1)[-1].strip()

    # 2) Lấy các ô giờ trong panel (td.time: "HH:MM - HH:MM")
    order = 0
    for td in panel.select("td.time"):
        raw = td.get_text(strip=True)
        m = re.search(r"(\d{2}:\d{2})\s*-\s*(\d{2}:\d{2})", raw)
        if m:
            order += 1
            trips.append({
                "Order": order,
                "Start": m.group(1),
                "End": m.group(2),
                "Raw": raw
            })
    return direction, info, trips


# ====== Main: chỉ lấy biểu đồ giờ ======
csv_filename = 'tuyen_xe_buyt.csv'
try:
    df = pd.read_csv(csv_filename)
    print(f"Đã đọc thành công {len(df)} tuyến từ file {csv_filename}")
except FileNotFoundError:
    print(f"Không tìm thấy file {csv_filename}. Vui lòng chạy code scrape URL trước!")
    raise SystemExit

# Giới hạn để test nhanh
df = df.head(5)
print(f"Test với {len(df)} tuyến đầu tiên...")

timetable_rows = []

print(f"Bắt đầu scrape biểu đồ giờ cho {len(df)} tuyến...")
for _, row in df.iterrows():
    route_number = row['Route_Number']
    route_name = row['Route_Name']
    url = row['URL']

    print(f"\n--- Tuyến {route_number}: {route_name} ---")
    print(f"URL: {url}")

    try:
        headers = {
            'User-Agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                           'AppleWebKit/537.36 (KHTML, like Gecko) '
                           'Chrome/120.0.0.0 Safari/537.36')
        }
        resp = requests.get(url, headers=headers, timeout=30)
        resp.raise_for_status()

        html_content = html.unescape(resp.text)
        soup = BeautifulSoup(html_content, "html.parser")
        print(f"✅ Parse HTML ok. Độ dài: {len(resp.text)}")

        # Duyệt tất cả chiều trong #accTimetable
        headers_h3 = soup.select("#accTimetable > h3.ui-accordion-header")
        if not headers_h3:
            print("⚠️ Không tìm thấy H3 chiều trong #accTimetable")
            continue

        for h3 in headers_h3:
            # Chỉ giữ các h3 có chữ "Đi "
            if "Đi " not in h3.get_text():
                continue

            direction, info, trips = parse_timetable_panel(h3)

            # Append từng trip
            for t in trips:
                timetable_rows.append({
                    "Route_Number": route_number,
                    "Route_Name": route_name,
                    "URL": url,
                    "Direction": direction,
                    "Order": t["Order"],
                    "Start": t["Start"],
                    "End": t["End"],
                    "Raw": t["Raw"],
                    "Trips_Count": info["Trips_Count"],
                    "Trip_Duration": info["Trip_Duration"],
                    "Operating_Time": info["Operating_Time"],
                })

            print(f"  ✅ {direction}: {len(trips)} chuyến")

    except requests.exceptions.RequestException as e:
        print(f"❌ HTTP error tuyến {route_number}: {e}")
    except Exception as e:
        print(f"❌ Lỗi xử lý tuyến {route_number}: {e}")
        import traceback; traceback.print_exc()

    time.sleep(1.5)

print("\n--- Kết thúc scrape ---")
print(f"Tổng số dòng biểu đồ giờ thu được: {len(timetable_rows)}")

if timetable_rows:
    timetable_df = pd.DataFrame(timetable_rows)
    out_file = "tuyen_xe_buyt_bieudo_gio.csv"
    timetable_df.to_csv(out_file, index=False, encoding="utf-8")
    print(f"✅ Đã lưu {len(timetable_df)} dòng vào {out_file}")

    # Preview
    print("\n--- Preview (top 20) ---")
    print(timetable_df.head(20).to_string(index=False))

    # Thống kê nhanh
    print("\n--- Thống kê ---")
    print(f"- Số tuyến có dữ liệu: {timetable_df['Route_Number'].nunique()}")
    print(f"- Số chiều: {timetable_df['Direction'].nunique()}")
    print(f"- Số chuyến TB/tuyến: {len(timetable_df) / timetable_df['Route_Number'].nunique():.1f}")
else:
    print("❌ Không có dữ liệu biểu đồ giờ. Kiểm tra HTML thực tế của site.")
# Out:
# Đã đọc thành công 5 tuyến từ file tuyen_xe_buyt.csv
# Test với 5 tuyến đầu tiên...
# Bắt đầu scrape biểu đồ giờ cho 5 tuyến...
#
# --- Tuyến 1: Bến Thành- BX Chợ Lớn ---
# URL: https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# ✅ Parse HTML ok. Độ dài: 52658
# ⚠️ Không tìm thấy H3 chiều trong #accTimetable
#
# --- Tuyến 2: Bến Thành- BX Miền Tây ---
# URL: https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html
# ✅ Parse HTML ok. Độ dài: 52394
# ⚠️ Không tìm thấy H3 chiều trong #accTimetable
#
# --- Tuyến 3: Bến Thành- Thạnh Lộc ---
# URL: https://xebuyt.net/ben-thanh-thanh-loc.html
# ✅ Parse HTML ok. Độ dài: 67605
# ⚠️ Không tìm thấy H3 chiều trong #accTimetable
#
# --- Tuyến 4: Bến Thành- Cộng Hòa- An Sương ---
# URL: https://xebuyt.net/ben-thanh-cong-hoa-an-suong.html
# ✅ Parse HTML ok. Độ dài: 65800
# ⚠️ Không tìm thấy H3 chiều trong #accTimetable
#
# --- Tuyến 5: Bến xe Chợ Lớn - Biên Hòa ---
# URL: https://xebuyt.net/ben-xe-cho-lon-bien-hoa.html
# ✅ Parse HTML ok. Độ dài: 56251
# ⚠️ Không tìm thấy H3 chiều trong #accTimetable
#
# --- Kết thúc scrape ---
# Tổng số dòng biểu đồ giờ thu được: 0
# ❌ Không có dữ liệu biểu đồ giờ. Kiểm tra HTML thực tế của site.

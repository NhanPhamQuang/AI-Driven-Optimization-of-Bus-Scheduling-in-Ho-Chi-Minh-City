# %% [markdown]
# # Cài đặt thư viện

# %%
# !pip install requests beautifulsoup4
# !pip install pymongo
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.8.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.12/dist-packages (4.15.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymongo) (2.8.0)

# %% [markdown]
# # Lấy URL

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# URL của trang web
url = 'https://xebuyt.net/tuyen-xe-buyt'

# Gửi request để lấy nội dung trang
response = requests.get(url)
response.raise_for_status()  # Kiểm tra lỗi nếu có

# Parse HTML với BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Tìm div chứa danh sách tuyến
div_result = soup.find('div', id='divResult')

# Tìm tất cả các thẻ <a> với class 'cms-button'
route_links = div_result.find_all('a', class_='cms-button')

# Danh sách để lưu dữ liệu
data = []

# Duyệt qua từng link
for link in route_links:
    # Lấy href
    href = link.get('href')
    full_url = 'https://xebuyt.net' + href if href.startswith('/') else href

    # Lấy số tuyến từ span.icon
    route_number = link.find('span', class_='icon').get_text(strip=True)

    # Lấy tên tuyến từ div.routetrip
    route_name = link.find('div', class_='routetrip').get_text(strip=True)

    # Thêm vào danh sách
    data.append({
        'Route_Number': route_number,
        'Route_Name': route_name,
        'URL': full_url
    })

# Lưu vào file CSV
filename = 'tuyen_xe_buyt.csv'
with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Route_Number', 'Route_Name', 'URL']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerows(data)

print(f'Dữ liệu đã được lưu vào file {filename}. Tổng số tuyến: {len(data)}')

# Hiển thị dưới dạng DataFrame (comment nếu không cần)
df = pd.DataFrame(data)
df.head()
# Out:
# Dữ liệu đã được lưu vào file tuyen_xe_buyt.csv. Tổng số tuyến: 140
#   Route_Number                     Route_Name  \
# 0           01          Bến Thành- BX Chợ Lớn
# 1           02         Bến Thành- BX Miền Tây
# 2           03           Bến Thành- Thạnh Lộc
# 3           04  Bến Thành- Cộng Hòa- An Sương
# 4           05      Bến xe Chợ Lớn - Biên Hòa
#
#                                                    URL
# 0     https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 1    https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html
# 2          https://xebuyt.net/ben-thanh-thanh-loc.html
# 3  https://xebuyt.net/ben-thanh-cong-hoa-an-suong.html
# 4      https://xebuyt.net/ben-xe-cho-lon-bien-hoa.html

# %% [markdown]
# # Lấy thông tin chuyến xe

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re

# Đọc file CSV đã tạo trước đó
csv_filename = 'tuyen_xe_buyt.csv'
df = pd.read_csv(csv_filename)

# Danh sách để lưu dữ liệu mở rộng
extended_data = []

# Headers cho CSV mới
headers = [
    'Route_Number', 'Route_Name', 'URL',
    'Operator', 'Operating_Type', 'Distance', 'Vehicle_Type', 'Operating_Hours',
    'Ticket_Price', 'Number_of_Trips', 'Trip_Time', 'Frequency'
]

# Duyệt qua từng hàng trong DataFrame
for index, row in df.iterrows():
    route_number = row['Route_Number']
    route_name = row['Route_Name']
    url = row['URL']

    print(f"Đang scrape tuyến {route_number}: {route_name}")

    try:
        # Gửi request
        response = requests.get(url)
        response.raise_for_status()

        # Parse HTML
        soup = BeautifulSoup(response.content, 'html.parser')

        # Tìm div rouInfo và table
        rou_info_div = soup.find('div', id='rouInfo')
        if not rou_info_div:
            print(f"Không tìm thấy div#rouInfo cho tuyến {route_number}")
            continue

        table = rou_info_div.find('table', class_='tbl100')
        if not table:
            print(f"Không tìm thấy table cho tuyến {route_number}")
            continue

        # Khởi tạo giá trị mặc định
        operator = ''
        operating_type = ''
        distance = ''
        vehicle_type = ''
        operating_hours = ''
        ticket_price = ''
        number_of_trips = ''
        trip_time = ''
        frequency = ''

        # Duyệt qua các hàng trong table
        rows = table.find('tbody').find_all('tr')
        for tr in rows:
            tds = tr.find_all('td')
            if len(tds) < 2:
                continue

            label_td = tds[0].get_text(strip=True)
            content = tds[1].get_text(separator='\n').strip()

            # Xử lý Đơn vị đảm nhận (có thể ở hàng riêng)
            if 'Đơn vị đảm nhận' in label_td:
                operator = content

            # Bỏ qua hàng spacing
            if not label_td and not content:
                continue

            # Xử lý ul lists ở hàng cuối (cột 2 và 3)
            if len(tds) >= 3 and not label_td:  # Hàng có ul lists
                left_ul = tds[1].find('ul')
                right_ul = tds[2].find('ul') if len(tds) > 2 else None

                if left_ul:
                    left_items = [li.get_text(strip=True) for li in left_ul.find_all('li')]
                    for item in left_items:
                        if 'Loại hình hoạt động' in item:
                            operating_type = item.replace('Loại hình hoạt động:', '').strip()
                        elif 'Cự ly' in item:
                            distance = item.replace('Cự ly:', '').strip()
                        elif 'Loại xe' in item:
                            vehicle_type = item.replace('Loại xe:', '').strip()
                        elif 'Thời gian hoạt động' in item:
                            operating_hours = item.replace('Thời gian hoạt động:', '').strip()

                if right_ul:
                    right_items = [li.get_text(separator='\n').strip() for li in right_ul.find_all('li')]
                    for item in right_items:
                        if 'Giá vé' in item:
                            ticket_price = item.replace('Giá vé:', '').strip()
                        elif 'Số chuyến' in item:
                            number_of_trips = item.replace('Số chuyến:', '').strip()
                        elif 'Thời gian chuyến' in item:
                            trip_time = item.replace('Thời gian chuyến:', '').strip()
                        elif 'Giãn cách chuyến' in item:
                            frequency = item.replace('Giãn cách chuyến:', '').strip()

        # Thêm vào danh sách
        extended_data.append({
            'Route_Number': route_number,
            'Route_Name': route_name,
            'URL': url,
            'Operator': operator,
            'Operating_Type': operating_type,
            'Distance': distance,
            'Vehicle_Type': vehicle_type,
            'Operating_Hours': operating_hours,
            'Ticket_Price': ticket_price,
            'Number_of_Trips': number_of_trips,
            'Trip_Time': trip_time,
            'Frequency': frequency
        })

    except Exception as e:
        print(f"Lỗi khi scrape tuyến {route_number}: {e}")
        # Vẫn thêm dữ liệu với giá trị rỗng
        extended_data.append({
            'Route_Number': route_number,
            'Route_Name': route_name,
            'URL': url,
            'Operator': '',
            'Operating_Type': '',
            'Distance': '',
            'Vehicle_Type': '',
            'Operating_Hours': '',
            'Ticket_Price': '',
            'Number_of_Trips': '',
            'Trip_Time': '',
            'Frequency': ''
        })

    # Delay để tránh overload server
    time.sleep(1)

# Tạo DataFrame và lưu vào CSV mới
extended_df = pd.DataFrame(extended_data)
output_filename = 'tuyen_xe_buyt_detailed.csv'
extended_df.to_csv(output_filename, index=False, encoding='utf-8')

print(f'Dữ liệu chi tiết đã được lưu vào file {output_filename}. Tổng số tuyến: {len(extended_data)}')

# Hiển thị DataFrame (comment nếu không cần)
extended_df.head()
# Out:
# Đang scrape tuyến 01: Bến Thành- BX Chợ Lớn
# Đang scrape tuyến 02: Bến Thành- BX Miền Tây
# Đang scrape tuyến 03: Bến Thành- Thạnh Lộc
# Đang scrape tuyến 04: Bến Thành- Cộng Hòa- An Sương
# Đang scrape tuyến 05: Bến xe Chợ Lớn - Biên Hòa
# Đang scrape tuyến 06: Bến xe Chợ Lớn- Đại học Nông Lâm
# Đang scrape tuyến 07: Bến xe Chợ Lớn- Gò vấp
# Đang scrape tuyến 08: Bến xe Quận 8- Đại học Quốc Gia
# Đang scrape tuyến 09: Chợ Lớn - Bình Chánh - Hưng Long
# Đang scrape tuyến 10: Đại học Quốc Gia- Bến xe Miền Tây
# Đang scrape tuyến 11: Bến Thành- Đầm Sen
# Đang scrape tuyến 12: Bến Thành - Thác Giang Điền
# Đang scrape tuyến 13: Bến Thành- Bến xe Củ Chi
# Đang scrape tuyến 14: Miền Đông- 3 tháng 2- Miền Tây
# Đang scrape tuyến 15: Bến Phú Định- Đầm Sen
# Đang scrape tuyến 16: Bến xe Chợ Lớn - Bến xe Tân Phú
# Đang scrape tuyến 17: Bến Xe Chợ Lớn - ĐH Sài Gòn - KCX Tân Thuận
# Đang scrape tuyến 18: Bến Thành - Chợ Hiệp Thành
# Đang scrape tuyến 19: Bến Thành - Khu Chế Xuất Linh Trung - Đại Học Quốc Gia
# Đang scrape tuyến 20: Bến Thành - Nhà Bè
# Đang scrape tuyến 22: Bến Xe Quận 8 - KCN Lê Minh Xuân
# Đang scrape tuyến 23: Bến xe Chợ Lớn - Ngã 3 Giồng - Cầu Lớn
# Đang scrape tuyến 24: Bến Xe Miền Đông - Hóc Môn
# Đang scrape tuyến 25: Bến Xe Quận 8 - Khu Dân Cư Vĩnh Lộc A
# Đang scrape tuyến 27: Bến Thành - Âu Cơ - An Sương
# Đang scrape tuyến 28: Bến Thành - Chợ Xuân Thới Thượng
# Đang scrape tuyến 29: Bến Phà Cát Lái - Chợ Nông Sản Thủ Đức
# Đang scrape tuyến 30: Chợ Tân Hương - Đại học Quốc tế
# Đang scrape tuyến 31: Khu dân cư Tân Quy - Bến Thành - Khu dân cư Bình Lợi
# Đang scrape tuyến 32: Bến Xe Miền Tây - Bến Xe Ngã Tư Ga
# Đang scrape tuyến 33: Bến Xe An Sương - Suối Tiên - Đại học Quốc Gia
# Đang scrape tuyến 34: Bến Thành - Đại Học Công Nghệ Sài Gòn
# Đang scrape tuyến 35: Tuyến xe buýt Quận 1 - Quận 2
# Đang scrape tuyến 36: Bến Thành - Thới An
# Đang scrape tuyến 37: Cảng Quận 4 - Nhơn Đức
# Đang scrape tuyến 38: KDC Tân Quy - Đầm Sen
# Đang scrape tuyến 39: Bến Thành - Võ Văn Kiệt - Bến Xe Miền Tây
# Đang scrape tuyến 40: Bến xe Miền Đông- Bến xe Ngã Tư Ga
# Đang scrape tuyến 41: Bến xe Miền Tây- Ngã tư Bốn xã- Bến xe An Sương
# Đang scrape tuyến 42: Chợ Cầu Muối-Chợ nông sản Thủ Đức
# Đang scrape tuyến 43: Bến xe Miền Đông- Phà Cát Lái
# Đang scrape tuyến 44: Cảng Quận 4- Bình Quới
# Đang scrape tuyến 45: Bến xe Quận 8- Bến Thành- Bến xe Miền Đông
# Đang scrape tuyến 46: Cảng Quận 4- Bến Thành- Bến Mễ Cốc
# Đang scrape tuyến 47: Bến xe Chợ Lớn - Quốc lộ 50 - Hưng Long
# Đang scrape tuyến 48: Bến xe Tân Phú - Chợ Hiệp Thành
# Đang scrape tuyến 50: Đại học Bách khoa - Đại học Quốc gia
# Đang scrape tuyến 51: Bến xe Miền Đông - Bình Hưng Hòa
# Đang scrape tuyến 52: Bến Thành - Đại học Quốc tế
# Đang scrape tuyến 53: Lê Hồng Phong - Đại học Quốc gia
# Đang scrape tuyến 54: Bến xe Miền Đông - Bến xe Chợ Lớn
# Đang scrape tuyến 55: Công viên phần mềm Quang Trung - Khu Công nghệ cao (Q9)
# Đang scrape tuyến 56: Bến xe Chợ Lớn - Đại học Giao thông Vận tải
# Đang scrape tuyến 57: Chợ Phước Bình - Trường THPT Hiệp Bình
# Đang scrape tuyến 58: Bến xe Ngã 4 Ga - Khu Công nghiệp Đông Nam
# Đang scrape tuyến 59: Bến xe Quận 8 - Bến xe Ngã 4 Ga
# Đang scrape tuyến 60: Bến xe An Sương - KCN Lê Minh Xuân
# Đang scrape tuyến 60-1: BX Miền Tây - BX Biên Hòa
# Đang scrape tuyến 60-3: Bến xe Miền Đông - Khu Công nghiệp Nhơn Trạch
# Đang scrape tuyến 60-4: Bến xe Miền Đông - Bến xe Hố Nai
# Đang scrape tuyến 61: Bến xe Chợ Lớn - KCN Lê Minh Xuân
# Đang scrape tuyến 61-1: Thủ Đức - Dĩ An
# Đang scrape tuyến 61-3: Bến xe An Sương - Thủ Dầu Một
# Đang scrape tuyến 61-4: Bến Dược - Dầu Tiếng
# Đang scrape tuyến 61-6: Bến Thành - Khu Du lịch Đại Nam
# Đang scrape tuyến 61-7: Bến đò Bình Mỹ - Bến xe Bình Dương
# Đang scrape tuyến 61-8: Bến xe Miền Tây - Khu Du lịch Đại Nam
# Đang scrape tuyến 62: Bến xe Quận 8 -Thới An
# Đang scrape tuyến 62-1: Chợ Lớn- Bến Lức
# Đang scrape tuyến 62-2: Bến xe Chợ Lớn - Ngã 3 Tân Lân
# Đang scrape tuyến 62-3: Bến Củ Chi - Bến xe Hậu Nghĩa
# Đang scrape tuyến 62-4: Thị trấn Tân Túc - Chợ Bến Lức
# Đang scrape tuyến 62-5: Bến xe An Sương - Bến xe Hậu Nghĩa
# Đang scrape tuyến 62-7: Bến xe Chợ Lớn - Bến xe Đức Huệ
# Đang scrape tuyến 62-8: Bến xe Chợ Lớn - Bến xe Tân An
# Đang scrape tuyến 62-9: Bến xe Quận 8 - Cầu Nổi
# Đang scrape tuyến 62-10: Bến xe Chợ Lớn - Thanh Vĩnh Đông
# Đang scrape tuyến 62-11: Bến xe Miền Tây - Tân Tập
# Đang scrape tuyến 64: Bến xe Miền Đông - Đầm Sen
# Đang scrape tuyến 65: Bến Thành - CMT8 - Bến xe An Sương
# Đang scrape tuyến 66: Bến xe Chợ Lớn - Bến xe An Sương
# Đang scrape tuyến 68: Bến xe Chợ Lớn - KCX Tân Thuận
# Đang scrape tuyến 69: Công viên 23/9 - KCN Tân Bình
# Đang scrape tuyến 70: Tân Quy - Bến Súc
# Đang scrape tuyến 70-1: Bến xe Củ Chi - Bến xe Gò Dầu
# Đang scrape tuyến 70-2: BX Củ Chi - Hòa Thành
# Đang scrape tuyến 70-3: Bến Thành - Mộc Bài
# Đang scrape tuyến 70-5: Bố Heo - Lộc Hưng
# Đang scrape tuyến 71: Bến xe An Sương - Phật Cô Đơn
# Đang scrape tuyến 72: Công viên 23/9 - Hiệp Phước
# Đang scrape tuyến 73: Chợ Bình Chánh - KCN Lê Minh Xuân
# Đang scrape tuyến 74: Bến xe An Sương - Bến xe Củ Chi
# Đang scrape tuyến 75: Sài Gòn - Cần Giờ
# Đang scrape tuyến 76: Long Phước - Suối Tiên - Đền Vua Hùng
# Đang scrape tuyến 77: Đồng Hòa - Cần Thạnh
# Đang scrape tuyến 78: Thới An - Hóc Môn
# Đang scrape tuyến 79: Bến xe Củ Chi - Đền Bến Dược
# Đang scrape tuyến 81: Bến xe Chợ Lớn - Lê Minh Xuân
# Đang scrape tuyến 83: Bến xe Củ Chi - Cầu Thầy Cai
# Đang scrape tuyến 84: Bến xe Chợ Lớn - Tân Túc
# Đang scrape tuyến 85: Bến xe An Sương- Hậu Nghĩa
# Đang scrape tuyến 86: Bến Thành - Đại học Tôn Đức Thắng
# Đang scrape tuyến 87: Bến xe Củ Chi - An Nhơn Tây
# Đang scrape tuyến 88: Bến Thành - Chợ Long Phước
# Đang scrape tuyến 89: Đại học Nông Lâm - Trường THPT Hiệp Bình
# Đang scrape tuyến 90: Phà Bình Khánh - Cần Thạnh
# Đang scrape tuyến 91: Bến xe Miền Tây - Chợ nông sản Thủ Đức
# Đang scrape tuyến 93: Bến Thành - Đại học Nông Lâm
# Đang scrape tuyến 94: Bến xe Chợ Lớn - Bến xe Củ Chi
# Đang scrape tuyến 95: Bến xe Miền Đông - KCN Tân Bình
# Đang scrape tuyến 96: Bến Thành - Chợ Bình Điền
# Đang scrape tuyến 99: Chợ Thạnh Mỹ Lợi - Đại học Quốc gia
# Đang scrape tuyến 100: Bến xe Củ Chi - Cầu Tân Thái
# Đang scrape tuyến 101: Bến xe Chợ Lớn - Chợ Tân Nhựt
# Đang scrape tuyến 102: Bến Thành - Nguyễn Văn Linh - Bến xe Miền Tây
# Đang scrape tuyến 103: Bến xe Chợ Lớn - Bến xe Ngã 4 Ga
# Đang scrape tuyến 104: Bến xe An Sương - Đại học Nông Lâm
# Đang scrape tuyến 107: Bến xe Củ Chi - Bố Heo
# Đang scrape tuyến 109: Công viên 23/9 - Sân bay Tân Sơn Nhất
# Đang scrape tuyến 110: Phú Xuân - Hiệp Phước
# Đang scrape tuyến 119: Sân bay Tân Sơn Nhất - Bến xe Miền Tây
# Đang scrape tuyến 120: Tuyến xe buýt vòng khu vực trung tâm
# Đang scrape tuyến 122: Bến xe An Sương - Tân Quy
# Đang scrape tuyến 123: Phú Mỹ Hưng (khu H) - Quận 1
# Đang scrape tuyến 124: Phú Mỹ Hưng (khu S) - Quận 1
# Đang scrape tuyến 126: Bến xe Củ Chi - Bình Mỹ
# Đang scrape tuyến 127: An Thới Đông - Ngã ba Bà Xán
# Đang scrape tuyến 128: Tân Điền - An Nghĩa
# Đang scrape tuyến 139: Bến xe Miền Tây - Phú Xuân
# Đang scrape tuyến 140: Công viên 23/9 - Phạm Thế Hiển - Ba Tơ
# Đang scrape tuyến 141: KDL BCR - Long Trường - KCX Linh Trung 2
# Đang scrape tuyến 144: Bến xe Miền Tây - Chợ Lớn - CV Đầm Sen - CX Nhiêu Lộc
# Đang scrape tuyến 145: Bến xe Chợ Lớn - Chợ Hiệp Thành
# Đang scrape tuyến 146: Bến xe Miền Đông - Chợ Hiệp Thành
# Đang scrape tuyến 148: Bến xe Miền Tây - Gò Vấp
# Đang scrape tuyến 149: Công viên 23/9 - Khu dân cư Bình Hưng Hòa
# Đang scrape tuyến 150: Bến xe Chợ Lớn - Ngã 3 Tân Vạn
# Đang scrape tuyến 151: Bến xe Miền Tây - Bến xe An Sương
# Đang scrape tuyến 152: Khu dân cư Trung Sơn - Bến Thành - Sân bay Tân Sơn Nhất
# Đang scrape tuyến C010: Phổ Quang - KCN Hiệp Phước
# Dữ liệu chi tiết đã được lưu vào file tuyen_xe_buyt_detailed.csv. Tổng số tuyến: 140
#   Route_Number                     Route_Name  \
# 0           01          Bến Thành- BX Chợ Lớn
# 1           02         Bến Thành- BX Miền Tây
# 2           03           Bến Thành- Thạnh Lộc
# 3           04  Bến Thành- Cộng Hòa- An Sương
# 4           05      Bến xe Chợ Lớn - Biên Hòa
#
#                                                    URL  \
# 0     https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 1    https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html
# 2          https://xebuyt.net/ben-thanh-thanh-loc.html
# 3  https://xebuyt.net/ben-thanh-cong-hoa-an-suong.html
# 4      https://xebuyt.net/ben-xe-cho-lon-bien-hoa.html
#
#                                                                                                                                                    Operator  \
# 0                                                                                                     Công ty Cổ phần Xe khách Sài Gòn, ĐT: (08) 38.441.224
# 1                                                                                                Công ty TNHH Vận tải Ngôi sao Sài Gòn, ĐT: (08) 38.642.764
# 2                                                  Công ty TNHH Vận tải Ngôi sao Sài Gòn, ĐT: (08) 38.642.764\nHợp tác xã vận tải 19/5, ĐT: (08) 37.130.711
# 3                                                  Công ty TNHH Vận tải Ngôi sao Sài Gòn, ĐT: (08) 38.642.764\nHợp tác xã vận tải 19/5, ĐT: (08) 37.130.711
# 4  Hợp tác xã vận tải xe buýt Quyết Thắng, ĐT: (08) 38.642.712\nHợp tác xã vận tải 19/5, ĐT: (08) 37.130.711\nHợp tác xã vận tải số 15, ĐT: (08) 62.820.071
#
#               Operating_Type  Distance  Vehicle_Type Operating_Hours  \
# 0     Phổ thông - Có trợ giá    8.6 km       80 chỗ   05:00 - 20:30
# 1     Phổ thông - Có trợ giá  13.65 km  30 - 80 chỗ   04:45 - 18:30
# 2     Phổ thông - Có trợ giá  18.05 km  26 - 55 chỗ   04:15 - 20:45
# 3     Phổ thông - Có trợ giá   16.6 km  30 - 55 chỗ   05:00 - 20:30
# 4  Phổ thông - Không trợ giá     38 km  30 - 80 chỗ   04:50 - 17:50
#
#                                                                                       Ticket_Price  \
# 0  &nbsp- Vé lượt: 5,000 VNĐ\n     &nbsp- Vé lượt HSSV: 2,000 VNĐ\n     &nbsp- Vé tập: 112,500 VNĐ
# 1  &nbsp- Vé lượt: 5,000 VNĐ\n     &nbsp- Vé lượt HSSV: 2,000 VNĐ\n     &nbsp- Vé tập: 112,500 VNĐ
# 2  &nbsp- Vé lượt: 6,000 VNĐ\n     &nbsp- Vé lượt HSSV: 2,000 VNĐ\n     &nbsp- Vé tập: 135,000 VNĐ
# 3  &nbsp- Vé lượt: 5,000 VNĐ\n     &nbsp- Vé lượt HSSV: 2,000 VNĐ\n     &nbsp- Vé tập: 112,500 VNĐ
# 4
#
#      Number_of_Trips      Trip_Time      Frequency
# 0  240 chuyến/ngày  30 - 35 phút   6 - 10 phút
# 1  180 chuyến/ngày  45 - 50 phút   8 - 12 phút
# 2  312 chuyến/ngày  55 - 65 phút   4 - 12 phút
# 3  303 chuyến/ngày  50 - 65 phút   5 - 10 phút
# 4   72 chuyến/ngày  60 - 95 phút  20 - 25 phút

# %% [markdown]
# # Lấy lộ trình

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re

# Đọc file CSV đã tạo trước đó
csv_filename = 'tuyen_xe_buyt.csv'
df = pd.read_csv(csv_filename)

# Danh sách để lưu dữ liệu lộ trình (mỗi stop là một row)
route_stops_data = []

# Duyệt qua từng hàng trong DataFrame
for index, row in df.iterrows():
    route_number = row['Route_Number']
    route_name = row['Route_Name']
    url = row['URL']

    print(f"Đang scrape lộ trình tuyến {route_number}: {route_name}")

    try:
        # Gửi request
        response = requests.get(url)
        response.raise_for_status()

        # Parse HTML
        soup = BeautifulSoup(response.content, 'html.parser')

        # Tìm div lotrinh
        lotrinh_div = soup.find('div', id='lotrinh')
        if not lotrinh_div:
            print(f"Không tìm thấy div#lotrinh cho tuyến {route_number}")
            continue

        # Tìm tất cả accordion headers và contents
        accordion = lotrinh_div.find('div', id='accordion')
        if not accordion:
            print(f"Không tìm thấy accordion cho tuyến {route_number}")
            continue

        # Tìm tất cả h3 (headers cho hướng)
        headers = accordion.find_all('h3', class_='ui-accordion-header')

        for header in headers:
            # Lấy tên hướng (direction)
            direction = header.get_text(strip=True)

            # Tìm div content tương ứng (thường là sibling next div)
            content_div = header.find_next_sibling('div', class_='ui-accordion-content')
            if not content_div:
                continue

            # Tìm table trong content
            table = content_div.find('table')
            if not table:
                continue

            # Tìm tất cả rows trong tbody
            rows = table.find('tbody').find_all('tr', class_='rowStop')

            # Duyệt qua từng stop
            for row in rows:
                tds = row.find_all('td')
                if len(tds) < 2:
                    continue

                # Lấy thứ tự stop (A, 1, 2, ..., B)
                order_no_td = tds[0].find('div')
                stop_order = order_no_td.get_text(strip=True) if order_no_td else ''

                # Lấy tên stop
                stop_name_td = tds[1]
                stop_name = stop_name_td.get_text(strip=True)

                # Thêm vào danh sách
                route_stops_data.append({
                    'Route_Number': route_number,
                    'Route_Name': route_name,
                    'URL': url,
                    'Direction': direction,
                    'Stop_Order': stop_order,
                    'Stop_Name': stop_name
                })

    except Exception as e:
        print(f"Lỗi khi scrape lộ trình tuyến {route_number}: {e}")

    # Delay để tránh overload server
    time.sleep(1)

# Tạo DataFrame và lưu vào CSV mới
route_stops_df = pd.DataFrame(route_stops_data)
output_filename = 'tuyen_xe_buyt_lotrinh.csv'
route_stops_df.to_csv(output_filename, index=False, encoding='utf-8')

print(f'Dữ liệu lộ trình đã được lưu vào file {output_filename}. Tổng số stops: {len(route_stops_data)}')

# Hiển thị DataFrame (comment nếu không cần)
route_stops_df.head(10)
# Out:
# Đang scrape lộ trình tuyến 01: Bến Thành- BX Chợ Lớn
# Đang scrape lộ trình tuyến 02: Bến Thành- BX Miền Tây
# Đang scrape lộ trình tuyến 03: Bến Thành- Thạnh Lộc
# Đang scrape lộ trình tuyến 04: Bến Thành- Cộng Hòa- An Sương
# Đang scrape lộ trình tuyến 05: Bến xe Chợ Lớn - Biên Hòa
# Đang scrape lộ trình tuyến 06: Bến xe Chợ Lớn- Đại học Nông Lâm
# Đang scrape lộ trình tuyến 07: Bến xe Chợ Lớn- Gò vấp
# Đang scrape lộ trình tuyến 08: Bến xe Quận 8- Đại học Quốc Gia
# Đang scrape lộ trình tuyến 09: Chợ Lớn - Bình Chánh - Hưng Long
# Đang scrape lộ trình tuyến 10: Đại học Quốc Gia- Bến xe Miền Tây
# Đang scrape lộ trình tuyến 11: Bến Thành- Đầm Sen
# Đang scrape lộ trình tuyến 12: Bến Thành - Thác Giang Điền
# Đang scrape lộ trình tuyến 13: Bến Thành- Bến xe Củ Chi
# Đang scrape lộ trình tuyến 14: Miền Đông- 3 tháng 2- Miền Tây
# Đang scrape lộ trình tuyến 15: Bến Phú Định- Đầm Sen
# Đang scrape lộ trình tuyến 16: Bến xe Chợ Lớn - Bến xe Tân Phú
# Đang scrape lộ trình tuyến 17: Bến Xe Chợ Lớn - ĐH Sài Gòn - KCX Tân Thuận
# Đang scrape lộ trình tuyến 18: Bến Thành - Chợ Hiệp Thành
# Đang scrape lộ trình tuyến 19: Bến Thành - Khu Chế Xuất Linh Trung - Đại Học Quốc Gia
# Đang scrape lộ trình tuyến 20: Bến Thành - Nhà Bè
# Đang scrape lộ trình tuyến 22: Bến Xe Quận 8 - KCN Lê Minh Xuân
# Đang scrape lộ trình tuyến 23: Bến xe Chợ Lớn - Ngã 3 Giồng - Cầu Lớn
# Đang scrape lộ trình tuyến 24: Bến Xe Miền Đông - Hóc Môn
# Đang scrape lộ trình tuyến 25: Bến Xe Quận 8 - Khu Dân Cư Vĩnh Lộc A
# Đang scrape lộ trình tuyến 27: Bến Thành - Âu Cơ - An Sương
# Đang scrape lộ trình tuyến 28: Bến Thành - Chợ Xuân Thới Thượng
# Đang scrape lộ trình tuyến 29: Bến Phà Cát Lái - Chợ Nông Sản Thủ Đức
# Đang scrape lộ trình tuyến 30: Chợ Tân Hương - Đại học Quốc tế
# Đang scrape lộ trình tuyến 31: Khu dân cư Tân Quy - Bến Thành - Khu dân cư Bình Lợi
# Đang scrape lộ trình tuyến 32: Bến Xe Miền Tây - Bến Xe Ngã Tư Ga
# Đang scrape lộ trình tuyến 33: Bến Xe An Sương - Suối Tiên - Đại học Quốc Gia
# Đang scrape lộ trình tuyến 34: Bến Thành - Đại Học Công Nghệ Sài Gòn
# Đang scrape lộ trình tuyến 35: Tuyến xe buýt Quận 1 - Quận 2
# Đang scrape lộ trình tuyến 36: Bến Thành - Thới An
# Đang scrape lộ trình tuyến 37: Cảng Quận 4 - Nhơn Đức
# Đang scrape lộ trình tuyến 38: KDC Tân Quy - Đầm Sen
# Đang scrape lộ trình tuyến 39: Bến Thành - Võ Văn Kiệt - Bến Xe Miền Tây
# Đang scrape lộ trình tuyến 40: Bến xe Miền Đông- Bến xe Ngã Tư Ga
# Đang scrape lộ trình tuyến 41: Bến xe Miền Tây- Ngã tư Bốn xã- Bến xe An Sương
# Đang scrape lộ trình tuyến 42: Chợ Cầu Muối-Chợ nông sản Thủ Đức
# Đang scrape lộ trình tuyến 43: Bến xe Miền Đông- Phà Cát Lái
# Đang scrape lộ trình tuyến 44: Cảng Quận 4- Bình Quới
# Đang scrape lộ trình tuyến 45: Bến xe Quận 8- Bến Thành- Bến xe Miền Đông
# Đang scrape lộ trình tuyến 46: Cảng Quận 4- Bến Thành- Bến Mễ Cốc
# Đang scrape lộ trình tuyến 47: Bến xe Chợ Lớn - Quốc lộ 50 - Hưng Long
# Đang scrape lộ trình tuyến 48: Bến xe Tân Phú - Chợ Hiệp Thành
# Đang scrape lộ trình tuyến 50: Đại học Bách khoa - Đại học Quốc gia
# Đang scrape lộ trình tuyến 51: Bến xe Miền Đông - Bình Hưng Hòa
# Đang scrape lộ trình tuyến 52: Bến Thành - Đại học Quốc tế
# Đang scrape lộ trình tuyến 53: Lê Hồng Phong - Đại học Quốc gia
# Đang scrape lộ trình tuyến 54: Bến xe Miền Đông - Bến xe Chợ Lớn
# Đang scrape lộ trình tuyến 55: Công viên phần mềm Quang Trung - Khu Công nghệ cao (Q9)
# Đang scrape lộ trình tuyến 56: Bến xe Chợ Lớn - Đại học Giao thông Vận tải
# Đang scrape lộ trình tuyến 57: Chợ Phước Bình - Trường THPT Hiệp Bình
# Đang scrape lộ trình tuyến 58: Bến xe Ngã 4 Ga - Khu Công nghiệp Đông Nam
# Đang scrape lộ trình tuyến 59: Bến xe Quận 8 - Bến xe Ngã 4 Ga
# Đang scrape lộ trình tuyến 60: Bến xe An Sương - KCN Lê Minh Xuân
# Đang scrape lộ trình tuyến 60-1: BX Miền Tây - BX Biên Hòa
# Đang scrape lộ trình tuyến 60-3: Bến xe Miền Đông - Khu Công nghiệp Nhơn Trạch
# Đang scrape lộ trình tuyến 60-4: Bến xe Miền Đông - Bến xe Hố Nai
# Đang scrape lộ trình tuyến 61: Bến xe Chợ Lớn - KCN Lê Minh Xuân
# Đang scrape lộ trình tuyến 61-1: Thủ Đức - Dĩ An
# Đang scrape lộ trình tuyến 61-3: Bến xe An Sương - Thủ Dầu Một
# Đang scrape lộ trình tuyến 61-4: Bến Dược - Dầu Tiếng
# Đang scrape lộ trình tuyến 61-6: Bến Thành - Khu Du lịch Đại Nam
# Đang scrape lộ trình tuyến 61-7: Bến đò Bình Mỹ - Bến xe Bình Dương
# Đang scrape lộ trình tuyến 61-8: Bến xe Miền Tây - Khu Du lịch Đại Nam
# Đang scrape lộ trình tuyến 62: Bến xe Quận 8 -Thới An
# Đang scrape lộ trình tuyến 62-1: Chợ Lớn- Bến Lức
# Đang scrape lộ trình tuyến 62-2: Bến xe Chợ Lớn - Ngã 3 Tân Lân
# Đang scrape lộ trình tuyến 62-3: Bến Củ Chi - Bến xe Hậu Nghĩa
# Đang scrape lộ trình tuyến 62-4: Thị trấn Tân Túc - Chợ Bến Lức
# Đang scrape lộ trình tuyến 62-5: Bến xe An Sương - Bến xe Hậu Nghĩa
# Đang scrape lộ trình tuyến 62-7: Bến xe Chợ Lớn - Bến xe Đức Huệ
# Đang scrape lộ trình tuyến 62-8: Bến xe Chợ Lớn - Bến xe Tân An
# Đang scrape lộ trình tuyến 62-9: Bến xe Quận 8 - Cầu Nổi
# Đang scrape lộ trình tuyến 62-10: Bến xe Chợ Lớn - Thanh Vĩnh Đông
# Đang scrape lộ trình tuyến 62-11: Bến xe Miền Tây - Tân Tập
# Đang scrape lộ trình tuyến 64: Bến xe Miền Đông - Đầm Sen
# Đang scrape lộ trình tuyến 65: Bến Thành - CMT8 - Bến xe An Sương
# Đang scrape lộ trình tuyến 66: Bến xe Chợ Lớn - Bến xe An Sương
# Đang scrape lộ trình tuyến 68: Bến xe Chợ Lớn - KCX Tân Thuận
# Đang scrape lộ trình tuyến 69: Công viên 23/9 - KCN Tân Bình
# Đang scrape lộ trình tuyến 70: Tân Quy - Bến Súc
# Đang scrape lộ trình tuyến 70-1: Bến xe Củ Chi - Bến xe Gò Dầu
# Đang scrape lộ trình tuyến 70-2: BX Củ Chi - Hòa Thành
# Đang scrape lộ trình tuyến 70-3: Bến Thành - Mộc Bài
# Đang scrape lộ trình tuyến 70-5: Bố Heo - Lộc Hưng
# Đang scrape lộ trình tuyến 71: Bến xe An Sương - Phật Cô Đơn
# Đang scrape lộ trình tuyến 72: Công viên 23/9 - Hiệp Phước
# Đang scrape lộ trình tuyến 73: Chợ Bình Chánh - KCN Lê Minh Xuân
# Đang scrape lộ trình tuyến 74: Bến xe An Sương - Bến xe Củ Chi
# Đang scrape lộ trình tuyến 75: Sài Gòn - Cần Giờ
# Đang scrape lộ trình tuyến 76: Long Phước - Suối Tiên - Đền Vua Hùng
# Đang scrape lộ trình tuyến 77: Đồng Hòa - Cần Thạnh
# Đang scrape lộ trình tuyến 78: Thới An - Hóc Môn
# Đang scrape lộ trình tuyến 79: Bến xe Củ Chi - Đền Bến Dược
# Đang scrape lộ trình tuyến 81: Bến xe Chợ Lớn - Lê Minh Xuân
# Đang scrape lộ trình tuyến 83: Bến xe Củ Chi - Cầu Thầy Cai
# Đang scrape lộ trình tuyến 84: Bến xe Chợ Lớn - Tân Túc
# Đang scrape lộ trình tuyến 85: Bến xe An Sương- Hậu Nghĩa
# Đang scrape lộ trình tuyến 86: Bến Thành - Đại học Tôn Đức Thắng
# Đang scrape lộ trình tuyến 87: Bến xe Củ Chi - An Nhơn Tây
# Đang scrape lộ trình tuyến 88: Bến Thành - Chợ Long Phước
# Đang scrape lộ trình tuyến 89: Đại học Nông Lâm - Trường THPT Hiệp Bình
# Đang scrape lộ trình tuyến 90: Phà Bình Khánh - Cần Thạnh
# Đang scrape lộ trình tuyến 91: Bến xe Miền Tây - Chợ nông sản Thủ Đức
# Đang scrape lộ trình tuyến 93: Bến Thành - Đại học Nông Lâm
# Đang scrape lộ trình tuyến 94: Bến xe Chợ Lớn - Bến xe Củ Chi
# Đang scrape lộ trình tuyến 95: Bến xe Miền Đông - KCN Tân Bình
# Đang scrape lộ trình tuyến 96: Bến Thành - Chợ Bình Điền
# Đang scrape lộ trình tuyến 99: Chợ Thạnh Mỹ Lợi - Đại học Quốc gia
# Đang scrape lộ trình tuyến 100: Bến xe Củ Chi - Cầu Tân Thái
# Đang scrape lộ trình tuyến 101: Bến xe Chợ Lớn - Chợ Tân Nhựt
# Đang scrape lộ trình tuyến 102: Bến Thành - Nguyễn Văn Linh - Bến xe Miền Tây
# Đang scrape lộ trình tuyến 103: Bến xe Chợ Lớn - Bến xe Ngã 4 Ga
# Đang scrape lộ trình tuyến 104: Bến xe An Sương - Đại học Nông Lâm
# Đang scrape lộ trình tuyến 107: Bến xe Củ Chi - Bố Heo
# Đang scrape lộ trình tuyến 109: Công viên 23/9 - Sân bay Tân Sơn Nhất
# Đang scrape lộ trình tuyến 110: Phú Xuân - Hiệp Phước
# Đang scrape lộ trình tuyến 119: Sân bay Tân Sơn Nhất - Bến xe Miền Tây
# Đang scrape lộ trình tuyến 120: Tuyến xe buýt vòng khu vực trung tâm
# Đang scrape lộ trình tuyến 122: Bến xe An Sương - Tân Quy
# Đang scrape lộ trình tuyến 123: Phú Mỹ Hưng (khu H) - Quận 1
# Đang scrape lộ trình tuyến 124: Phú Mỹ Hưng (khu S) - Quận 1
# Đang scrape lộ trình tuyến 126: Bến xe Củ Chi - Bình Mỹ
# Đang scrape lộ trình tuyến 127: An Thới Đông - Ngã ba Bà Xán
# Đang scrape lộ trình tuyến 128: Tân Điền - An Nghĩa
# Đang scrape lộ trình tuyến 139: Bến xe Miền Tây - Phú Xuân
# Đang scrape lộ trình tuyến 140: Công viên 23/9 - Phạm Thế Hiển - Ba Tơ
# Đang scrape lộ trình tuyến 141: KDL BCR - Long Trường - KCX Linh Trung 2
# Đang scrape lộ trình tuyến 144: Bến xe Miền Tây - Chợ Lớn - CV Đầm Sen - CX Nhiêu Lộc
# Đang scrape lộ trình tuyến 145: Bến xe Chợ Lớn - Chợ Hiệp Thành
# Đang scrape lộ trình tuyến 146: Bến xe Miền Đông - Chợ Hiệp Thành
# Đang scrape lộ trình tuyến 148: Bến xe Miền Tây - Gò Vấp
# Đang scrape lộ trình tuyến 149: Công viên 23/9 - Khu dân cư Bình Hưng Hòa
# Đang scrape lộ trình tuyến 150: Bến xe Chợ Lớn - Ngã 3 Tân Vạn
# Đang scrape lộ trình tuyến 151: Bến xe Miền Tây - Bến xe An Sương
# Đang scrape lộ trình tuyến 152: Khu dân cư Trung Sơn - Bến Thành - Sân bay Tân Sơn Nhất
# Đang scrape lộ trình tuyến C010: Phổ Quang - KCN Hiệp Phước
# Dữ liệu lộ trình đã được lưu vào file tuyen_xe_buyt_lotrinh.csv. Tổng số stops: 0
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
from bs4 import BeautifulSoup
import html
import pandas as pd
import time
from pprint import pprint  # Để debug nếu cần

# Đọc file CSV đã tạo trước đó
csv_filename = 'tuyen_xe_buyt.csv'
try:
    df = pd.read_csv(csv_filename)
    print(f"Đã đọc thành công {len(df)} tuyến từ file {csv_filename}")
except FileNotFoundError:
    print(f"Không tìm thấy file {csv_filename}. Vui lòng chạy code scrape URL trước!")
    exit()

# Danh sách để lưu dữ liệu lộ trình (mỗi stop là một row)
route_stops_data = []

# Giới hạn số tuyến để test (bỏ comment nếu muốn scrape tất cả)
# df = df.head(5)  # Chỉ scrape 5 tuyến đầu để test

print(f"Bắt đầu scrape lộ trình cho {len(df)} tuyến...")

# Duyệt qua từng hàng trong DataFrame
for index, row in df.iterrows():
    route_number = row['Route_Number']
    route_name = row['Route_Name']
    url = row['URL']

    print(f"\n--- Đang scrape lộ trình tuyến {route_number}: {route_name} ---")
    print(f"URL: {url}")

    try:
        # Gửi yêu cầu HTTP để lấy nội dung trang web
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Kiểm tra lỗi HTTP

        # Giải mã HTML để xử lý các ký tự đặc biệt
        html_content = html.unescape(response.text)

        # Sử dụng BeautifulSoup để phân tích HTML
        soup = BeautifulSoup(html_content, 'html.parser')
        print(f"✅ Đã parse HTML thành công. Độ dài content: {len(response.text)}")

        # Khởi tạo danh sách stops cho tuyến này
        stops_data = []

        # Biến để xác định hướng hiện tại
        current_direction = None

        # Duyệt qua các element h3 và table theo thứ tự
        for element in soup.find_all(['h3', 'table']):
            if element.name == 'h3':
                # Cập nhật hướng dựa trên tiêu đề (tìm các pattern phổ biến như "Đi [Điểm cuối]")
                header_text = element.get_text(strip=True)
                if "Đi" in header_text:
                    # Lấy phần sau "Đi " làm tên hướng
                    direction_name = header_text.replace("Đi ", "").strip()
                    current_direction = direction_name
                    print(f"  ✅ Phát hiện hướng mới: {current_direction}")
                else:
                    current_direction = None
            elif element.name == 'table' and current_direction:
                # Tìm tất cả các hàng trong bảng
                rows = element.find_all('tr')
                stop_count = 0
                for row in rows:
                    cols = row.find_all('td')
                    if len(cols) >= 2:
                        # Lấy thứ tự stop (từ cột 1, thường là <div> với A/1/2/.../B)
                        order_col = cols[0].find('div')
                        stop_order = order_col.get_text(strip=True) if order_col else str(stop_count + 1)

                        # Lấy tên stop từ cột 2
                        stop_name = cols[1].get_text(strip=True)

                        if stop_name and stop_name != '':  # Bỏ qua stop rỗng
                            # Thêm vào danh sách
                            stops_data.append({
                                'Route_Number': route_number,
                                'Route_Name': route_name,
                                'URL': url,
                                'Direction': current_direction,
                                'Stop_Order': stop_order,
                                'Stop_Name': stop_name
                            })
                            stop_count += 1
                            if stop_count <= 3:  # Chỉ print 3 stops đầu mỗi hướng để tránh spam
                                print(f"    Stop {stop_order}: {stop_name}")
                            if stop_count == 4:
                                print(f"    ... (và {len(rows) - stop_count + 1} stops khác)")

                print(f"  ✅ Thu thập {stop_count} stops cho hướng '{current_direction}'")

        # Thêm stops của tuyến này vào danh sách tổng
        route_stops_data.extend(stops_data)
        total_stops_this_route = len(stops_data)
        print(f"✅ Hoàn thành tuyến {route_number}: {total_stops_this_route} stops tổng cộng")

        # Debug: In preview stops nếu cần (comment nếu không muốn)
        # pprint(stops_data, indent=2)

    except requests.exceptions.RequestException as e:
        print(f"❌ Lỗi HTTP cho tuyến {route_number}: {e}")
    except Exception as e:
        print(f"❌ Lỗi khi xử lý dữ liệu tuyến {route_number}: {e}")
        import traceback
        traceback.print_exc()  # In chi tiết lỗi để debug

    # Delay để tránh overload server
    # time.sleep(2)

print(f"\n--- Kết thúc scrape ---")
print(f"Tổng số stops thu thập được: {len(route_stops_data)}")

if len(route_stops_data) == 0:
    print("❌ Không có dữ liệu nào! Kiểm tra log trên để debug.")
    print("Có thể một số tuyến không có lộ trình, hoặc HTML thay đổi.")

# Tạo DataFrame và lưu vào CSV mới
if len(route_stops_data) > 0:
    route_stops_df = pd.DataFrame(route_stops_data)
    output_filename = 'tuyen_xe_buyt_lotrinh.csv'
    route_stops_df.to_csv(output_filename, index=False, encoding='utf-8')

    print(f"✅ Dữ liệu lộ trình đã được lưu vào file {output_filename}")

    # Hiển thị preview DataFrame (top 20 rows)
    print("\n--- Preview DataFrame (top 20 rows) ---")
    print(route_stops_df.head(20).to_string(index=False))

    # Thống kê nhanh
    print(f"\n--- Thống kê ---")
    print(f"- Tổng tuyến có dữ liệu: {route_stops_df['Route_Number'].nunique()}")
    print(f"- Hướng phổ biến nhất: {route_stops_df['Direction'].value_counts().head(1)}")
else:
    print("❌ Không lưu file vì không có dữ liệu.")
# Out:
# Đã đọc thành công 140 tuyến từ file tuyen_xe_buyt.csv
# Bắt đầu scrape lộ trình cho 140 tuyến...
#
# --- Đang scrape lộ trình tuyến 01: Bến Thành- BX Chợ Lớn ---
# URL: https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# ✅ Đã parse HTML thành công. Độ dài content: 52658
#   ✅ Phát hiện hướng mới: BX Chợ Lớn
#     Stop A: Công Trường Mê Linh
#     Stop 1: Bến Bạch Đằng
#     Stop 2: Cục Hải Quan Thành Phố
#     ... (và 26 stops khác)
#   ✅ Thu thập 29 stops cho hướng 'BX Chợ Lớn'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Bến xe Chợ Lớn
#     Stop 1: Chu Văn An
#     Stop 2: Tháp Mười
#     ... (và 32 stops khác)
#   ✅ Thu thập 35 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 05:35
#     Stop 2: 05:10 - 05:45
#     Stop 3: 05:20 - 05:55
#     ... (và 117 stops khác)
#   ✅ Thu thập 120 stops cho hướng 'BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 05:30
#     Stop 2: 05:10 - 05:40
#     Stop 3: 05:20 - 05:50
#     ... (và 117 stops khác)
#   ✅ Thu thập 120 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 01: 304 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 02: Bến Thành- BX Miền Tây ---
# URL: https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html
# ✅ Đã parse HTML thành công. Độ dài content: 52394
#   ✅ Phát hiện hướng mới: BX Miền Tây
#     Stop A: Công Trường Mê Linh
#     Stop 1: Bến Bạch Đằng
#     Stop 2: Cục Hải Quan Thành Phố
#     ... (và 40 stops khác)
#   ✅ Thu thập 43 stops cho hướng 'BX Miền Tây'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Bến xe Miền Tây
#     Stop 1: 49-51 (317), Kinh Dương Vương
#     Stop 2: Dương Tự Quản
#     ... (và 34 stops khác)
#   ✅ Thu thập 37 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: BX Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'BX Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:45 - 05:30
#     Stop 2: 04:57 - 05:42
#     Stop 3: 05:09 - 05:54
#     ... (và 87 stops khác)
#   ✅ Thu thập 90 stops cho hướng 'BX Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:45 - 05:30
#     Stop 2: 04:57 - 05:42
#     Stop 3: 05:09 - 05:54
#     ... (và 87 stops khác)
#   ✅ Thu thập 90 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 02: 260 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 03: Bến Thành- Thạnh Lộc ---
# URL: https://xebuyt.net/ben-thanh-thanh-loc.html
# ✅ Đã parse HTML thành công. Độ dài content: 67605
#   ✅ Phát hiện hướng mới: Thạnh Lộc
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Tôn Thất Tùng
#     Stop 2: Nguyễn Thị Nghĩa
#     ... (và 45 stops khác)
#   ✅ Thu thập 48 stops cho hướng 'Thạnh Lộc'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: THẠNH LỘC
#     Stop 1: Trường Điện Lực 2
#     Stop 2: Chợ Thạnh Xuân
#     ... (và 45 stops khác)
#   ✅ Thu thập 48 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: Thạnh Lộc(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Thạnh Lộc(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:55 - 05:50
#     Stop 2: 05:03 - 05:58
#     Stop 3: 05:11 - 06:06
#     ... (và 153 stops khác)
#   ✅ Thu thập 156 stops cho hướng 'Thạnh Lộc(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:15 - 05:10
#     Stop 2: 04:27 - 05:22
#     Stop 3: 04:37 - 05:32
#     ... (và 153 stops khác)
#   ✅ Thu thập 156 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 03: 408 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 04: Bến Thành- Cộng Hòa- An Sương ---
# URL: https://xebuyt.net/ben-thanh-cong-hoa-an-suong.html
# ✅ Đã parse HTML thành công. Độ dài content: 65800
#   ✅ Phát hiện hướng mới: An Sương
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Tôn Thất Tùng
#     Stop 2: Nguyễn Thị Nghĩa
#     ... (và 47 stops khác)
#   ✅ Thu thập 50 stops cho hướng 'An Sương'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Bến xe An Sương
#     Stop 1: Chợ Chiều
#     Stop 2: Bitis
#     ... (và 38 stops khác)
#   ✅ Thu thập 41 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:30 - 06:25
#     Stop 2: 05:38 - 06:33
#     Stop 3: 05:44 - 06:39
#     ... (và 147 stops khác)
#   ✅ Thu thập 150 stops cho hướng 'An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 05:50
#     Stop 2: 05:08 - 05:58
#     Stop 3: 05:16 - 06:06
#     ... (và 150 stops khác)
#   ✅ Thu thập 153 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 04: 394 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 05: Bến xe Chợ Lớn - Biên Hòa ---
# URL: https://xebuyt.net/ben-xe-cho-lon-bien-hoa.html
# ✅ Đã parse HTML thành công. Độ dài content: 56251
#   ✅ Phát hiện hướng mới: Biên Hòa
#     Stop A: Bến xe Chợ Lớn
#     Stop 1: Chu Văn An
#     Stop 2: Chợ Kim Biên
#     ... (và 56 stops khác)
#   ✅ Thu thập 59 stops cho hướng 'Biên Hòa'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn
#     Stop A: Big C
#     Stop 1: Chùa Từ Quang
#     Stop 2: Đường số 8
#     ... (và 65 stops khác)
#   ✅ Thu thập 68 stops cho hướng 'Bến xe Chợ Lớn'
#   ✅ Phát hiện hướng mới: Biên Hòa(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Biên Hòa(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:50 - 06:25
#     Stop 2: 05:10 - 06:45
#     Stop 3: 05:30 - 07:05
#     ... (và 33 stops khác)
#   ✅ Thu thập 36 stops cho hướng 'Biên Hòa(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:50 - 06:25
#     Stop 2: 05:10 - 06:45
#     Stop 3: 05:30 - 07:05
#     ... (và 33 stops khác)
#   ✅ Thu thập 36 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 05: 199 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 06: Bến xe Chợ Lớn- Đại học Nông Lâm ---
# URL: https://xebuyt.net/ben-xe-cho-lon-dai-hoc-nong-lam.html
# ✅ Đã parse HTML thành công. Độ dài content: 62110
#   ✅ Phát hiện hướng mới: Đại học Nông Lâm
#     Stop A: Bến xe Chợ Lớn
#     Stop 1: Bến xe Chợ Lớn
#     Stop 2: Thuận Kiều Plaza
#     ... (và 47 stops khác)
#   ✅ Thu thập 50 stops cho hướng 'Đại học Nông Lâm'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn
#     Stop A: Đại học Nông Lâm
#     Stop 1: ĐH Nông Lâm
#     Stop 2: Khu Công nghệ cao Q9
#     ... (và 57 stops khác)
#   ✅ Thu thập 60 stops cho hướng 'Bến xe Chợ Lớn'
#   ✅ Phát hiện hướng mới: Đại học Nông Lâm(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)
#   ✅ Thu thập 0 stops cho hướng 'Đại học Nông Lâm(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)'
#     Stop 1: 04:55 - 06:05
#     Stop 2: 05:15 - 06:25
#     Stop 3: 05:30 - 06:40
#     ... (và 92 stops khác)
#   ✅ Thu thập 95 stops cho hướng 'Đại học Nông Lâm(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)'
#     Stop 1: 04:55 - 06:05
#     Stop 2: 05:15 - 06:25
#     Stop 3: 05:30 - 06:40
#     ... (và 92 stops khác)
#   ✅ Thu thập 95 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)'
# ✅ Hoàn thành tuyến 06: 300 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 07: Bến xe Chợ Lớn- Gò vấp ---
# URL: https://xebuyt.net/ben-xe-cho-lon-go-vap.html
# ✅ Đã parse HTML thành công. Độ dài content: 57949
#   ✅ Phát hiện hướng mới: Gò vấp
#     Stop A: Bến xe Chợ Lớn
#     Stop 1: Chu Văn An
#     Stop 2: Tháp Mười
#     ... (và 43 stops khác)
#   ✅ Thu thập 46 stops cho hướng 'Gò vấp'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn
#     Stop A: BÃI HẬU CẦN SỐ 1
#     Stop 1: Bãi hậu cần số 1
#     Stop 2: UBND Phường 5, Quận Gò Vấp
#     ... (và 48 stops khác)
#   ✅ Thu thập 51 stops cho hướng 'Bến xe Chợ Lớn'
#   ✅ Phát hiện hướng mới: Gò vấp(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)
#   ✅ Thu thập 0 stops cho hướng 'Gò vấp(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#     Stop 1: 05:00 - 06:08
#     Stop 2: 05:15 - 06:23
#     Stop 3: 05:30 - 06:38
#     ... (và 72 stops khác)
#   ✅ Thu thập 75 stops cho hướng 'Gò vấp(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#     Stop 1: 05:00 - 06:08
#     Stop 2: 05:15 - 06:23
#     Stop 3: 05:30 - 06:38
#     ... (và 72 stops khác)
#   ✅ Thu thập 75 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
# ✅ Hoàn thành tuyến 07: 247 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 08: Bến xe Quận 8- Đại học Quốc Gia ---
# URL: https://xebuyt.net/ben-xe-quan-8-dai-hoc-quoc-gia.html
# ✅ Đã parse HTML thành công. Độ dài content: 80325
#   ✅ Phát hiện hướng mới: Đại học Quốc Gia
#     Stop A: Bến xe Quận 8
#     Stop 1: Bùi Minh Trực
#     Stop 2: Cầu Nhị Thiên Đường
#     ... (và 63 stops khác)
#   ✅ Thu thập 66 stops cho hướng 'Đại học Quốc Gia'
#   ✅ Phát hiện hướng mới: Bến xe Quận 8
#     Stop A: Đại học Quốc gia
#     Stop 1: 621-Ngã 3 Lâm Viên
#     Stop 2: Trường giáo dục Quốc phòng
#     ... (và 64 stops khác)
#   ✅ Thu thập 67 stops cho hướng 'Bến xe Quận 8'
#   ✅ Phát hiện hướng mới: Đại học Quốc Gia(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)
#   ✅ Thu thập 0 stops cho hướng 'Đại học Quốc Gia(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)'
#     Stop 1: 04:40 - 06:00
#     Stop 2: 04:50 - 06:10
#     Stop 3: 05:00 - 06:20
#     ... (và 157 stops khác)
#   ✅ Thu thập 160 stops cho hướng 'Đại học Quốc Gia(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)'
#   ✅ Phát hiện hướng mới: Bến xe Quận 8(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Quận 8(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)'
#     Stop 1: 04:40 - 06:00
#     Stop 2: 04:50 - 06:10
#     Stop 3: 05:00 - 06:20
#     ... (và 157 stops khác)
#   ✅ Thu thập 160 stops cho hướng 'Bến xe Quận 8(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)'
# ✅ Hoàn thành tuyến 08: 453 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 09: Chợ Lớn - Bình Chánh - Hưng Long ---
# URL: https://xebuyt.net/cho-lon-binh-chanh-hung-long.html
# ✅ Đã parse HTML thành công. Độ dài content: 65922
#   ✅ Phát hiện hướng mới: Hưng Long
#     Stop A: Bến xe Chợ Lớn
#     Stop 1: Trường Võ Văn Tần
#     Stop 2: Cây Mai
#     ... (và 55 stops khác)
#   ✅ Thu thập 58 stops cho hướng 'Hưng Long'
#   ✅ Phát hiện hướng mới: Chợ Lớn
#     Stop A: Hưng Long
#     Stop 1: Nguyễn Văn Long
#     Stop 2: Nguyễn Văn Thời
#     ... (và 56 stops khác)
#   ✅ Thu thập 59 stops cho hướng 'Chợ Lớn'
#   ✅ Phát hiện hướng mới: Hưng Long(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Hưng Long(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:25 - 06:35
#     Stop 2: 05:33 - 06:43
#     Stop 3: 05:41 - 06:51
#     ... (và 111 stops khác)
#   ✅ Thu thập 114 stops cho hướng 'Hưng Long(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:00 - 05:10
#     Stop 2: 04:08 - 05:18
#     Stop 3: 04:16 - 05:26
#     ... (và 111 stops khác)
#   ✅ Thu thập 114 stops cho hướng 'Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 09: 345 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 10: Đại học Quốc Gia- Bến xe Miền Tây ---
# URL: https://xebuyt.net/dai-hoc-quoc-gia-ben-xe-mien-tay.html
# ✅ Đã parse HTML thành công. Độ dài content: 36971
#   ✅ Phát hiện hướng mới: Bến xe Miền Tây
#     Stop A: Đại học Quốc gia
#     Stop 1: Trường giáo dục Quốc phòng
#     Stop 2: Khu DL Suối Tiên
#     ... (và 13 stops khác)
#   ✅ Thu thập 16 stops cho hướng 'Bến xe Miền Tây'
#   ✅ Phát hiện hướng mới: Đại học Quốc Gia
#     Stop A: Bến xe Miền Tây
#     Stop 1: Coop mart
#     Stop 2: Chu Văn An
#     ... (và 11 stops khác)
#   ✅ Thu thập 14 stops cho hướng 'Đại học Quốc Gia'
#   ✅ Phát hiện hướng mới: Bến xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:20
#     Stop 2: 05:15 - 06:35
#     Stop 3: 05:30 - 06:50
#     ... (và 58 stops khác)
#   ✅ Thu thập 61 stops cho hướng 'Bến xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Đại học Quốc Gia(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Đại học Quốc Gia(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:20
#     Stop 2: 05:12 - 06:32
#     Stop 3: 05:24 - 06:44
#     ... (và 58 stops khác)
#   ✅ Thu thập 61 stops cho hướng 'Đại học Quốc Gia(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 10: 152 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 11: Bến Thành- Đầm Sen ---
# URL: https://xebuyt.net/ben-thanh-dam-sen.html
# ✅ Đã parse HTML thành công. Độ dài content: 44226
#   ✅ Phát hiện hướng mới: Đầm Sen
#     Stop A: Đầu bến Hàm Nghi
#     Stop 1: Bến Thành C
#     Stop 2: Trường Ernst Thalmann
#     ... (và 26 stops khác)
#   ✅ Thu thập 29 stops cho hướng 'Đầm Sen'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: BÃI XE BUÝT ĐẦM SEN
#     Stop 1: Ngã 4 Hòa Bình
#     Stop 2: Tòa án nhân dân Q11
#     ... (và 25 stops khác)
#   ✅ Thu thập 28 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: Đầm Sen(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Đầm Sen(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:30 - 06:05
#     Stop 2: 05:42 - 06:17
#     Stop 3: 05:54 - 06:29
#     ... (và 67 stops khác)
#   ✅ Thu thập 70 stops cho hướng 'Đầm Sen(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:30 - 06:05
#     Stop 2: 05:42 - 06:17
#     Stop 3: 05:54 - 06:29
#     ... (và 67 stops khác)
#   ✅ Thu thập 70 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 11: 197 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 12: Bến Thành - Thác Giang Điền ---
# URL: https://xebuyt.net/ben-thanh-thac-giang-dien.html
# ✅ Đã parse HTML thành công. Độ dài content: 46298
#   ✅ Phát hiện hướng mới: Thác Giang Điền
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Tôn Thất Tùng
#     Stop 2: Nguyễn Thị Nghĩa
#     ... (và 41 stops khác)
#   ✅ Thu thập 44 stops cho hướng 'Thác Giang Điền'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Công ty TNHH Thuận Thành Tâm
#     Stop 1: Công ty Dosan
#     Stop 2: Công ty Cp Đức Khải
#     ... (và 39 stops khác)
#   ✅ Thu thập 42 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: Thác Giang Điền(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Thác Giang Điền(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 06:00 - 07:50
#     Stop 2: 06:20 - 08:10
#     Stop 3: 06:40 - 08:30
#     ... (và 27 stops khác)
#   ✅ Thu thập 30 stops cho hướng 'Thác Giang Điền(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:50
#     Stop 2: 05:20 - 07:10
#     Stop 3: 05:40 - 07:30
#     ... (và 27 stops khác)
#   ✅ Thu thập 30 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 12: 146 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 13: Bến Thành- Bến xe Củ Chi ---
# URL: https://xebuyt.net/ben-thanh-ben-xe-cu-chi.html
# ✅ Đã parse HTML thành công. Độ dài content: 44912
#   ✅ Phát hiện hướng mới: Bến xe Củ Chi
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Trống Đồng
#     Stop 2: Bệnh viện Mắt TPHCM
#     ... (và 23 stops khác)
#   ✅ Thu thập 26 stops cho hướng 'Bến xe Củ Chi'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Bến xe Củ Chi
#     Stop 1: Trường trung học cơ sở Củ Chi
#     Stop 2: Điện lực Củ Chi - Ngã 3 Việt Kiều
#     ... (và 24 stops khác)
#   ✅ Thu thập 27 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: Bến xe Củ Chi(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Củ Chi(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:30 - 05:45
#     Stop 2: 04:50 - 06:05
#     Stop 3: 05:10 - 06:25
#     ... (và 72 stops khác)
#   ✅ Thu thập 75 stops cho hướng 'Bến xe Củ Chi(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 03:30 - 04:45
#     Stop 2: 03:50 - 05:05
#     Stop 3: 04:10 - 05:25
#     ... (và 72 stops khác)
#   ✅ Thu thập 75 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 13: 203 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 14: Miền Đông- 3 tháng 2- Miền Tây ---
# URL: https://xebuyt.net/mien-dong-3-thang-2-mien-tay.html
# ✅ Đã parse HTML thành công. Độ dài content: 61651
#   ✅ Phát hiện hướng mới: Miền Tây
#     Stop A: Bến xe Miền Đông
#     Stop 1: Ngã năm Liệt Sĩ
#     Stop 2: Chợ Phường 25
#     ... (và 45 stops khác)
#   ✅ Thu thập 48 stops cho hướng 'Miền Tây'
#   ✅ Phát hiện hướng mới: Miền Đông
#     Stop A: Bến xe Miền Tây
#     Stop 1: 49-51 (317), Kinh Dương Vương
#     Stop 2: Dương Tự Quản
#     ... (và 39 stops khác)
#   ✅ Thu thập 42 stops cho hướng 'Miền Đông'
#   ✅ Phát hiện hướng mới: Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:00 - 05:00
#     Stop 2: 04:10 - 05:10
#     Stop 3: 04:20 - 05:20
#     ... (và 119 stops khác)
#   ✅ Thu thập 122 stops cho hướng 'Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Miền Đông(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Miền Đông(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:00 - 05:00
#     Stop 2: 04:10 - 05:10
#     Stop 3: 04:20 - 05:20
#     ... (và 119 stops khác)
#   ✅ Thu thập 122 stops cho hướng 'Miền Đông(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 14: 334 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 15: Bến Phú Định- Đầm Sen ---
# URL: https://xebuyt.net/ben-phu-dinh-dam-sen.html
# ✅ Đã parse HTML thành công. Độ dài content: 47308
#   ✅ Phát hiện hướng mới: Đầm Sen
#     Stop A: Đường 44
#     Stop 1: Đường 44
#     Stop 2: Cầu Nhà Thương
#     ... (và 34 stops khác)
#   ✅ Thu thập 37 stops cho hướng 'Đầm Sen'
#   ✅ Phát hiện hướng mới: Bến Phú Định
#     Stop A: BÃI XE BUÝT ĐẦM SEN
#     Stop 1: Ngã 4 Hòa Bình
#     Stop 2: Bãi xe buýt Đầm Sen
#     ... (và 35 stops khác)
#   ✅ Thu thập 38 stops cho hướng 'Bến Phú Định'
#   ✅ Phát hiện hướng mới: Đầm Sen(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Đầm Sen(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:30 - 06:25
#     Stop 2: 05:42 - 06:37
#     Stop 3: 05:54 - 06:49
#     ... (và 57 stops khác)
#   ✅ Thu thập 60 stops cho hướng 'Đầm Sen(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Phú Định(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Phú Định(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:30 - 06:25
#     Stop 2: 05:42 - 06:37
#     Stop 3: 05:54 - 06:49
#     ... (và 57 stops khác)
#   ✅ Thu thập 60 stops cho hướng 'Bến Phú Định(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 15: 195 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 16: Bến xe Chợ Lớn - Bến xe Tân Phú ---
# URL: https://xebuyt.net/ben-xe-cho-lon-ben-xe-tan-phu.html
# ✅ Đã parse HTML thành công. Độ dài content: 50595
#   ✅ Phát hiện hướng mới: Bến xe Tân Phú
#     Stop A: Bến xe Chợ Lớn
#     Stop 1: Cây Mai
#     Stop 2: Lò Siêu
#     ... (và 37 stops khác)
#   ✅ Thu thập 40 stops cho hướng 'Bến xe Tân Phú'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn
#     Stop A: Trạm Điều hành Tân Phú (0,55ha)
#     Stop 1: Trạm Đài Liệt Sỹ
#     Stop 2: Mũi tàu Cộng Hòa
#     ... (và 40 stops khác)
#   ✅ Thu thập 43 stops cho hướng 'Bến xe Chợ Lớn'
#   ✅ Phát hiện hướng mới: Bến xe Tân Phú(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Tân Phú(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:30 - 06:25
#     Stop 2: 05:45 - 06:40
#     Stop 3: 06:00 - 06:55
#     ... (và 62 stops khác)
#   ✅ Thu thập 65 stops cho hướng 'Bến xe Tân Phú(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:30 - 06:25
#     Stop 2: 05:45 - 06:40
#     Stop 3: 06:00 - 06:55
#     ... (và 62 stops khác)
#   ✅ Thu thập 65 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 16: 213 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 17: Bến Xe Chợ Lớn - ĐH Sài Gòn - KCX Tân Thuận ---
# URL: https://xebuyt.net/ben-xe-cho-lon-dh-sai-gon-kcx-tan-thuạn.html
# ✅ Đã parse HTML thành công. Độ dài content: 50039
#   ✅ Phát hiện hướng mới: KCX Tân Thuận
#     Stop A: Bến xe Chợ Lớn
#     Stop 1: Bến xe Chợ Lớn
#     Stop 2: Thuận Kiều Plaza
#     ... (và 37 stops khác)
#   ✅ Thu thập 40 stops cho hướng 'KCX Tân Thuận'
#   ✅ Phát hiện hướng mới: Bến Xe Chợ Lớn
#     Stop A: Khu chế xuất Tân Thuận
#     Stop 1: Sân bóng CLB cảng SG
#     Stop 2: Ủy ban phường Tân Thuận Tây
#     ... (và 37 stops khác)
#   ✅ Thu thập 40 stops cho hướng 'Bến Xe Chợ Lớn'
#   ✅ Phát hiện hướng mới: KCX Tân Thuận(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'KCX Tân Thuận(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:15 - 06:10
#     Stop 2: 05:30 - 06:25
#     Stop 3: 05:45 - 06:40
#     ... (và 62 stops khác)
#   ✅ Thu thập 65 stops cho hướng 'KCX Tân Thuận(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:15 - 06:10
#     Stop 2: 05:30 - 06:25
#     Stop 3: 05:45 - 06:40
#     ... (và 62 stops khác)
#   ✅ Thu thập 65 stops cho hướng 'Bến Xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 17: 210 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 18: Bến Thành - Chợ Hiệp Thành ---
# URL: https://xebuyt.net/ben-thanh-cho-hiep-thanh.html
# ✅ Đã parse HTML thành công. Độ dài content: 67042
#   ✅ Phát hiện hướng mới: Chợ Hiệp Thành
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Tôn Thất Tùng
#     Stop 2: Nguyễn Thị Nghĩa
#     ... (và 61 stops khác)
#   ✅ Thu thập 64 stops cho hướng 'Chợ Hiệp Thành'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Hiệp Thành
#     Stop 1: Ngân hàng Agribank
#     Stop 2: NVH Lao động Quận 12
#     ... (và 59 stops khác)
#   ✅ Thu thập 62 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: Chợ Hiệp Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Chợ Hiệp Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:15
#     Stop 2: 05:08 - 06:23
#     Stop 3: 05:16 - 06:31
#     ... (và 97 stops khác)
#   ✅ Thu thập 100 stops cho hướng 'Chợ Hiệp Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:30 - 05:45
#     Stop 2: 04:40 - 05:55
#     Stop 3: 04:50 - 06:05
#     ... (và 97 stops khác)
#   ✅ Thu thập 100 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 18: 326 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 19: Bến Thành - Khu Chế Xuất Linh Trung - Đại Học Quốc Gia ---
# URL: https://xebuyt.net/ben-thanh-khu-che-xuat-linh-trung-dai-hoc-quoc-gia.html
# ✅ Đã parse HTML thành công. Độ dài content: 69836
#   ✅ Phát hiện hướng mới: Đại Học Quốc Gia
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Tôn Thất Tùng
#     Stop 2: Nguyễn Thị Nghĩa
#     ... (và 55 stops khác)
#   ✅ Thu thập 58 stops cho hướng 'Đại Học Quốc Gia'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Đại học Quốc gia
#     Stop 1: 621-Ngã 3 Lâm Viên
#     Stop 2: Trường giáo dục Quốc phòng
#     ... (và 58 stops khác)
#   ✅ Thu thập 61 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: Đại Học Quốc Gia(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Đại Học Quốc Gia(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:20
#     Stop 2: 05:08 - 06:28
#     Stop 3: 05:16 - 06:36
#     ... (và 121 stops khác)
#   ✅ Thu thập 124 stops cho hướng 'Đại Học Quốc Gia(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:20
#     Stop 2: 05:08 - 06:28
#     Stop 3: 05:16 - 06:36
#     ... (và 121 stops khác)
#   ✅ Thu thập 124 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 19: 367 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 20: Bến Thành - Nhà Bè ---
# URL: https://xebuyt.net/ben-thanh-nha-be.html
# ✅ Đã parse HTML thành công. Độ dài content: 70828
#   ✅ Phát hiện hướng mới: Nhà Bè
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Tôn Thất Tùng
#     Stop 2: Nguyễn Thị Nghĩa
#     ... (và 47 stops khác)
#   ✅ Thu thập 50 stops cho hướng 'Nhà Bè'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Bình Khánh
#     Stop 1: Phà Bình Khánh
#     Stop 2: Chùa Bà Châu Đốc 2
#     ... (và 43 stops khác)
#   ✅ Thu thập 46 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: Nhà Bè(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Nhà Bè(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:20 - 05:10
#     Stop 2: 04:30 - 05:20
#     Stop 3: 04:40 - 05:30
#     ... (và 161 stops khác)
#   ✅ Thu thập 164 stops cho hướng 'Nhà Bè(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:20 - 05:10
#     Stop 2: 04:30 - 05:20
#     Stop 3: 04:40 - 05:30
#     ... (và 161 stops khác)
#   ✅ Thu thập 164 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 20: 424 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 22: Bến Xe Quận 8 - KCN Lê Minh Xuân ---
# URL: https://xebuyt.net/ben-xe-quan-8-kcn-le-minh-xuan.html
# ✅ Đã parse HTML thành công. Độ dài content: 51815
#   ✅ Phát hiện hướng mới: KCN Lê Minh Xuân
#     Stop A: Bến xe Quận 8
#     Stop 1: Bến xe Quận 8
#     Stop 2: Chùa Linh Sơn
#     ... (và 40 stops khác)
#   ✅ Thu thập 43 stops cho hướng 'KCN Lê Minh Xuân'
#   ✅ Phát hiện hướng mới: Bến Xe Quận 8
#     Stop A: KCN LÊ MINH XUÂN
#     Stop 1: Láng Le Bàu Cò
#     Stop 2: Cổng số 8
#     ... (và 38 stops khác)
#   ✅ Thu thập 41 stops cho hướng 'Bến Xe Quận 8'
#   ✅ Phát hiện hướng mới: KCN Lê Minh Xuân(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'KCN Lê Minh Xuân(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:00
#     Stop 2: 05:10 - 06:10
#     Stop 3: 05:20 - 06:20
#     ... (và 73 stops khác)
#   ✅ Thu thập 76 stops cho hướng 'KCN Lê Minh Xuân(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Xe Quận 8(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Xe Quận 8(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:00
#     Stop 2: 05:10 - 06:10
#     Stop 3: 05:20 - 06:20
#     ... (và 73 stops khác)
#   ✅ Thu thập 76 stops cho hướng 'Bến Xe Quận 8(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 22: 236 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 23: Bến xe Chợ Lớn - Ngã 3 Giồng - Cầu Lớn ---
# URL: https://xebuyt.net/ben-xe-cho-lon-nga-3-giong-cau-lon.html
# ✅ Đã parse HTML thành công. Độ dài content: 61729
#   ✅ Phát hiện hướng mới: Cầu Lớn
#     Stop A: Bến xe Chợ Lớn
#     Stop 1: Bến xe Chợ Lớn
#     Stop 2: Tạ Uyên
#     ... (và 50 stops khác)
#   ✅ Thu thập 53 stops cho hướng 'Cầu Lớn'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn
#     Stop A: Cầu Lớn
#     Stop 1: trường tiểu học Nhị Xuân
#     Stop 2: Long Thành Phát
#     ... (và 53 stops khác)
#   ✅ Thu thập 56 stops cho hướng 'Bến xe Chợ Lớn'
#   ✅ Phát hiện hướng mới: Cầu Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Cầu Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:15
#     Stop 2: 05:14 - 06:29
#     Stop 3: 05:27 - 06:42
#     ... (và 82 stops khác)
#   ✅ Thu thập 85 stops cho hướng 'Cầu Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:00 - 05:15
#     Stop 2: 04:14 - 05:29
#     Stop 3: 04:26 - 05:41
#     ... (và 82 stops khác)
#   ✅ Thu thập 85 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 23: 279 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 24: Bến Xe Miền Đông - Hóc Môn ---
# URL: https://xebuyt.net/ben-xe-mien-dong-hoc-mon.html
# ✅ Đã parse HTML thành công. Độ dài content: 83147
#   ✅ Phát hiện hướng mới: Hóc Môn
#     Stop A: Bến xe Miền Đông
#     Stop 1: Ngã Tư Nguyễn Xí
#     Stop 2: Ngã Tư Chu Văn An
#     ... (và 65 stops khác)
#   ✅ Thu thập 68 stops cho hướng 'Hóc Môn'
#   ✅ Phát hiện hướng mới: Bến Xe Miền Đông
#     Stop A: Bãi xe buýt 19/5
#     Stop 1: Ngã 3 Lam Sơn
#     Stop 2: Bích Phương
#     ... (và 63 stops khác)
#   ✅ Thu thập 66 stops cho hướng 'Bến Xe Miền Đông'
#   ✅ Phát hiện hướng mới: Hóc Môn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Hóc Môn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:00 - 05:15
#     Stop 2: 04:12 - 05:27
#     Stop 3: 04:24 - 05:39
#     ... (và 184 stops khác)
#   ✅ Thu thập 187 stops cho hướng 'Hóc Môn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Xe Miền Đông(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Xe Miền Đông(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:00 - 05:15
#     Stop 2: 04:12 - 05:27
#     Stop 3: 04:22 - 05:37
#     ... (và 180 stops khác)
#   ✅ Thu thập 183 stops cho hướng 'Bến Xe Miền Đông(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 24: 504 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 25: Bến Xe Quận 8 - Khu Dân Cư Vĩnh Lộc A ---
# URL: https://xebuyt.net/ben-xe-quan-8-khu-dan-cu-vinh-loc-a.html
# ✅ Đã parse HTML thành công. Độ dài content: 53152
#   ✅ Phát hiện hướng mới: Khu Dân Cư Vĩnh Lộc A
#     Stop A: Bến xe Quận 8
#     Stop 1: Bùi Minh Trực
#     Stop 2: Cầu Nhị Thiên Đường
#     ... (và 43 stops khác)
#   ✅ Thu thập 46 stops cho hướng 'Khu Dân Cư Vĩnh Lộc A'
#   ✅ Phát hiện hướng mới: Bến Xe Quận 8
#     Stop A: KDC VĨNH LỘC A
#     Stop 1: KDC Vĩnh Lộc A
#     Stop 2: Ngã 5 Vĩnh Lộc
#     ... (và 43 stops khác)
#   ✅ Thu thập 46 stops cho hướng 'Bến Xe Quận 8'
#   ✅ Phát hiện hướng mới: Khu Dân Cư Vĩnh Lộc A(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Khu Dân Cư Vĩnh Lộc A(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:00
#     Stop 2: 05:12 - 06:12
#     Stop 3: 05:24 - 06:24
#     ... (và 67 stops khác)
#   ✅ Thu thập 70 stops cho hướng 'Khu Dân Cư Vĩnh Lộc A(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Xe Quận 8(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Xe Quận 8(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:00
#     Stop 2: 05:12 - 06:12
#     Stop 3: 05:24 - 06:24
#     ... (và 67 stops khác)
#   ✅ Thu thập 70 stops cho hướng 'Bến Xe Quận 8(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 25: 232 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 27: Bến Thành - Âu Cơ - An Sương ---
# URL: https://xebuyt.net/ben-thanh-au-co-an-suong.html
# ✅ Đã parse HTML thành công. Độ dài content: 56540
#   ✅ Phát hiện hướng mới: An Sương
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Nhà thờ Huyện Sỹ
#     Stop 2: Chợ Thái Bình
#     ... (và 42 stops khác)
#   ✅ Thu thập 45 stops cho hướng 'An Sương'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Bến xe An Sương
#     Stop 1: Chợ Chiều
#     Stop 2: Bitis
#     ... (và 39 stops khác)
#   ✅ Thu thập 42 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)
#   ✅ Thu thập 0 stops cho hướng 'An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#     Stop 1: 05:00 - 06:00
#     Stop 2: 05:15 - 06:15
#     Stop 3: 05:30 - 06:30
#     ... (và 87 stops khác)
#   ✅ Thu thập 90 stops cho hướng 'An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#     Stop 1: 05:00 - 06:00
#     Stop 2: 05:10 - 06:10
#     Stop 3: 05:18 - 06:18
#     ... (và 87 stops khác)
#   ✅ Thu thập 90 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
# ✅ Hoàn thành tuyến 27: 267 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 28: Bến Thành - Chợ Xuân Thới Thượng ---
# URL: https://xebuyt.net/ben-thanh-cho-xuan-thoi-thuong.html
# ✅ Đã parse HTML thành công. Độ dài content: 63291
#   ✅ Phát hiện hướng mới: Chợ Xuân Thới Thượng
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Tôn Thất Tùng
#     Stop 2: Nguyễn Thị Nghĩa
#     ... (và 63 stops khác)
#   ✅ Thu thập 66 stops cho hướng 'Chợ Xuân Thới Thượng'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Xuân Thới Thượng
#     Stop 1: Trường Ngã ba Giòng
#     Stop 2: Phan Văn Hớn
#     ... (và 63 stops khác)
#   ✅ Thu thập 66 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: Chợ Xuân Thới Thượng(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)
#   ✅ Thu thập 0 stops cho hướng 'Chợ Xuân Thới Thượng(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#     Stop 1: 05:00 - 06:20
#     Stop 2: 05:20 - 06:40
#     Stop 3: 05:40 - 07:00
#     ... (và 52 stops khác)
#   ✅ Thu thập 55 stops cho hướng 'Chợ Xuân Thới Thượng(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#     Stop 1: 05:00 - 06:20
#     Stop 2: 05:08 - 06:28
#     Stop 3: 05:16 - 06:36
#     ... (và 52 stops khác)
#   ✅ Thu thập 55 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
# ✅ Hoàn thành tuyến 28: 242 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 29: Bến Phà Cát Lái - Chợ Nông Sản Thủ Đức ---
# URL: https://xebuyt.net/ben-pha-cat-lai-cho-nong-san-thu-duc.html
# ✅ Đã parse HTML thành công. Độ dài content: 58018
#   ✅ Phát hiện hướng mới: Chợ Nông Sản Thủ Đức
#     Stop A: Cát Lái
#     Stop 1: Sân bóng Mini
#     Stop 2: Khu Dân Cư Phố Đông
#     ... (và 42 stops khác)
#   ✅ Thu thập 45 stops cho hướng 'Chợ Nông Sản Thủ Đức'
#   ✅ Phát hiện hướng mới: Bến Phà Cát Lái
#     Stop A: Chợ nông sản Thủ Đức
#     Stop 1: Chợ đầu mối nông sản Thủ Đức
#     Stop 2: Chợ Đầu Mối
#     ... (và 48 stops khác)
#   ✅ Thu thập 51 stops cho hướng 'Bến Phà Cát Lái'
#   ✅ Phát hiện hướng mới: Chợ Nông Sản Thủ Đức(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Chợ Nông Sản Thủ Đức(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:10
#     Stop 2: 05:08 - 06:18
#     Stop 3: 05:16 - 06:26
#     ... (và 87 stops khác)
#   ✅ Thu thập 90 stops cho hướng 'Chợ Nông Sản Thủ Đức(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Phà Cát Lái(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Phà Cát Lái(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:10
#     Stop 2: 05:10 - 06:20
#     Stop 3: 05:19 - 06:29
#     ... (và 87 stops khác)
#   ✅ Thu thập 90 stops cho hướng 'Bến Phà Cát Lái(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 29: 276 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 30: Chợ Tân Hương - Đại học Quốc tế ---
# URL: https://xebuyt.net/cho-tan-huong-dai-hoc-quoc-te.html
# ✅ Đã parse HTML thành công. Độ dài content: 61442
#   ✅ Phát hiện hướng mới: Đại học Quốc tế
#     Stop A: Cư xá Nhiêu Lộc
#     Stop 1: Bình Long
#     Stop 2: Lê Sát
#     ... (và 61 stops khác)
#   ✅ Thu thập 64 stops cho hướng 'Đại học Quốc tế'
#   ✅ Phát hiện hướng mới: Chợ Tân Hương
#     Stop A: Đường nội bộ Đại học Quốc gia
#     Stop 1: 621-Ngã 3 Lâm Viên
#     Stop 2: Trường giáo dục Quốc phòng
#     ... (và 61 stops khác)
#   ✅ Thu thập 64 stops cho hướng 'Chợ Tân Hương'
#   ✅ Phát hiện hướng mới: Đại học Quốc tế(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Đại học Quốc tế(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:25
#     Stop 2: 05:12 - 06:37
#     Stop 3: 05:20 - 06:45
#     ... (và 57 stops khác)
#   ✅ Thu thập 60 stops cho hướng 'Đại học Quốc tế(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Chợ Tân Hương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Chợ Tân Hương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:15 - 06:40
#     Stop 2: 05:30 - 06:55
#     Stop 3: 05:45 - 07:10
#     ... (và 57 stops khác)
#   ✅ Thu thập 60 stops cho hướng 'Chợ Tân Hương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 30: 248 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 31: Khu dân cư Tân Quy - Bến Thành - Khu dân cư Bình Lợi ---
# URL: https://xebuyt.net/khu-dan-cu-tan-quy-ben-thanh-khu-dan-cu-binh-loi.html
# ✅ Đã parse HTML thành công. Độ dài content: 55620
#   ✅ Phát hiện hướng mới: Khu dân cư Bình Lợi
#     Stop A: Khu dân cư Tân Quy Đông
#     Stop 1: Khu dân cư Tân Quy Đông
#     Stop 2: Đường số 38
#     ... (và 51 stops khác)
#   ✅ Thu thập 54 stops cho hướng 'Khu dân cư Bình Lợi'
#   ✅ Phát hiện hướng mới: Khu dân cư Tân Quy
#     Stop A: Khu dân cư Bình Lợi
#     Stop 1: Chùa phước Thành
#     Stop 2: Chùa Diệu Pháp
#     ... (và 47 stops khác)
#   ✅ Thu thập 50 stops cho hướng 'Khu dân cư Tân Quy'
#   ✅ Phát hiện hướng mới: Khu dân cư Bình Lợi(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Khu dân cư Bình Lợi(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:10
#     Stop 2: 05:15 - 06:25
#     Stop 3: 05:30 - 06:40
#     ... (và 60 stops khác)
#   ✅ Thu thập 63 stops cho hướng 'Khu dân cư Bình Lợi(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Khu dân cư Tân Quy(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Khu dân cư Tân Quy(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:10
#     Stop 2: 05:15 - 06:25
#     Stop 3: 05:30 - 06:40
#     ... (và 60 stops khác)
#   ✅ Thu thập 63 stops cho hướng 'Khu dân cư Tân Quy(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 31: 230 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 32: Bến Xe Miền Tây - Bến Xe Ngã Tư Ga ---
# URL: https://xebuyt.net/ben-xe-mien-tay-ben-xe-nga-tu-ga.html
# ✅ Đã parse HTML thành công. Độ dài content: 72900
#   ✅ Phát hiện hướng mới: Bến Xe Ngã Tư Ga
#     Stop A: Bến xe Miền Tây
#     Stop 1: Dương Tự Quản
#     Stop 2: Công viên Phú Lâm
#     ... (và 64 stops khác)
#   ✅ Thu thập 67 stops cho hướng 'Bến Xe Ngã Tư Ga'
#   ✅ Phát hiện hướng mới: Bến Xe Miền Tây
#     Stop A: Bến xe Ngã tư Ga
#     Stop 1: Ngã tư Ga
#     Stop 2: Cầu An Lộc
#     ... (và 64 stops khác)
#   ✅ Thu thập 66 stops cho hướng 'Bến Xe Miền Tây'
#   ✅ Phát hiện hướng mới: Bến Xe Ngã Tư Ga(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Xe Ngã Tư Ga(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:30 - 05:45
#     Stop 2: 04:38 - 05:53
#     Stop 3: 04:46 - 06:01
#     ... (và 119 stops khác)
#   ✅ Thu thập 122 stops cho hướng 'Bến Xe Ngã Tư Ga(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:30 - 05:45
#     Stop 2: 04:38 - 05:53
#     Stop 3: 04:46 - 06:01
#     ... (và 119 stops khác)
#   ✅ Thu thập 122 stops cho hướng 'Bến Xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 32: 377 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 33: Bến Xe An Sương - Suối Tiên - Đại học Quốc Gia ---
# URL: https://xebuyt.net/ben-xe-an-suong-suoi-tien-dai-hoc-quoc-gia.html
# ✅ Đã parse HTML thành công. Độ dài content: 71765
#   ✅ Phát hiện hướng mới: Đại học Quốc Gia
#     Stop A: Bến xe An Sương
#     Stop 1: Cầu vượt An Sương
#     Stop 2: Bến xe Tây Nam
#     ... (và 43 stops khác)
#   ✅ Thu thập 46 stops cho hướng 'Đại học Quốc Gia'
#   ✅ Phát hiện hướng mới: Bến Xe An Sương
#     Stop A: Bến Xe Buýt ÐH Quốc Gia
#     Stop 1: 621-Ngã 3 Lâm Viên
#     Stop 2: Trường giáo dục Quốc phòng
#     ... (và 49 stops khác)
#   ✅ Thu thập 52 stops cho hướng 'Bến Xe An Sương'
#   ✅ Phát hiện hướng mới: Đại học Quốc Gia(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)
#   ✅ Thu thập 0 stops cho hướng 'Đại học Quốc Gia(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#     Stop 1: 04:30 - 05:25
#     Stop 2: 04:45 - 05:40
#     Stop 3: 04:57 - 05:52
#     ... (và 171 stops khác)
#   ✅ Thu thập 174 stops cho hướng 'Đại học Quốc Gia(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#   ✅ Phát hiện hướng mới: Bến Xe An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)
#   ✅ Thu thập 0 stops cho hướng 'Bến Xe An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#     Stop 1: 04:30 - 05:25
#     Stop 2: 04:45 - 05:40
#     Stop 3: 04:57 - 05:52
#     ... (và 171 stops khác)
#   ✅ Thu thập 174 stops cho hướng 'Bến Xe An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
# ✅ Hoàn thành tuyến 33: 446 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 34: Bến Thành - Đại Học Công Nghệ Sài Gòn ---
# URL: https://xebuyt.net/ben-thanh-dai-hoc-cong-nghe-sai-gon.html
# ✅ Đã parse HTML thành công. Độ dài content: 53223
#   ✅ Phát hiện hướng mới: Đại Học Công Nghệ Sài Gòn
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Tôn Thất Tùng
#     Stop 2: Nguyễn Thị Nghĩa
#     ... (và 41 stops khác)
#   ✅ Thu thập 44 stops cho hướng 'Đại Học Công Nghệ Sài Gòn'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Công viên Đồng Diều
#     Stop 1: Đường số 5
#     Stop 2: Centre Mall
#     ... (và 45 stops khác)
#   ✅ Thu thập 48 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: Đại Học Công Nghệ Sài Gòn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Đại Học Công Nghệ Sài Gòn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 05:55
#     Stop 2: 05:15 - 06:10
#     Stop 3: 05:30 - 06:25
#     ... (và 66 stops khác)
#   ✅ Thu thập 69 stops cho hướng 'Đại Học Công Nghệ Sài Gòn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 05:55
#     Stop 2: 05:15 - 06:10
#     Stop 3: 05:30 - 06:25
#     ... (và 66 stops khác)
#   ✅ Thu thập 69 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 34: 230 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 35: Tuyến xe buýt Quận 1 - Quận 2 ---
# URL: https://xebuyt.net/tuyen-xe-buyt-quan-1-quan-2.html
# ✅ Đã parse HTML thành công. Độ dài content: 40674
#   ✅ Phát hiện hướng mới: Quận 2
#     Stop A: Bến xe buýt Hoàng Sa
#     Stop 1: Kho Bạc Q1
#     Stop 2: UBND Phường Dakao
#     ... (và 28 stops khác)
#   ✅ Thu thập 31 stops cho hướng 'Quận 2'
#   ✅ Phát hiện hướng mới: Tuyến xe buýt Quận 1
#     Stop A: Làng báo chí
#     Stop 1: Làng báo chí
#     Stop 2: Quốc Hương - Lê Văn Miến
#     ... (và 30 stops khác)
#   ✅ Thu thập 33 stops cho hướng 'Tuyến xe buýt Quận 1'
#   ✅ Phát hiện hướng mới: Quận 2(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Quận 2(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:25 - 06:15
#     Stop 2: 05:50 - 06:40
#     Stop 3: 06:15 - 07:05
#     ... (và 33 stops khác)
#   ✅ Thu thập 36 stops cho hướng 'Quận 2(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Tuyến xe buýt Quận 1(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Tuyến xe buýt Quận 1(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 06:00 - 06:50
#     Stop 2: 06:20 - 07:10
#     Stop 3: 06:40 - 07:35
#     ... (và 33 stops khác)
#   ✅ Thu thập 36 stops cho hướng 'Tuyến xe buýt Quận 1(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 35: 136 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 36: Bến Thành - Thới An ---
# URL: https://xebuyt.net/ben-thanh-thoi-an.html
# ✅ Đã parse HTML thành công. Độ dài content: 58646
#   ✅ Phát hiện hướng mới: Thới An
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Tôn Thất Tùng
#     Stop 2: Nguyễn Thị Nghĩa
#     ... (và 49 stops khác)
#   ✅ Thu thập 52 stops cho hướng 'Thới An'
#   ✅ Phát hiện hướng mới: Bến Thành
#     Stop A: Bãi xe buýt Thới An
#     Stop 1: Ủy Ban nhân dân Phường Thới An
#     Stop 2: Bảo hiểm xã hội Quận 12
#     ... (và 46 stops khác)
#   ✅ Thu thập 49 stops cho hướng 'Bến Thành'
#   ✅ Phát hiện hướng mới: Thới An(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)
#   ✅ Thu thập 0 stops cho hướng 'Thới An(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#     Stop 1: 05:00 - 06:00
#     Stop 2: 05:10 - 06:10
#     Stop 3: 05:20 - 06:20
#     ... (và 77 stops khác)
#   ✅ Thu thập 80 stops cho hướng 'Thới An(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#   ✅ Phát hiện hướng mới: Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)
#   ✅ Thu thập 0 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#     Stop 1: 04:45 - 05:45
#     Stop 2: 05:00 - 06:00
#     Stop 3: 05:10 - 06:10
#     ... (và 77 stops khác)
#   ✅ Thu thập 80 stops cho hướng 'Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
# ✅ Hoàn thành tuyến 36: 261 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 37: Cảng Quận 4 - Nhơn Đức ---
# URL: https://xebuyt.net/cang-quan-4-nhon-duc.html
# ✅ Đã parse HTML thành công. Độ dài content: 37328
#   ✅ Phát hiện hướng mới: Nhơn Đức
#     Stop A: Cảng Quận 4
#     Stop 1: UBND Phường 4
#     Stop 2: Tôn Đản
#     ... (và 36 stops khác)
#   ✅ Thu thập 39 stops cho hướng 'Nhơn Đức'
#   ✅ Phát hiện hướng mới: Cảng Quận 4
#     Stop A: Nhơn Đức
#     Stop 1: Long Thới - Nhơn Đức
#     Stop 2: Cầu Rạch Tôm
#     ... (và 35 stops khác)
#   ✅ Thu thập 38 stops cho hướng 'Cảng Quận 4'
# ...
# ✅ Hoàn thành tuyến 141: 333 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 144: Bến xe Miền Tây - Chợ Lớn - CV Đầm Sen - CX Nhiêu Lộc ---
# URL: https://xebuyt.net/ben-xe-mien-tay-cho-lon-cv-dam-sen-cu-xa-nhieu-loc.html
# ✅ Đã parse HTML thành công. Độ dài content: 50472
#   ✅ Phát hiện hướng mới: CX Nhiêu Lộc
#     Stop A: Bến xe Miền Tây
#     Stop 1: 49-51 (317), Kinh Dương Vương
#     Stop 2: Dương Tự Quản
#     ... (và 40 stops khác)
#   ✅ Thu thập 43 stops cho hướng 'CX Nhiêu Lộc'
#   ✅ Phát hiện hướng mới: Bến xe Miền Tây
#     Stop A: Cư xá Nhiêu Lộc
#     Stop 1: Bình Long
#     Stop 2: Nghĩa trang Đa Minh
#     ... (và 42 stops khác)
#   ✅ Thu thập 45 stops cho hướng 'Bến xe Miền Tây'
#   ✅ Phát hiện hướng mới: CX Nhiêu Lộc(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'CX Nhiêu Lộc(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:30 - 06:25
#     Stop 2: 05:45 - 06:40
#     Stop 3: 06:00 - 06:55
#     ... (và 57 stops khác)
#   ✅ Thu thập 60 stops cho hướng 'CX Nhiêu Lộc(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:30 - 06:25
#     Stop 2: 05:45 - 06:40
#     Stop 3: 06:00 - 06:55
#     ... (và 57 stops khác)
#   ✅ Thu thập 60 stops cho hướng 'Bến xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 144: 208 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 145: Bến xe Chợ Lớn - Chợ Hiệp Thành ---
# URL: https://xebuyt.net/ben-xe-cho-lon-cho-hiep-thanh.html
# ✅ Đã parse HTML thành công. Độ dài content: 64500
#   ✅ Phát hiện hướng mới: Chợ Hiệp Thành
#     Stop A: Bến xe Chợ Lớn
#     Stop 1: Cây Mai
#     Stop 2: Lò Siêu
#     ... (và 57 stops khác)
#   ✅ Thu thập 60 stops cho hướng 'Chợ Hiệp Thành'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn
#     Stop A: Hiệp Thành
#     Stop 1: Ngân hàng Agribank
#     Stop 2: NVH Lao động Quận 12
#     ... (và 60 stops khác)
#   ✅ Thu thập 63 stops cho hướng 'Bến xe Chợ Lớn'
#   ✅ Phát hiện hướng mới: Chợ Hiệp Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Chợ Hiệp Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:10
#     Stop 2: 05:10 - 06:20
#     Stop 3: 05:20 - 06:30
#     ... (và 87 stops khác)
#   ✅ Thu thập 90 stops cho hướng 'Chợ Hiệp Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:10
#     Stop 2: 05:12 - 06:22
#     Stop 3: 05:22 - 06:32
#     ... (và 87 stops khác)
#   ✅ Thu thập 90 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 145: 303 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 146: Bến xe Miền Đông - Chợ Hiệp Thành ---
# URL: https://xebuyt.net/ben-xe-mien-dong-cho-hiep-thanh.html
# ✅ Đã parse HTML thành công. Độ dài content: 50144
#   ✅ Phát hiện hướng mới: Chợ Hiệp Thành
#     Stop A: Bến xe Miền Đông
#     Stop 1: Ngã Tư Nguyễn Xí
#     Stop 2: Ngã Tư Chu Văn An
#     ... (và 38 stops khác)
#   ✅ Thu thập 41 stops cho hướng 'Chợ Hiệp Thành'
#   ✅ Phát hiện hướng mới: Bến xe Miền Đông
#     Stop A: Hiệp Thành
#     Stop 1: Hiệp Thành 31
#     Stop 2: Lê Văn Khương
#     ... (và 41 stops khác)
#   ✅ Thu thập 44 stops cho hướng 'Bến xe Miền Đông'
#   ✅ Phát hiện hướng mới: Chợ Hiệp Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Chợ Hiệp Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:00
#     Stop 2: 05:15 - 06:15
#     Stop 3: 05:30 - 06:30
#     ... (và 52 stops khác)
#   ✅ Thu thập 55 stops cho hướng 'Chợ Hiệp Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến xe Miền Đông(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Miền Đông(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 06:00
#     Stop 2: 05:15 - 06:15
#     Stop 3: 05:30 - 06:30
#     ... (và 52 stops khác)
#   ✅ Thu thập 55 stops cho hướng 'Bến xe Miền Đông(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 146: 195 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 148: Bến xe Miền Tây - Gò Vấp ---
# URL: https://xebuyt.net/ben-xe-mien-tay-go-vap.html
# ✅ Đã parse HTML thành công. Độ dài content: 53794
#   ✅ Phát hiện hướng mới: Gò Vấp
#     Stop A: Bến xe Miền Tây
#     Stop 1: 49-51 (317), Kinh Dương Vương
#     Stop 2: Dương Tự Quản
#     ... (và 40 stops khác)
#   ✅ Thu thập 43 stops cho hướng 'Gò Vấp'
#   ✅ Phát hiện hướng mới: Bến xe Miền Tây
#     Stop A: BÃI HẬU CẦN SỐ 1
#     Stop 1: Bãi hậu cần số 1
#     Stop 2: UBND Phường 5, Quận Gò Vấp
#     ... (và 48 stops khác)
#   ✅ Thu thập 51 stops cho hướng 'Bến xe Miền Tây'
#   ✅ Phát hiện hướng mới: Gò Vấp(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Gò Vấp(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:00 - 05:57
#     Stop 2: 05:12 - 06:09
#     Stop 3: 05:22 - 06:19
#     ... (và 70 stops khác)
#   ✅ Thu thập 73 stops cho hướng 'Gò Vấp(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:20 - 06:17
#     Stop 2: 05:32 - 06:29
#     Stop 3: 05:44 - 06:41
#     ... (và 62 stops khác)
#   ✅ Thu thập 65 stops cho hướng 'Bến xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 148: 232 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 149: Công viên 23/9 - Khu dân cư Bình Hưng Hòa ---
# URL: https://xebuyt.net/cong-vien-23-9-khu-dan-cu-bình-hung-hoa.html
# ✅ Đã parse HTML thành công. Độ dài content: 52245
#   ✅ Phát hiện hướng mới: Khu dân cư Bình Hưng Hòa
#     Stop A: TĐH xe buýt Sài Gòn
#     Stop 1: Tôn Thất Tùng
#     Stop 2: Nguyễn Thị Nghĩa
#     ... (và 42 stops khác)
#   ✅ Thu thập 45 stops cho hướng 'Khu dân cư Bình Hưng Hòa'
#   ✅ Phát hiện hướng mới: Công viên 23/9
#     Stop A: Khu dân cư Bình Hưng Hòa B
#     Stop 1: Công ty Bảo Ngọc Châu
#     Stop 2: Nguyễn Thị Tú
#     ... (và 38 stops khác)
#   ✅ Thu thập 41 stops cho hướng 'Công viên 23/9'
#   ✅ Phát hiện hướng mới: Khu dân cư Bình Hưng Hòa(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Khu dân cư Bình Hưng Hòa(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:15 - 06:15
#     Stop 2: 05:35 - 06:35
#     Stop 3: 05:55 - 06:55
#     ... (và 62 stops khác)
#   ✅ Thu thập 65 stops cho hướng 'Khu dân cư Bình Hưng Hòa(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Công viên 23/9(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Công viên 23/9(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:15 - 06:15
#     Stop 2: 05:30 - 06:30
#     Stop 3: 05:45 - 06:45
#     ... (và 62 stops khác)
#   ✅ Thu thập 65 stops cho hướng 'Công viên 23/9(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 149: 216 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 150: Bến xe Chợ Lớn - Ngã 3 Tân Vạn ---
# URL: https://xebuyt.net/ben-xe-cho-lon-nga-3-tan-van.html
# ✅ Đã parse HTML thành công. Độ dài content: 77928
#   ✅ Phát hiện hướng mới: Ngã 3 Tân Vạn
#     Stop A: Bến xe Chợ Lớn
#     Stop 1: Chu Văn An
#     Stop 2: Thuận Kiều Plaza
#     ... (và 48 stops khác)
#   ✅ Thu thập 51 stops cho hướng 'Ngã 3 Tân Vạn'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn
#     Stop A: Tân Vạn
#     Stop 1: Công ty TNHH Thuận Thành Tâm
#     Stop 2: Công ty Dosan
#     ... (và 50 stops khác)
#   ✅ Thu thập 53 stops cho hướng 'Bến xe Chợ Lớn'
#   ✅ Phát hiện hướng mới: Ngã 3 Tân Vạn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Ngã 3 Tân Vạn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:30 - 05:50
#     Stop 2: 04:40 - 06:00
#     Stop 3: 04:48 - 06:08
#     ... (và 183 stops khác)
#   ✅ Thu thập 186 stops cho hướng 'Ngã 3 Tân Vạn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 04:30 - 05:50
#     Stop 2: 04:40 - 06:00
#     Stop 3: 04:48 - 06:08
#     ... (và 184 stops khác)
#   ✅ Thu thập 187 stops cho hướng 'Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 150: 477 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 151: Bến xe Miền Tây - Bến xe An Sương ---
# URL: https://xebuyt.net/ben-xe-mien-tay-ben-xe-an-suong.html
# ✅ Đã parse HTML thành công. Độ dài content: 57132
#   ✅ Phát hiện hướng mới: Bến xe An Sương
#     Stop A: Bến xe Miền Tây
#     Stop 1: Bệnh viện Triều An
#     Stop 2: Hàng Dương
#     ... (và 34 stops khác)
#   ✅ Thu thập 37 stops cho hướng 'Bến xe An Sương'
#   ✅ Phát hiện hướng mới: Bến xe Miền Tây
#     Stop A: Bến xe An Sương
#     Stop 1: Trạm măng
#     Stop 2: Hồng Mộc
#     ... (và 31 stops khác)
#   ✅ Thu thập 34 stops cho hướng 'Bến xe Miền Tây'
#   ✅ Phát hiện hướng mới: Bến xe An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#     Stop 1: 04:00 - 04:45
#     Stop 2: 04:09 - 04:54
#     Stop 3: 04:18 - 05:03
#     ... (và 135 stops khác)
#   ✅ Thu thập 138 stops cho hướng 'Bến xe An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#   ✅ Phát hiện hướng mới: Bến xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)
#   ✅ Thu thập 0 stops cho hướng 'Bến xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
#     Stop 1: 05:00 - 05:45
#     Stop 2: 05:10 - 05:55
#     Stop 3: 05:20 - 06:05
#     ... (và 131 stops khác)
#   ✅ Thu thập 134 stops cho hướng 'Bến xe Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7)'
# ✅ Hoàn thành tuyến 151: 343 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến 152: Khu dân cư Trung Sơn - Bến Thành - Sân bay Tân Sơn Nhất ---
# URL: https://xebuyt.net/khu-dan-cu-trung-son-ben-thanh-san-bay-tan-son-nhat.html
# ✅ Đã parse HTML thành công. Độ dài content: 45855
#   ✅ Phát hiện hướng mới: Sân bay Tân Sơn Nhất
#     Stop A: Khu dân cư Trung Sơn
#     Stop 1: Thảo Loan PLAZA
#     Stop 2: Đường 9A
#     ... (và 35 stops khác)
#   ✅ Thu thập 38 stops cho hướng 'Sân bay Tân Sơn Nhất'
#   ✅ Phát hiện hướng mới: Khu dân cư Trung Sơn
#     Stop A: Sân bay Tân Sơn Nhất
#     Stop 1: Trường Ngô Sỹ Liên
#     Stop 2: Siêu thị Super Bow
#     ... (và 30 stops khác)
#   ✅ Thu thập 33 stops cho hướng 'Khu dân cư Trung Sơn'
#   ✅ Phát hiện hướng mới: Sân bay Tân Sơn Nhất(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Sân bay Tân Sơn Nhất(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:30 - 06:20
#     Stop 2: 05:45 - 06:35
#     Stop 3: 05:57 - 06:47
#     ... (và 47 stops khác)
#   ✅ Thu thập 50 stops cho hướng 'Sân bay Tân Sơn Nhất(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Khu dân cư Trung Sơn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho hướng 'Khu dân cư Trung Sơn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#     Stop 1: 05:30 - 06:20
#     Stop 2: 05:45 - 06:35
#     Stop 3: 05:57 - 06:47
#     ... (và 47 stops khác)
#   ✅ Thu thập 50 stops cho hướng 'Khu dân cư Trung Sơn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 152: 171 stops tổng cộng
#
# --- Đang scrape lộ trình tuyến C010: Phổ Quang - KCN Hiệp Phước ---
# URL: https://xebuyt.net/pho-quang-kcn-hiep-phuoc.html
# ✅ Đã parse HTML thành công. Độ dài content: 19964
#   ✅ Phát hiện hướng mới: KCN Hiệp Phước
#     Stop A: Bãi Xe Phổ Quang
#     Stop 1: Trường Ernst Thalmann
#     Stop 2: Trần Hưng Đạo
#     ... (và 2 stops khác)
#   ✅ Thu thập 5 stops cho hướng 'KCN Hiệp Phước'
#   ✅ Phát hiện hướng mới: Phổ Quang
#     Stop A: Công ty Hồng Anh
#     Stop 1: Trung tâm TDTT Quận 4
#     Stop 2: Trần Hưng Đạo
#     ... (và 1 stops khác)
#   ✅ Thu thập 4 stops cho hướng 'Phổ Quang'
#   ✅ Phát hiện hướng mới: KCN Hiệp Phước(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)
#   ✅ Thu thập 0 stops cho hướng 'KCN Hiệp Phước(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)'
#   ✅ Thu thập 0 stops cho hướng 'KCN Hiệp Phước(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)'
#   ✅ Phát hiện hướng mới: Phổ Quang(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)
#   ✅ Thu thập 0 stops cho hướng 'Phổ Quang(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)'
#   ✅ Thu thập 0 stops cho hướng 'Phổ Quang(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6)'
# ✅ Hoàn thành tuyến C010: 9 stops tổng cộng
#
# --- Kết thúc scrape ---
# Tổng số stops thu thập được: 27016
# ✅ Dữ liệu lộ trình đã được lưu vào file tuyen_xe_buyt_lotrinh.csv
#
# --- Preview DataFrame (top 20 rows) ---
# Route_Number            Route_Name                                              URL  Direction Stop_Order                         Stop_Name
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          A               Công Trường Mê Linh
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          1                     Bến Bạch Đằng
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          2            Cục Hải Quan Thành Phố
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          3                            Chợ Cũ
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          4                  Trường Cao Thắng
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          5                 Công ty Đường sắt
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          6                     Bến Thành B
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          7             Trường Ernst Thalmann
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          8                 KTX Trần Hưng Đạo
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          9                      Rạp Hưng Đạo
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         10            Bệnh viện Răng Hàm Mặt
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         11                      Trần Đình Xu
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         12                    Tổng Cty Samco
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         13                         Chợ Nanci
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         14                       Nguyễn Biểu
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         15 Trường Cao đẳng Kinh tế Đối ngoại
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         16                   Trần Bình Trọng
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         17  Bệnh viện Chấn thương Chỉnh hình
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         18                     Rạp Đồng Tháp
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn         19                       Rạp Đống Đa
#
# --- Thống kê ---
# - Tổng tuyến có dữ liệu: 117
# - Hướng phổ biến nhất: Direction
# Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)    1512
# Name: count, dtype: int64

# %%
import pandas as pd

# Thiết lập để hiển thị toàn bộ DataFrame (tắt giới hạn hàng và cột)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# Hiển thị DataFrame

route_stops_df.head(300)
# Out:
#     Route_Number             Route_Name  \
# 0             01  Bến Thành- BX Chợ Lớn
# 1             01  Bến Thành- BX Chợ Lớn
# 2             01  Bến Thành- BX Chợ Lớn
# 3             01  Bến Thành- BX Chợ Lớn
# 4             01  Bến Thành- BX Chợ Lớn
# 5             01  Bến Thành- BX Chợ Lớn
# 6             01  Bến Thành- BX Chợ Lớn
# 7             01  Bến Thành- BX Chợ Lớn
# 8             01  Bến Thành- BX Chợ Lớn
# 9             01  Bến Thành- BX Chợ Lớn
# 10            01  Bến Thành- BX Chợ Lớn
# 11            01  Bến Thành- BX Chợ Lớn
# 12            01  Bến Thành- BX Chợ Lớn
# 13            01  Bến Thành- BX Chợ Lớn
# 14            01  Bến Thành- BX Chợ Lớn
# 15            01  Bến Thành- BX Chợ Lớn
# 16            01  Bến Thành- BX Chợ Lớn
# 17            01  Bến Thành- BX Chợ Lớn
# 18            01  Bến Thành- BX Chợ Lớn
# 19            01  Bến Thành- BX Chợ Lớn
# 20            01  Bến Thành- BX Chợ Lớn
# 21            01  Bến Thành- BX Chợ Lớn
# 22            01  Bến Thành- BX Chợ Lớn
# 23            01  Bến Thành- BX Chợ Lớn
# 24            01  Bến Thành- BX Chợ Lớn
# 25            01  Bến Thành- BX Chợ Lớn
# 26            01  Bến Thành- BX Chợ Lớn
# 27            01  Bến Thành- BX Chợ Lớn
# 28            01  Bến Thành- BX Chợ Lớn
# 29            01  Bến Thành- BX Chợ Lớn
# 30            01  Bến Thành- BX Chợ Lớn
# 31            01  Bến Thành- BX Chợ Lớn
# 32            01  Bến Thành- BX Chợ Lớn
# 33            01  Bến Thành- BX Chợ Lớn
# 34            01  Bến Thành- BX Chợ Lớn
# 35            01  Bến Thành- BX Chợ Lớn
# 36            01  Bến Thành- BX Chợ Lớn
# 37            01  Bến Thành- BX Chợ Lớn
# 38            01  Bến Thành- BX Chợ Lớn
# 39            01  Bến Thành- BX Chợ Lớn
# 40            01  Bến Thành- BX Chợ Lớn
# 41            01  Bến Thành- BX Chợ Lớn
# 42            01  Bến Thành- BX Chợ Lớn
# 43            01  Bến Thành- BX Chợ Lớn
# 44            01  Bến Thành- BX Chợ Lớn
# 45            01  Bến Thành- BX Chợ Lớn
# 46            01  Bến Thành- BX Chợ Lớn
# 47            01  Bến Thành- BX Chợ Lớn
# 48            01  Bến Thành- BX Chợ Lớn
# 49            01  Bến Thành- BX Chợ Lớn
# 50            01  Bến Thành- BX Chợ Lớn
# 51            01  Bến Thành- BX Chợ Lớn
# 52            01  Bến Thành- BX Chợ Lớn
# 53            01  Bến Thành- BX Chợ Lớn
# 54            01  Bến Thành- BX Chợ Lớn
# 55            01  Bến Thành- BX Chợ Lớn
# 56            01  Bến Thành- BX Chợ Lớn
# 57            01  Bến Thành- BX Chợ Lớn
# 58            01  Bến Thành- BX Chợ Lớn
# 59            01  Bến Thành- BX Chợ Lớn
# 60            01  Bến Thành- BX Chợ Lớn
# 61            01  Bến Thành- BX Chợ Lớn
# 62            01  Bến Thành- BX Chợ Lớn
# 63            01  Bến Thành- BX Chợ Lớn
# 64            01  Bến Thành- BX Chợ Lớn
# 65            01  Bến Thành- BX Chợ Lớn
# 66            01  Bến Thành- BX Chợ Lớn
# 67            01  Bến Thành- BX Chợ Lớn
# 68            01  Bến Thành- BX Chợ Lớn
# 69            01  Bến Thành- BX Chợ Lớn
# 70            01  Bến Thành- BX Chợ Lớn
# 71            01  Bến Thành- BX Chợ Lớn
# 72            01  Bến Thành- BX Chợ Lớn
# 73            01  Bến Thành- BX Chợ Lớn
# 74            01  Bến Thành- BX Chợ Lớn
# 75            01  Bến Thành- BX Chợ Lớn
# 76            01  Bến Thành- BX Chợ Lớn
# 77            01  Bến Thành- BX Chợ Lớn
# 78            01  Bến Thành- BX Chợ Lớn
# 79            01  Bến Thành- BX Chợ Lớn
# 80            01  Bến Thành- BX Chợ Lớn
# 81            01  Bến Thành- BX Chợ Lớn
# 82            01  Bến Thành- BX Chợ Lớn
# 83            01  Bến Thành- BX Chợ Lớn
# 84            01  Bến Thành- BX Chợ Lớn
# 85            01  Bến Thành- BX Chợ Lớn
# 86            01  Bến Thành- BX Chợ Lớn
# 87            01  Bến Thành- BX Chợ Lớn
# 88            01  Bến Thành- BX Chợ Lớn
# 89            01  Bến Thành- BX Chợ Lớn
# 90            01  Bến Thành- BX Chợ Lớn
# 91            01  Bến Thành- BX Chợ Lớn
# 92            01  Bến Thành- BX Chợ Lớn
# 93            01  Bến Thành- BX Chợ Lớn
# 94            01  Bến Thành- BX Chợ Lớn
# 95            01  Bến Thành- BX Chợ Lớn
# 96            01  Bến Thành- BX Chợ Lớn
# 97            01  Bến Thành- BX Chợ Lớn
# 98            01  Bến Thành- BX Chợ Lớn
# 99            01  Bến Thành- BX Chợ Lớn
# 100           01  Bến Thành- BX Chợ Lớn
# 101           01  Bến Thành- BX Chợ Lớn
# 102           01  Bến Thành- BX Chợ Lớn
# 103           01  Bến Thành- BX Chợ Lớn
# 104           01  Bến Thành- BX Chợ Lớn
# 105           01  Bến Thành- BX Chợ Lớn
# 106           01  Bến Thành- BX Chợ Lớn
# 107           01  Bến Thành- BX Chợ Lớn
# 108           01  Bến Thành- BX Chợ Lớn
# 109           01  Bến Thành- BX Chợ Lớn
# 110           01  Bến Thành- BX Chợ Lớn
# 111           01  Bến Thành- BX Chợ Lớn
# 112           01  Bến Thành- BX Chợ Lớn
# 113           01  Bến Thành- BX Chợ Lớn
# 114           01  Bến Thành- BX Chợ Lớn
# 115           01  Bến Thành- BX Chợ Lớn
# 116           01  Bến Thành- BX Chợ Lớn
# 117           01  Bến Thành- BX Chợ Lớn
# 118           01  Bến Thành- BX Chợ Lớn
# 119           01  Bến Thành- BX Chợ Lớn
# 120           01  Bến Thành- BX Chợ Lớn
# 121           01  Bến Thành- BX Chợ Lớn
# 122           01  Bến Thành- BX Chợ Lớn
# 123           01  Bến Thành- BX Chợ Lớn
# 124           01  Bến Thành- BX Chợ Lớn
# 125           01  Bến Thành- BX Chợ Lớn
# 126           01  Bến Thành- BX Chợ Lớn
# 127           01  Bến Thành- BX Chợ Lớn
# 128           01  Bến Thành- BX Chợ Lớn
# 129           01  Bến Thành- BX Chợ Lớn
# 130           01  Bến Thành- BX Chợ Lớn
# 131           01  Bến Thành- BX Chợ Lớn
# 132           01  Bến Thành- BX Chợ Lớn
# 133           01  Bến Thành- BX Chợ Lớn
# 134           01  Bến Thành- BX Chợ Lớn
# 135           01  Bến Thành- BX Chợ Lớn
# 136           01  Bến Thành- BX Chợ Lớn
# 137           01  Bến Thành- BX Chợ Lớn
# 138           01  Bến Thành- BX Chợ Lớn
# 139           01  Bến Thành- BX Chợ Lớn
# 140           01  Bến Thành- BX Chợ Lớn
# 141           01  Bến Thành- BX Chợ Lớn
# 142           01  Bến Thành- BX Chợ Lớn
# 143           01  Bến Thành- BX Chợ Lớn
# 144           01  Bến Thành- BX Chợ Lớn
# 145           01  Bến Thành- BX Chợ Lớn
# 146           01  Bến Thành- BX Chợ Lớn
# 147           01  Bến Thành- BX Chợ Lớn
# 148           01  Bến Thành- BX Chợ Lớn
# 149           01  Bến Thành- BX Chợ Lớn
# 150           01  Bến Thành- BX Chợ Lớn
# 151           01  Bến Thành- BX Chợ Lớn
# 152           01  Bến Thành- BX Chợ Lớn
# 153           01  Bến Thành- BX Chợ Lớn
# 154           01  Bến Thành- BX Chợ Lớn
# 155           01  Bến Thành- BX Chợ Lớn
# 156           01  Bến Thành- BX Chợ Lớn
# 157           01  Bến Thành- BX Chợ Lớn
# 158           01  Bến Thành- BX Chợ Lớn
# 159           01  Bến Thành- BX Chợ Lớn
# 160           01  Bến Thành- BX Chợ Lớn
# 161           01  Bến Thành- BX Chợ Lớn
# 162           01  Bến Thành- BX Chợ Lớn
# 163           01  Bến Thành- BX Chợ Lớn
# 164           01  Bến Thành- BX Chợ Lớn
# 165           01  Bến Thành- BX Chợ Lớn
# 166           01  Bến Thành- BX Chợ Lớn
# 167           01  Bến Thành- BX Chợ Lớn
# 168           01  Bến Thành- BX Chợ Lớn
# 169           01  Bến Thành- BX Chợ Lớn
# 170           01  Bến Thành- BX Chợ Lớn
# 171           01  Bến Thành- BX Chợ Lớn
# 172           01  Bến Thành- BX Chợ Lớn
# 173           01  Bến Thành- BX Chợ Lớn
# 174           01  Bến Thành- BX Chợ Lớn
# 175           01  Bến Thành- BX Chợ Lớn
# 176           01  Bến Thành- BX Chợ Lớn
# 177           01  Bến Thành- BX Chợ Lớn
# 178           01  Bến Thành- BX Chợ Lớn
# 179           01  Bến Thành- BX Chợ Lớn
# 180           01  Bến Thành- BX Chợ Lớn
# 181           01  Bến Thành- BX Chợ Lớn
# 182           01  Bến Thành- BX Chợ Lớn
# 183           01  Bến Thành- BX Chợ Lớn
# 184           01  Bến Thành- BX Chợ Lớn
# 185           01  Bến Thành- BX Chợ Lớn
# 186           01  Bến Thành- BX Chợ Lớn
# 187           01  Bến Thành- BX Chợ Lớn
# 188           01  Bến Thành- BX Chợ Lớn
# 189           01  Bến Thành- BX Chợ Lớn
# 190           01  Bến Thành- BX Chợ Lớn
# 191           01  Bến Thành- BX Chợ Lớn
# 192           01  Bến Thành- BX Chợ Lớn
# 193           01  Bến Thành- BX Chợ Lớn
# 194           01  Bến Thành- BX Chợ Lớn
# 195           01  Bến Thành- BX Chợ Lớn
# 196           01  Bến Thành- BX Chợ Lớn
# 197           01  Bến Thành- BX Chợ Lớn
# 198           01  Bến Thành- BX Chợ Lớn
# 199           01  Bến Thành- BX Chợ Lớn
# 200           01  Bến Thành- BX Chợ Lớn
# 201           01  Bến Thành- BX Chợ Lớn
# 202           01  Bến Thành- BX Chợ Lớn
# 203           01  Bến Thành- BX Chợ Lớn
# 204           01  Bến Thành- BX Chợ Lớn
# 205           01  Bến Thành- BX Chợ Lớn
# 206           01  Bến Thành- BX Chợ Lớn
# 207           01  Bến Thành- BX Chợ Lớn
# 208           01  Bến Thành- BX Chợ Lớn
# 209           01  Bến Thành- BX Chợ Lớn
# 210           01  Bến Thành- BX Chợ Lớn
# 211           01  Bến Thành- BX Chợ Lớn
# 212           01  Bến Thành- BX Chợ Lớn
# 213           01  Bến Thành- BX Chợ Lớn
# 214           01  Bến Thành- BX Chợ Lớn
# 215           01  Bến Thành- BX Chợ Lớn
# 216           01  Bến Thành- BX Chợ Lớn
# 217           01  Bến Thành- BX Chợ Lớn
# 218           01  Bến Thành- BX Chợ Lớn
# 219           01  Bến Thành- BX Chợ Lớn
# 220           01  Bến Thành- BX Chợ Lớn
# 221           01  Bến Thành- BX Chợ Lớn
# 222           01  Bến Thành- BX Chợ Lớn
# 223           01  Bến Thành- BX Chợ Lớn
# 224           01  Bến Thành- BX Chợ Lớn
# 225           01  Bến Thành- BX Chợ Lớn
# 226           01  Bến Thành- BX Chợ Lớn
# 227           01  Bến Thành- BX Chợ Lớn
# 228           01  Bến Thành- BX Chợ Lớn
# 229           01  Bến Thành- BX Chợ Lớn
# 230           01  Bến Thành- BX Chợ Lớn
# 231           01  Bến Thành- BX Chợ Lớn
# 232           01  Bến Thành- BX Chợ Lớn
# 233           01  Bến Thành- BX Chợ Lớn
# 234           01  Bến Thành- BX Chợ Lớn
# 235           01  Bến Thành- BX Chợ Lớn
# 236           01  Bến Thành- BX Chợ Lớn
# 237           01  Bến Thành- BX Chợ Lớn
# 238           01  Bến Thành- BX Chợ Lớn
# 239           01  Bến Thành- BX Chợ Lớn
# 240           01  Bến Thành- BX Chợ Lớn
# 241           01  Bến Thành- BX Chợ Lớn
# 242           01  Bến Thành- BX Chợ Lớn
# 243           01  Bến Thành- BX Chợ Lớn
# 244           01  Bến Thành- BX Chợ Lớn
# 245           01  Bến Thành- BX Chợ Lớn
# 246           01  Bến Thành- BX Chợ Lớn
# 247           01  Bến Thành- BX Chợ Lớn
# 248           01  Bến Thành- BX Chợ Lớn
# 249           01  Bến Thành- BX Chợ Lớn
# 250           01  Bến Thành- BX Chợ Lớn
# 251           01  Bến Thành- BX Chợ Lớn
# 252           01  Bến Thành- BX Chợ Lớn
# 253           01  Bến Thành- BX Chợ Lớn
# 254           01  Bến Thành- BX Chợ Lớn
# 255           01  Bến Thành- BX Chợ Lớn
# 256           01  Bến Thành- BX Chợ Lớn
# 257           01  Bến Thành- BX Chợ Lớn
# 258           01  Bến Thành- BX Chợ Lớn
# 259           01  Bến Thành- BX Chợ Lớn
# 260           01  Bến Thành- BX Chợ Lớn
# 261           01  Bến Thành- BX Chợ Lớn
# 262           01  Bến Thành- BX Chợ Lớn
# 263           01  Bến Thành- BX Chợ Lớn
# 264           01  Bến Thành- BX Chợ Lớn
# 265           01  Bến Thành- BX Chợ Lớn
# 266           01  Bến Thành- BX Chợ Lớn
# 267           01  Bến Thành- BX Chợ Lớn
# 268           01  Bến Thành- BX Chợ Lớn
# 269           01  Bến Thành- BX Chợ Lớn
# 270           01  Bến Thành- BX Chợ Lớn
# 271           01  Bến Thành- BX Chợ Lớn
# 272           01  Bến Thành- BX Chợ Lớn
# 273           01  Bến Thành- BX Chợ Lớn
# 274           01  Bến Thành- BX Chợ Lớn
# 275           01  Bến Thành- BX Chợ Lớn
# 276           01  Bến Thành- BX Chợ Lớn
# 277           01  Bến Thành- BX Chợ Lớn
# 278           01  Bến Thành- BX Chợ Lớn
# 279           01  Bến Thành- BX Chợ Lớn
# 280           01  Bến Thành- BX Chợ Lớn
# 281           01  Bến Thành- BX Chợ Lớn
# 282           01  Bến Thành- BX Chợ Lớn
# 283           01  Bến Thành- BX Chợ Lớn
# 284           01  Bến Thành- BX Chợ Lớn
# 285           01  Bến Thành- BX Chợ Lớn
# 286           01  Bến Thành- BX Chợ Lớn
# 287           01  Bến Thành- BX Chợ Lớn
# 288           01  Bến Thành- BX Chợ Lớn
# 289           01  Bến Thành- BX Chợ Lớn
# 290           01  Bến Thành- BX Chợ Lớn
# 291           01  Bến Thành- BX Chợ Lớn
# 292           01  Bến Thành- BX Chợ Lớn
# 293           01  Bến Thành- BX Chợ Lớn
# 294           01  Bến Thành- BX Chợ Lớn
# 295           01  Bến Thành- BX Chợ Lớn
# 296           01  Bến Thành- BX Chợ Lớn
# 297           01  Bến Thành- BX Chợ Lớn
# 298           01  Bến Thành- BX Chợ Lớn
# 299           01  Bến Thành- BX Chợ Lớn
#
#                                                   URL  \
# 0    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 1    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 2    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 3    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 4    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 5    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 6    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 7    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 8    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 9    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 10   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 11   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 12   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 13   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 14   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 15   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 16   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 17   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 18   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 19   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 20   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 21   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 22   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 23   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 24   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 25   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 26   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 27   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 28   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 29   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 30   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 31   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 32   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 33   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 34   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 35   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 36   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 37   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 38   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 39   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 40   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 41   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 42   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 43   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 44   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 45   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 46   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 47   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 48   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 49   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 50   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 51   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 52   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 53   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 54   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 55   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 56   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 57   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 58   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 59   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 60   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 61   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 62   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 63   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 64   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 65   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 66   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 67   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 68   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 69   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 70   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 71   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 72   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 73   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 74   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 75   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 76   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 77   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 78   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 79   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 80   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 81   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 82   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 83   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 84   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 85   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 86   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 87   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 88   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 89   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 90   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 91   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 92   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 93   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 94   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 95   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 96   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 97   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 98   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 99   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 100  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 101  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 102  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 103  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 104  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 105  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 106  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 107  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 108  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 109  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 110  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 111  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 112  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 113  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 114  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 115  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 116  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 117  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 118  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 119  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 120  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 121  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 122  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 123  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 124  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 125  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 126  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 127  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 128  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 129  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 130  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 131  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 132  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 133  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 134  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 135  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 136  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 137  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 138  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 139  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 140  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 141  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 142  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 143  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 144  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 145  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 146  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 147  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 148  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 149  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 150  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 151  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 152  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 153  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 154  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 155  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 156  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 157  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 158  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 159  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 160  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 161  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 162  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 163  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 164  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 165  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 166  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 167  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 168  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 169  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 170  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 171  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 172  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 173  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 174  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 175  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 176  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 177  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 178  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 179  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 180  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 181  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 182  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 183  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 184  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 185  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 186  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 187  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 188  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 189  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 190  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 191  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 192  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 193  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 194  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 195  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 196  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 197  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 198  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 199  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 200  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 201  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 202  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 203  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 204  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 205  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 206  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 207  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 208  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 209  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 210  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 211  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 212  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 213  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 214  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 215  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 216  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 217  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 218  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 219  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 220  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 221  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 222  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 223  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 224  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 225  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 226  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 227  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 228  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 229  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 230  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 231  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 232  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 233  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 234  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 235  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 236  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 237  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 238  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 239  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 240  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 241  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 242  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 243  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 244  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 245  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 246  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 247  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 248  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 249  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 250  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 251  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 252  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 253  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 254  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 255  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 256  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 257  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 258  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 259  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 260  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 261  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 262  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 263  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 264  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 265  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 266  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 267  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 268  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 269  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 270  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 271  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 272  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 273  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 274  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 275  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 276  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 277  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 278  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 279  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 280  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 281  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 282  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 283  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 284  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 285  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 286  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 287  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 288  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 289  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 290  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 291  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 292  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 293  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 294  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 295  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 296  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 297  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 298  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# 299  https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
#
#                                                           Direction  \
# 0                                                        BX Chợ Lớn
# 1                                                        BX Chợ Lớn
# 2                                                        BX Chợ Lớn
# 3                                                        BX Chợ Lớn
# 4                                                        BX Chợ Lớn
# 5                                                        BX Chợ Lớn
# 6                                                        BX Chợ Lớn
# 7                                                        BX Chợ Lớn
# 8                                                        BX Chợ Lớn
# 9                                                        BX Chợ Lớn
# 10                                                       BX Chợ Lớn
# 11                                                       BX Chợ Lớn
# 12                                                       BX Chợ Lớn
# 13                                                       BX Chợ Lớn
# 14                                                       BX Chợ Lớn
# 15                                                       BX Chợ Lớn
# 16                                                       BX Chợ Lớn
# 17                                                       BX Chợ Lớn
# 18                                                       BX Chợ Lớn
# 19                                                       BX Chợ Lớn
# 20                                                       BX Chợ Lớn
# 21                                                       BX Chợ Lớn
# 22                                                       BX Chợ Lớn
# 23                                                       BX Chợ Lớn
# 24                                                       BX Chợ Lớn
# 25                                                       BX Chợ Lớn
# 26                                                       BX Chợ Lớn
# 27                                                       BX Chợ Lớn
# 28                                                       BX Chợ Lớn
# 29                                                        Bến Thành
# 30                                                        Bến Thành
# 31                                                        Bến Thành
# 32                                                        Bến Thành
# 33                                                        Bến Thành
# 34                                                        Bến Thành
# 35                                                        Bến Thành
# 36                                                        Bến Thành
# 37                                                        Bến Thành
# 38                                                        Bến Thành
# 39                                                        Bến Thành
# 40                                                        Bến Thành
# 41                                                        Bến Thành
# 42                                                        Bến Thành
# 43                                                        Bến Thành
# 44                                                        Bến Thành
# 45                                                        Bến Thành
# 46                                                        Bến Thành
# 47                                                        Bến Thành
# 48                                                        Bến Thành
# 49                                                        Bến Thành
# 50                                                        Bến Thành
# 51                                                        Bến Thành
# 52                                                        Bến Thành
# 53                                                        Bến Thành
# 54                                                        Bến Thành
# 55                                                        Bến Thành
# 56                                                        Bến Thành
# 57                                                        Bến Thành
# 58                                                        Bến Thành
# 59                                                        Bến Thành
# 60                                                        Bến Thành
# 61                                                        Bến Thành
# 62                                                        Bến Thành
# 63                                                        Bến Thành
# 64   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 65   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 66   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 67   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 68   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 69   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 70   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 71   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 72   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 73   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 74   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 75   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 76   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 77   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 78   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 79   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 80   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 81   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 82   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 83   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 84   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 85   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 86   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 87   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 88   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 89   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 90   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 91   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 92   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 93   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 94   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 95   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 96   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 97   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 98   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 99   BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 100  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 101  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 102  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 103  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 104  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 105  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 106  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 107  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 108  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 109  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 110  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 111  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 112  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 113  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 114  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 115  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 116  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 117  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 118  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 119  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 120  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 121  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 122  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 123  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 124  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 125  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 126  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 127  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 128  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 129  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 130  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 131  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 132  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 133  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 134  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 135  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 136  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 137  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 138  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 139  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 140  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 141  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 142  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 143  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 144  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 145  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 146  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 147  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 148  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 149  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 150  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 151  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 152  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 153  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 154  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 155  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 156  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 157  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 158  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 159  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 160  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 161  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 162  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 163  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 164  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 165  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 166  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 167  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 168  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 169  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 170  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 171  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 172  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 173  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 174  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 175  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 176  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 177  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 178  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 179  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 180  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 181  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 182  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 183  BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 184   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 185   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 186   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 187   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 188   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 189   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 190   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 191   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 192   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 193   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 194   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 195   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 196   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 197   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 198   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 199   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 200   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 201   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 202   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 203   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 204   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 205   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 206   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 207   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 208   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 209   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 210   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 211   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 212   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 213   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 214   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 215   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 216   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 217   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 218   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 219   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 220   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 221   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 222   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 223   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 224   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 225   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 226   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 227   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 228   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 229   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 230   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 231   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 232   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 233   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 234   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 235   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 236   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 237   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 238   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 239   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 240   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 241   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 242   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 243   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 244   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 245   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 246   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 247   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 248   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 249   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 250   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# ...
# 296   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 297   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 298   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
# 299   Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#
#     Stop_Order                          Stop_Name
# 0            A                Công Trường Mê Linh
# 1            1                      Bến Bạch Đằng
# 2            2             Cục Hải Quan Thành Phố
# 3            3                             Chợ Cũ
# 4            4                   Trường Cao Thắng
# 5            5                  Công ty Đường sắt
# 6            6                      Bến Thành B
# 7            7              Trường Ernst Thalmann
# 8            8                  KTX Trần Hưng Đạo
# 9            9                       Rạp Hưng Đạo
# 10          10             Bệnh viện Răng Hàm Mặt
# 11          11                       Trần Đình Xu
# 12          12                     Tổng Cty Samco
# 13          13                          Chợ Nanci
# 14          14                        Nguyễn Biểu
# 15          15  Trường Cao đẳng Kinh tế Đối ngoại
# 16          16                    Trần Bình Trọng
# 17          17   Bệnh viện Chấn thương Chỉnh hình
# 18          18                      Rạp Đồng Tháp
# 19          19                        Rạp Đống Đa
# 20          20                         Đồng Khánh
# 21          21                 Nhà Văn hóa Quận 5
# 22          22                          Ngô Quyền
# 23          23                             Tản Đà
# 24          24                   Triệu Quang Phục
# 25          25                    Bưu điện Quận 5
# 26          26                 Hải Thượng Lãn Ông
# 27          27                       Chợ Kim Biên
# 28           B                     Bến xe Chợ Lớn
# 29           A                     Bến xe Chợ Lớn
# 30           1                         Chu Văn An
# 31           2                          Tháp Mười
# 32           3                       Chợ Kim Biên
# 33           4                    Bưu điện Quận 5
# 34           5                      Rạp Đại Quang
# 35           6                      Lương Nhữ Học
# 36           7                   Triệu Quang Phục
# 37           8   Đại học Sư phạm Thể dục thể thao
# 38           9          Siêu thị Điện máy Chợ Lớn
# 39          10                          Ngô Quyền
# 40          11               Chung cư Nguyễn Trãi
# 41          12                  Siêu thị Điện máy
# 42          13                 Nhà Văn hóa Quận 5
# 43          14                         Đồng Khánh
# 44          15                            An Bình
# 45          16                      Rạp Đồng Tháp
# 46          17   Bệnh viện Chấn Thương Chỉnh hình
# 47          18                    Trần Bình Trọng
# 48          19                        Nguyễn Biểu
# 49          20                          Chợ Nanci
# 50          21                     Tổng Cty Samco
# 51          22                            Sở PCCC
# 52          23                         Hồ Hảo Hớn
# 53          24             Bệnh Viện Răng Hàm Mặt
# 54          25                  Rạp Trần Hưng Đạo
# 55          26                  KTX Trần Hưng Đạo
# 56          27                         Nguyễn Kim
# 57          28                      Bến Thành E
# 58          29                           Hàm Nghi
# 59          30                             Chợ Củ
# 60          31                        Hồ Tùng Mậu
# 61          32                      Bến Bạch Đằng
# 62          33                Công Trường Mê Linh
# 63           B                Công Trường Mê Linh
# 64           1                      05:00 - 05:35
# 65           2                      05:10 - 05:45
# 66           3                      05:20 - 05:55
# 67           4                      05:30 - 06:05
# 68           5                      05:38 - 06:13
# 69           6                      05:46 - 06:21
# 70           7                      05:54 - 06:29
# 71           8                      06:02 - 06:37
# 72           9                      06:08 - 06:43
# 73          10                      06:14 - 06:49
# 74          11                      06:20 - 06:55
# 75          12                      06:26 - 07:01
# 76          13                      06:32 - 07:07
# 77          14                      06:38 - 07:13
# 78          15                      06:44 - 07:19
# 79          16                      06:50 - 07:25
# 80          17                      06:56 - 07:31
# 81          18                      07:02 - 07:37
# 82          19                      07:08 - 07:43
# 83          20                      07:14 - 07:49
# 84          21                      07:22 - 07:57
# 85          22                      07:30 - 08:05
# 86          23                      07:38 - 08:13
# 87          24                      07:46 - 08:21
# 88          25                      07:54 - 08:29
# 89          26                      08:02 - 08:37
# 90          27                      08:10 - 08:45
# 91          28                      08:18 - 08:53
# 92          29                      08:26 - 09:01
# 93          30                      08:34 - 09:09
# 94          31                      08:42 - 09:17
# 95          32                      08:50 - 09:25
# 96          33                      08:58 - 09:33
# 97          34                      09:06 - 09:41
# 98          35                      09:14 - 09:49
# 99          36                      09:22 - 09:57
# 100         37                      09:30 - 10:05
# 101         38                      09:38 - 10:13
# 102         39                      09:46 - 10:21
# 103         40                      09:54 - 10:29
# 104         41                      10:02 - 10:37
# 105         42                      10:10 - 10:45
# 106         43                      10:18 - 10:53
# 107         44                      10:24 - 10:59
# 108         45                      10:30 - 11:05
# 109         46                      10:36 - 11:11
# 110         47                      10:42 - 11:17
# 111         48                      10:48 - 11:23
# 112         49                      10:54 - 11:29
# 113         50                      11:00 - 11:35
# 114         51                      11:06 - 11:41
# 115         52                      11:12 - 11:47
# 116         53                      11:18 - 11:53
# 117         54                      11:26 - 12:01
# 118         55                      11:34 - 12:09
# 119         56                      11:42 - 12:17
# 120         57                      11:50 - 12:25
# 121         58                      11:58 - 12:33
# 122         59                      12:06 - 12:41
# 123         60                      12:16 - 12:51
# 124         61                      12:26 - 13:01
# 125         62                      12:36 - 13:11
# 126         63                      12:46 - 13:21
# 127         64                      12:56 - 13:31
# 128         65                      13:06 - 13:41
# 129         66                      13:14 - 13:49
# 130         67                      13:22 - 13:57
# 131         68                      13:30 - 14:05
# 132         69                      13:38 - 14:13
# 133         70                      13:46 - 14:21
# 134         71                      13:54 - 14:29
# 135         72                      14:02 - 14:37
# 136         73                      14:10 - 14:45
# 137         74                      14:18 - 14:53
# 138         75                      14:26 - 15:01
# 139         76                      14:34 - 15:09
# 140         77                      14:42 - 15:17
# 141         78                      14:50 - 15:25
# 142         79                      14:58 - 15:33
# 143         80                      15:06 - 15:41
# 144         81                      15:14 - 15:49
# 145         82                      15:22 - 15:57
# 146         83                      15:30 - 16:05
# 147         84                      15:38 - 16:13
# 148         85                      15:46 - 16:21
# 149         86                      15:54 - 16:29
# 150         87                      16:02 - 16:37
# 151         88                      16:08 - 16:43
# 152         89                      16:14 - 16:49
# 153         90                      16:20 - 16:55
# 154         91                      16:26 - 17:01
# 155         92                      16:32 - 17:07
# 156         93                      16:38 - 17:13
# 157         94                      16:44 - 17:19
# 158         95                      16:50 - 17:25
# 159         96                      16:56 - 17:31
# 160         97                      17:02 - 17:37
# 161         98                      17:08 - 17:43
# 162         99                      17:14 - 17:49
# 163        100                      17:22 - 17:57
# 164        101                      17:30 - 18:05
# 165        102                      17:38 - 18:13
# 166        103                      17:46 - 18:21
# 167        104                      17:54 - 18:29
# 168        105                      18:02 - 18:37
# 169        106                      18:10 - 18:45
# 170        107                      18:20 - 18:55
# 171        108                      18:30 - 19:05
# 172        109                      18:40 - 19:15
# 173        110                      18:50 - 19:25
# 174        111                      19:00 - 19:35
# 175        112                      19:10 - 19:45
# 176        113                      19:20 - 19:55
# 177        114                      19:30 - 20:05
# 178        115                      19:40 - 20:15
# 179        116                      19:50 - 20:25
# 180        117                      20:00 - 20:35
# 181        118                      20:10 - 20:45
# 182        119                      20:20 - 20:55
# 183        120                      20:30 - 21:05
# 184          1                      05:00 - 05:30
# 185          2                      05:10 - 05:40
# 186          3                      05:20 - 05:50
# 187          4                      05:30 - 06:00
# 188          5                      05:40 - 06:10
# 189          6                      05:48 - 06:18
# 190          7                      05:56 - 06:26
# 191          8                      06:04 - 06:34
# 192          9                      06:12 - 06:42
# 193         10                      06:20 - 06:50
# 194         11                      06:26 - 06:56
# 195         12                      06:32 - 07:02
# 196         13                      06:38 - 07:08
# 197         14                      06:44 - 07:14
# 198         15                      06:50 - 07:20
# 199         16                      06:56 - 07:26
# 200         17                      07:02 - 07:32
# 201         18                      07:08 - 07:38
# 202         19                      07:14 - 07:44
# 203         20                      07:20 - 07:50
# 204         21                      07:28 - 07:58
# 205         22                      07:36 - 08:06
# 206         23                      07:44 - 08:14
# 207         24                      07:52 - 08:22
# 208         25                      08:00 - 08:30
# 209         26                      08:08 - 08:38
# 210         27                      08:16 - 08:46
# 211         28                      08:24 - 08:54
# 212         29                      08:32 - 09:02
# 213         30                      08:40 - 09:10
# 214         31                      08:48 - 09:18
# 215         32                      08:56 - 09:26
# 216         33                      09:04 - 09:34
# 217         34                      09:12 - 09:42
# 218         35                      09:20 - 09:50
# 219         36                      09:28 - 09:58
# 220         37                      09:36 - 10:06
# 221         38                      09:44 - 10:14
# 222         39                      09:52 - 10:22
# 223         40                      10:00 - 10:30
# 224         41                      10:08 - 10:38
# 225         42                      10:16 - 10:46
# 226         43                      10:24 - 10:54
# 227         44                      10:30 - 11:00
# 228         45                      10:36 - 11:06
# 229         46                      10:42 - 11:12
# 230         47                      10:48 - 11:18
# 231         48                      10:54 - 11:24
# 232         49                      11:00 - 11:30
# 233         50                      11:06 - 11:36
# 234         51                      11:12 - 11:42
# 235         52                      11:18 - 11:48
# 236         53                      11:24 - 11:54
# 237         54                      11:32 - 12:02
# 238         55                      11:40 - 12:10
# 239         56                      11:48 - 12:18
# 240         57                      11:56 - 12:26
# 241         58                      12:04 - 12:34
# 242         59                      12:14 - 12:44
# 243         60                      12:24 - 12:54
# 244         61                      12:34 - 13:04
# 245         62                      12:44 - 13:14
# 246         63                      12:54 - 13:24
# 247         64                      13:04 - 13:34
# 248         65                      13:14 - 13:44
# 249         66                      13:22 - 13:52
# 250         67                      13:30 - 14:00
# 251         68                      13:38 - 14:08
# 252         69                      13:46 - 14:16
# 253         70                      13:54 - 14:24
# 254         71                      14:02 - 14:32
# 255         72                      14:10 - 14:40
# 256         73                      14:18 - 14:48
# 257         74                      14:26 - 14:56
# 258         75                      14:34 - 15:04
# 259         76                      14:42 - 15:12
# 260         77                      14:50 - 15:20
# 261         78                      14:58 - 15:28
# 262         79                      15:06 - 15:36
# 263         80                      15:14 - 15:44
# 264         81                      15:22 - 15:52
# 265         82                      15:30 - 16:00
# 266         83                      15:38 - 16:08
# 267         84                      15:46 - 16:16
# 268         85                      15:54 - 16:24
# 269         86                      16:02 - 16:32
# 270         87                      16:08 - 16:38
# 271         88                      16:14 - 16:44
# 272         89                      16:20 - 16:50
# 273         90                      16:26 - 16:56
# 274         91                      16:32 - 17:02
# 275         92                      16:38 - 17:08
# 276         93                      16:44 - 17:14
# 277         94                      16:50 - 17:20
# 278         95                      16:56 - 17:26
# 279         96                      17:02 - 17:32
# 280         97                      17:08 - 17:38
# 281         98                      17:14 - 17:44
# 282         99                      17:20 - 17:50
# 283        100                      17:28 - 17:58
# 284        101                      17:36 - 18:06
# 285        102                      17:44 - 18:14
# 286        103                      17:52 - 18:22
# 287        104                      18:00 - 18:30
# 288        105                      18:08 - 18:38
# 289        106                      18:16 - 18:46
# 290        107                      18:24 - 18:54
# 291        108                      18:32 - 19:02
# 292        109                      18:40 - 19:10
# 293        110                      18:50 - 19:20
# 294        111                      19:00 - 19:30
# 295        112                      19:10 - 19:40
# 296        113                      19:20 - 19:50
# 297        114                      19:30 - 20:00
# 298        115                      19:40 - 20:10
# 299        116                      19:50 - 20:20

# %%
import requests
from bs4 import BeautifulSoup
import html
import pandas as pd
import time
import re  # Để parse thời gian

# Đọc file CSV đã tạo trước đó
csv_filename = 'tuyen_xe_buyt.csv'
try:
    df = pd.read_csv(csv_filename)
    print(f"Đã đọc thành công {len(df)} tuyến từ file {csv_filename}")
except FileNotFoundError:
    print(f"Không tìm thấy file {csv_filename}. Vui lòng chạy code scrape URL trước!")
    exit()

# Danh sách để lưu dữ liệu
route_stops_data = []      # Cho lộ trình (stops)
timetable_data = []        # Cho biểu đồ giờ (timetable)

# Giới hạn số tuyến để test (bỏ comment nếu muốn scrape tất cả)
df = df.head(5)  # Chỉ scrape 5 tuyến đầu để test nhanh
print(f"Test với {len(df)} tuyến đầu tiên...")

print(f"Bắt đầu scrape lộ trình + timetable cho {len(df)} tuyến...")

# Duyệt qua từng hàng trong DataFrame
for index, row in df.iterrows():
    route_number = row['Route_Number']
    route_name = row['Route_Name']
    url = row['URL']

    print(f"\n--- Đang scrape tuyến {route_number}: {route_name} ---")
    print(f"URL: {url}")

    try:
        # Gửi yêu cầu HTTP
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        response = requests.get(url, headers=headers)
        response.raise_for_status()

        # Giải mã HTML
        html_content = html.unescape(response.text)
        soup = BeautifulSoup(html_content, 'html.parser')
        print(f"✅ Đã parse HTML. Độ dài: {len(response.text)}")

        # PHẦN 1: EXTRACT LỘ TRÌNH (STOPS) - Giữ nguyên logic của bạn
        print("  --- Extract lộ trình ---")
        stops_this_route = []  # Stops tạm cho tuyến này
        current_direction = None

        # Duyệt h3 và table cho lộ trình (thường ở #lotrinh)
        lotrinh_div = soup.find('div', id='lotrinh') or soup  # Fallback nếu không có id
        for element in lotrinh_div.find_all(['h3', 'table']) if lotrinh_div else soup.find_all(['h3', 'table']):
            if element.name == 'h3':
                header_text = element.get_text(strip=True)
                if "Đi" in header_text:
                    current_direction = header_text.replace("Đi ", "").strip()
                    print(f"    Hướng: {current_direction}")
            elif element.name == 'table' and current_direction:
                rows = element.find_all('tr')
                stop_count = 0
                for row in rows:
                    cols = row.find_all('td')
                    if len(cols) >= 2:
                        # Thứ tự stop
                        order_col = cols[0].find('div')
                        stop_order = order_col.get_text(strip=True) if order_col else str(stop_count + 1)

                        # Tên stop
                        stop_name = cols[1].get_text(strip=True)

                        if stop_name:
                            stops_this_route.append({
                                'Route_Number': route_number,
                                'Route_Name': route_name,
                                'URL': url,
                                'Direction': current_direction,
                                'Stop_Order': stop_order,
                                'Stop_Name': stop_name
                            })
                            stop_count += 1
                            if stop_count <= 2:  # Preview 2 stops
                                print(f"      {stop_order}: {stop_name}")

                print(f"    ✅ {stop_count} stops cho '{current_direction}'")

        route_stops_data.extend(stops_this_route)
        print(f"  ✅ Tổng stops tuyến này: {len(stops_this_route)}")

        # PHẦN 2: EXTRACT BIỂU ĐỒ GIỜ (TIMETABLE) - Parse table có thời gian
        print("  --- Extract timetable ---")
        timetable_this_route = []  # Timetable tạm cho tuyến này

        # Tìm tất cả table (timetable thường là table sau lộ trình, có text giờ)
        all_tables = soup.find_all('table')
        for table in all_tables:
            rows = table.find_all('tr')
            for row in rows:
                cols = row.find_all('td')
                if len(cols) >= 4:  # Giả sử timetable có >=4 cột: Stop_Order, Stop_Name, ..., Thời gian
                    # Lấy Stop_Order (cột 1, thường số)
                    stop_order = cols[0].get_text(strip=True) if cols[0] else ''

                    # Lấy Stop_Name (cột 2)
                    stop_name = cols[1].get_text(strip=True) if len(cols) > 1 else ''

                    # Tìm thời gian ở các cột sau (pattern HH:MM-HH:MM hoặc HH:MM)
                    time_text = ''
                    for col in cols[2:]:  # Từ cột 3 trở đi
                        col_text = col.get_text(strip=True)
                        # Regex match thời gian (e.g., "05:00-05:35", "05:00")
                        time_match = re.search(r'\d{2}:\d{2}(-\d{2}:\d{2})?', col_text)
                        if time_match:
                            time_text = time_match.group(0)
                            break

                    if stop_name and time_text:  # Chỉ lấy nếu có stop và thời gian
                        # Direction fallback (dùng hướng từ lộ trình gần nhất, hoặc default)
                        direction = current_direction or "Không xác định"

                        timetable_this_route.append({
                            'Route_Number': route_number,
                            'Route_Name': route_name,
                            'URL': url,
                            'Direction': direction,
                            'Stop_Order': stop_order,
                            'Stop_Name': stop_name,
                            'Departure_Time': time_text  # e.g., "05:00-05:35"
                        })

                        print(f"      {stop_order} - {stop_name}: {time_text}")

        timetable_data.extend(timetable_this_route)
        print(f"  ✅ Tổng timetable rows tuyến này: {len(timetable_this_route)}")

    except requests.exceptions.RequestException as e:
        print(f"❌ Lỗi HTTP: {e}")
    except Exception as e:
        print(f"❌ Lỗi xử lý: {e}")
        import traceback
        traceback.print_exc()

    time.sleep(2)  # Delay

print(f"\n--- Kết thúc scrape ---")
print(f"- Tổng stops (lộ trình): {len(route_stops_data)}")
print(f"- Tổng rows (timetable): {len(timetable_data)}")

# Lưu file lộ trình (chỉ stops)
if route_stops_data:
    lotrinh_df = pd.DataFrame(route_stops_data)
    lotrinh_df.to_csv('tuyen_xe_buyt_lotrinh.csv', index=False, encoding='utf-8')
    print(f"✅ Lưu lộ trình vào tuyen_xe_buyt_lotrinh.csv")
    print(lotrinh_df.head(10).to_string(index=False))  # Preview

# Lưu file timetable (chỉ giờ)
if timetable_data:
    timetable_df = pd.DataFrame(timetable_data)
    timetable_df.to_csv('tuyen_xe_buyt_timetable.csv', index=False, encoding='utf-8')
    print(f"✅ Lưu timetable vào tuyen_xe_buyt_timetable.csv")
    print(timetable_df.head(10).to_string(index=False))  # Preview
else:
    print("❌ Không có timetable data (có thể table giờ không match pattern).")
# Out:
# Đã đọc thành công 140 tuyến từ file tuyen_xe_buyt.csv
# Test với 5 tuyến đầu tiên...
# Bắt đầu scrape lộ trình + timetable cho 5 tuyến...
#
# --- Đang scrape tuyến 01: Bến Thành- BX Chợ Lớn ---
# URL: https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# ✅ Đã parse HTML. Độ dài: 52658
#   --- Extract lộ trình ---
#     Hướng: BX Chợ Lớn
#       A: Công Trường Mê Linh
#       1: Bến Bạch Đằng
#     ✅ 29 stops cho 'BX Chợ Lớn'
#     Hướng: Bến Thành
#       A: Bến xe Chợ Lớn
#       1: Chu Văn An
#     ✅ 35 stops cho 'Bến Thành'
#   ✅ Tổng stops tuyến này: 64
#   --- Extract timetable ---
#   ✅ Tổng timetable rows tuyến này: 0
#
# --- Đang scrape tuyến 02: Bến Thành- BX Miền Tây ---
# URL: https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html
# ✅ Đã parse HTML. Độ dài: 52394
#   --- Extract lộ trình ---
#     Hướng: BX Miền Tây
#       A: Công Trường Mê Linh
#       1: Bến Bạch Đằng
#     ✅ 43 stops cho 'BX Miền Tây'
#     Hướng: Bến Thành
#       A: Bến xe Miền Tây
#       1: 49-51 (317), Kinh Dương Vương
#     ✅ 37 stops cho 'Bến Thành'
#   ✅ Tổng stops tuyến này: 80
#   --- Extract timetable ---
#   ✅ Tổng timetable rows tuyến này: 0
#
# --- Đang scrape tuyến 03: Bến Thành- Thạnh Lộc ---
# URL: https://xebuyt.net/ben-thanh-thanh-loc.html
# ✅ Đã parse HTML. Độ dài: 67605
#   --- Extract lộ trình ---
#     Hướng: Thạnh Lộc
#       A: TĐH xe buýt Sài Gòn
#       1: Tôn Thất Tùng
#     ✅ 48 stops cho 'Thạnh Lộc'
#     Hướng: Bến Thành
#       A: THẠNH LỘC
#       1: Trường Điện Lực 2
#     ✅ 48 stops cho 'Bến Thành'
#   ✅ Tổng stops tuyến này: 96
#   --- Extract timetable ---
#   ✅ Tổng timetable rows tuyến này: 0
#
# --- Đang scrape tuyến 04: Bến Thành- Cộng Hòa- An Sương ---
# URL: https://xebuyt.net/ben-thanh-cong-hoa-an-suong.html
# ✅ Đã parse HTML. Độ dài: 65800
#   --- Extract lộ trình ---
#     Hướng: An Sương
#       A: TĐH xe buýt Sài Gòn
#       1: Tôn Thất Tùng
#     ✅ 50 stops cho 'An Sương'
#     Hướng: Bến Thành
#       A: Bến xe An Sương
#       1: Chợ Chiều
#     ✅ 41 stops cho 'Bến Thành'
#   ✅ Tổng stops tuyến này: 91
#   --- Extract timetable ---
#   ✅ Tổng timetable rows tuyến này: 0
#
# --- Đang scrape tuyến 05: Bến xe Chợ Lớn - Biên Hòa ---
# URL: https://xebuyt.net/ben-xe-cho-lon-bien-hoa.html
# ✅ Đã parse HTML. Độ dài: 56251
#   --- Extract lộ trình ---
#     Hướng: Biên Hòa
#       A: Bến xe Chợ Lớn
#       1: Chu Văn An
#     ✅ 59 stops cho 'Biên Hòa'
#     Hướng: Bến xe Chợ Lớn
#       A: Big C
#       1: Chùa Từ Quang
#     ✅ 68 stops cho 'Bến xe Chợ Lớn'
#   ✅ Tổng stops tuyến này: 127
#   --- Extract timetable ---
#   ✅ Tổng timetable rows tuyến này: 0
#
# --- Kết thúc scrape ---
# - Tổng stops (lộ trình): 458
# - Tổng rows (timetable): 0
# ✅ Lưu lộ trình vào tuyen_xe_buyt_lotrinh.csv
# Route_Number            Route_Name                                              URL  Direction Stop_Order              Stop_Name
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          A    Công Trường Mê Linh
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          1          Bến Bạch Đằng
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          2 Cục Hải Quan Thành Phố
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          3                 Chợ Cũ
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          4       Trường Cao Thắng
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          5      Công ty Đường sắt
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          6          Bến Thành B
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          7  Trường Ernst Thalmann
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          8      KTX Trần Hưng Đạo
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html BX Chợ Lớn          9           Rạp Hưng Đạo
# ❌ Không có timetable data (có thể table giờ không match pattern).

# %%
import requests
from bs4 import BeautifulSoup
import html
import pandas as pd
import time

# Đọc file CSV đã tạo trước đó
csv_filename = 'tuyen_xe_buyt.csv'
try:
    df = pd.read_csv(csv_filename)
    print(f"Đã đọc thành công {len(df)} tuyến từ file {csv_filename}")
except FileNotFoundError:
    print(f"Không tìm thấy file {csv_filename}. Vui lòng chạy code scrape URL trước!")
    exit()

# Danh sách để lưu dữ liệu lộ trình (mỗi stop là một row)
route_stops_data = []

# Giới hạn số tuyến để test (bỏ comment nếu muốn scrape tất cả)
df = df.head(5)  # Chỉ scrape 5 tuyến đầu để test nhanh
print(f"Test với {len(df)} tuyến đầu tiên...")

print(f"Bắt đầu scrape lộ trình cho {len(df)} tuyến...")

# Duyệt qua từng hàng trong DataFrame
for index, row in df.iterrows():
    route_number = row['Route_Number']
    route_name = row['Route_Name']
    url = row['URL']

    print(f"\n--- Đang scrape lộ trình tuyến {route_number}: {route_name} ---")
    print(f"URL: {url}")

    try:
        # Gửi request với headers để giả lập browser
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        resp = requests.get(url, headers=headers)
        resp.raise_for_status()  # Kiểm tra lỗi HTTP

        # Giải mã HTML (tránh ký tự &nbsp; hoặc &amp;)
        html_content = html.unescape(resp.text)
        soup = BeautifulSoup(html_content, "html.parser")
        print(f"✅ Đã parse HTML thành công. Độ dài content: {len(resp.text)}")

        # Khởi tạo routes cho tuyến này (dynamic, không hardcoded)
        routes_this_line = {}  # {direction: [stops]}

        current_direction = None

        # Duyệt toàn bộ h3 và table theo thứ tự (như code của bạn, nhưng generalize)
        for element in soup.find_all(["h3", "table"]):
            if element.name == "h3":
                text = element.get_text(strip=True)
                # Generalize: Bất kỳ h3 nào chứa "Đi " là hướng mới
                if "Đi " in text:
                    current_direction = text.strip()  # e.g., "Đi BX Chợ Lớn"
                    routes_this_line[current_direction] = []  # Khởi tạo list stops
                    print(f"  ✅ Phát hiện hướng mới: {current_direction}")
                else:
                    current_direction = None
            elif element.name == "table" and current_direction:
                # Duyệt qua các row với class="rowStop" (như code của bạn)
                stop_count = 0
                for row in element.find_all("tr", class_="rowStop"):
                    # Lấy Stop_Order từ td đầu tiên (class="orderNo" > div)
                    order_col = row.find("td", class_="orderNo")
                    if order_col:
                        order_div = order_col.find("div")
                        stop_order = order_div.get_text(strip=True) if order_div else str(stop_count + 1)
                    else:
                        stop_order = str(stop_count + 1)

                    # Lấy tên stop từ td class="stopName" (như code của bạn)
                    stop_col = row.find("td", class_="stopName")
                    if stop_col:
                        stop_name = stop_col.get_text(strip=True)
                        if stop_name:  # Bỏ qua stop rỗng
                            routes_this_line[current_direction].append({
                                'Stop_Order': stop_order,
                                'Stop_Name': stop_name
                            })
                            stop_count += 1
                            if stop_count <= 3:  # Preview 3 stops đầu
                                print(f"    {stop_order}: {stop_name}")
                            if stop_count == 4:
                                print(f"    ... (và {len(element.find_all('tr', class_='rowStop')) - stop_count} stops khác)")

                print(f"  ✅ Thu thập {stop_count} stops cho '{current_direction}'")

        # Thêm stops của tuyến này vào danh sách tổng (flat structure cho CSV)
        total_stops_this_route = 0
        for direction, stops in routes_this_line.items():
            for stop in stops:
                route_stops_data.append({
                    'Route_Number': route_number,
                    'Route_Name': route_name,
                    'URL': url,
                    'Direction': direction,
                    'Stop_Order': stop['Stop_Order'],
                    'Stop_Name': stop['Stop_Name']
                })
                total_stops_this_route += 1

        print(f"✅ Hoàn thành tuyến {route_number}: {total_stops_this_route} stops tổng cộng (từ {len(routes_this_line)} hướng)")

    except requests.exceptions.RequestException as e:
        print(f"❌ Lỗi HTTP cho tuyến {route_number}: {e}")
    except Exception as e:
        print(f"❌ Lỗi xử lý dữ liệu tuyến {route_number}: {e}")
        import traceback
        traceback.print_exc()  # In chi tiết lỗi để debug

    # Delay để tránh overload server
    time.sleep(2)

print(f"\n--- Kết thúc scrape ---")
print(f"Tổng số stops thu thập được: {len(route_stops_data)}")

if len(route_stops_data) == 0:
    print("❌ Không có dữ liệu nào! Kiểm tra log trên để debug.")
    print("💡 Có thể một số tuyến không có h3 'Đi ', hoặc HTML thay đổi. Thử Selenium nếu cần.")

# Tạo DataFrame và lưu vào CSV mới
if len(route_stops_data) > 0:
    route_stops_df = pd.DataFrame(route_stops_data)
    output_filename = 'tuyen_xe_buyt_lotrinh.csv'
    route_stops_df.to_csv(output_filename, index=False, encoding='utf-8')

    print(f"✅ Dữ liệu lộ trình đã được lưu vào file {output_filename}")

    # Hiển thị DataFrame (top 20 rows để xem)
    print("\n--- Preview DataFrame (top 20 rows) ---")
    print(route_stops_df.head(20).to_string(index=False))

    # Thống kê nhanh
    print(f"\n--- Thống kê ---")
    print(f"- Tổng tuyến có dữ liệu: {route_stops_df['Route_Number'].nunique()}")
    print(f"- Số hướng: {route_stops_df['Direction'].nunique()}")
    print(f"- Stops trung bình/tuyến: {len(route_stops_df) / route_stops_df['Route_Number'].nunique():.1f}")
    print(f"- Hướng phổ biến nhất: {route_stops_df['Direction'].value_counts().head(1)}")
else:
    print("❌ Không lưu file vì không có dữ liệu.")
# Out:
# Đã đọc thành công 140 tuyến từ file tuyen_xe_buyt.csv
# Test với 5 tuyến đầu tiên...
# Bắt đầu scrape lộ trình cho 5 tuyến...
#
# --- Đang scrape lộ trình tuyến 01: Bến Thành- BX Chợ Lớn ---
# URL: https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html
# ✅ Đã parse HTML thành công. Độ dài content: 52658
#   ✅ Phát hiện hướng mới: Đi BX Chợ Lớn
#     A: Công Trường Mê Linh
#     1: Bến Bạch Đằng
#     2: Cục Hải Quan Thành Phố
#     ... (và 25 stops khác)
#   ✅ Thu thập 29 stops cho 'Đi BX Chợ Lớn'
#   ✅ Phát hiện hướng mới: Đi Bến Thành
#     A: Bến xe Chợ Lớn
#     1: Chu Văn An
#     2: Tháp Mười
#     ... (và 31 stops khác)
#   ✅ Thu thập 35 stops cho 'Đi Bến Thành'
#   ✅ Phát hiện hướng mới: Đi BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho 'Đi BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Thu thập 0 stops cho 'Đi BX Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Đi Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho 'Đi Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Thu thập 0 stops cho 'Đi Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 01: 64 stops tổng cộng (từ 4 hướng)
#
# --- Đang scrape lộ trình tuyến 02: Bến Thành- BX Miền Tây ---
# URL: https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html
# ✅ Đã parse HTML thành công. Độ dài content: 52394
#   ✅ Phát hiện hướng mới: Đi BX Miền Tây
#     A: Công Trường Mê Linh
#     1: Bến Bạch Đằng
#     2: Cục Hải Quan Thành Phố
#     ... (và 39 stops khác)
#   ✅ Thu thập 43 stops cho 'Đi BX Miền Tây'
#   ✅ Phát hiện hướng mới: Đi Bến Thành
#     A: Bến xe Miền Tây
#     1: 49-51 (317), Kinh Dương Vương
#     2: Dương Tự Quản
#     ... (và 33 stops khác)
#   ✅ Thu thập 37 stops cho 'Đi Bến Thành'
#   ✅ Phát hiện hướng mới: Đi BX Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho 'Đi BX Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Thu thập 0 stops cho 'Đi BX Miền Tây(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Đi Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho 'Đi Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Thu thập 0 stops cho 'Đi Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 02: 80 stops tổng cộng (từ 4 hướng)
#
# --- Đang scrape lộ trình tuyến 03: Bến Thành- Thạnh Lộc ---
# URL: https://xebuyt.net/ben-thanh-thanh-loc.html
# ✅ Đã parse HTML thành công. Độ dài content: 67605
#   ✅ Phát hiện hướng mới: Đi Thạnh Lộc
#     A: TĐH xe buýt Sài Gòn
#     1: Tôn Thất Tùng
#     2: Nguyễn Thị Nghĩa
#     ... (và 44 stops khác)
#   ✅ Thu thập 48 stops cho 'Đi Thạnh Lộc'
#   ✅ Phát hiện hướng mới: Đi Bến Thành
#     A: THẠNH LỘC
#     1: Trường Điện Lực 2
#     2: Chợ Thạnh Xuân
#     ... (và 44 stops khác)
#   ✅ Thu thập 48 stops cho 'Đi Bến Thành'
#   ✅ Phát hiện hướng mới: Đi Thạnh Lộc(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho 'Đi Thạnh Lộc(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Thu thập 0 stops cho 'Đi Thạnh Lộc(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Đi Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho 'Đi Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Thu thập 0 stops cho 'Đi Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 03: 96 stops tổng cộng (từ 4 hướng)
#
# --- Đang scrape lộ trình tuyến 04: Bến Thành- Cộng Hòa- An Sương ---
# URL: https://xebuyt.net/ben-thanh-cong-hoa-an-suong.html
# ✅ Đã parse HTML thành công. Độ dài content: 65800
#   ✅ Phát hiện hướng mới: Đi An Sương
#     A: TĐH xe buýt Sài Gòn
#     1: Tôn Thất Tùng
#     2: Nguyễn Thị Nghĩa
#     ... (và 46 stops khác)
#   ✅ Thu thập 50 stops cho 'Đi An Sương'
#   ✅ Phát hiện hướng mới: Đi Bến Thành
#     A: Bến xe An Sương
#     1: Chợ Chiều
#     2: Bitis
#     ... (và 37 stops khác)
#   ✅ Thu thập 41 stops cho 'Đi Bến Thành'
#   ✅ Phát hiện hướng mới: Đi An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho 'Đi An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Thu thập 0 stops cho 'Đi An Sương(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Đi Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho 'Đi Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Thu thập 0 stops cho 'Đi Bến Thành(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 04: 91 stops tổng cộng (từ 4 hướng)
#
# --- Đang scrape lộ trình tuyến 05: Bến xe Chợ Lớn - Biên Hòa ---
# URL: https://xebuyt.net/ben-xe-cho-lon-bien-hoa.html
# ✅ Đã parse HTML thành công. Độ dài content: 56251
#   ✅ Phát hiện hướng mới: Đi Biên Hòa
#     A: Bến xe Chợ Lớn
#     1: Chu Văn An
#     2: Chợ Kim Biên
#     ... (và 55 stops khác)
#   ✅ Thu thập 59 stops cho 'Đi Biên Hòa'
#   ✅ Phát hiện hướng mới: Đi Bến xe Chợ Lớn
#     A: Big C
#     1: Chùa Từ Quang
#     2: Đường số 8
#     ... (và 64 stops khác)
#   ✅ Thu thập 68 stops cho 'Đi Bến xe Chợ Lớn'
#   ✅ Phát hiện hướng mới: Đi Biên Hòa(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho 'Đi Biên Hòa(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Thu thập 0 stops cho 'Đi Biên Hòa(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Phát hiện hướng mới: Đi Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)
#   ✅ Thu thập 0 stops cho 'Đi Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
#   ✅ Thu thập 0 stops cho 'Đi Bến xe Chợ Lớn(Thứ 2, Thứ 3, Thứ 4, Thứ 5, Thứ 6, Thứ 7, Chủ Nhật)'
# ✅ Hoàn thành tuyến 05: 127 stops tổng cộng (từ 4 hướng)
#
# --- Kết thúc scrape ---
# Tổng số stops thu thập được: 458
# ✅ Dữ liệu lộ trình đã được lưu vào file tuyen_xe_buyt_lotrinh.csv
#
# --- Preview DataFrame (top 20 rows) ---
# Route_Number            Route_Name                                              URL     Direction Stop_Order                         Stop_Name
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn          A               Công Trường Mê Linh
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn          1                     Bến Bạch Đằng
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn          2            Cục Hải Quan Thành Phố
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn          3                            Chợ Cũ
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn          4                  Trường Cao Thắng
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn          5                 Công ty Đường sắt
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn          6                     Bến Thành B
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn          7             Trường Ernst Thalmann
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn          8                 KTX Trần Hưng Đạo
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn          9                      Rạp Hưng Đạo
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn         10            Bệnh viện Răng Hàm Mặt
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn         11                      Trần Đình Xu
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn         12                    Tổng Cty Samco
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn         13                         Chợ Nanci
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn         14                       Nguyễn Biểu
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn         15 Trường Cao đẳng Kinh tế Đối ngoại
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn         16                   Trần Bình Trọng
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn         17  Bệnh viện Chấn thương Chỉnh hình
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn         18                     Rạp Đồng Tháp
#           01 Bến Thành- BX Chợ Lớn https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html Đi BX Chợ Lớn         19                       Rạp Đống Đa
#
# --- Thống kê ---
# - Tổng tuyến có dữ liệu: 5
# - Số hướng: 7
# - Stops trung bình/tuyến: 91.6
# - Hướng phổ biến nhất: Direction
# Đi Bến Thành    161
# Name: count, dtype: int64

# %%
route_stops_df.head(100)
# Out:
#    Route_Number              Route_Name  \
# 0            01   Bến Thành- BX Chợ Lớn
# 1            01   Bến Thành- BX Chợ Lớn
# 2            01   Bến Thành- BX Chợ Lớn
# 3            01   Bến Thành- BX Chợ Lớn
# 4            01   Bến Thành- BX Chợ Lớn
# 5            01   Bến Thành- BX Chợ Lớn
# 6            01   Bến Thành- BX Chợ Lớn
# 7            01   Bến Thành- BX Chợ Lớn
# 8            01   Bến Thành- BX Chợ Lớn
# 9            01   Bến Thành- BX Chợ Lớn
# 10           01   Bến Thành- BX Chợ Lớn
# 11           01   Bến Thành- BX Chợ Lớn
# 12           01   Bến Thành- BX Chợ Lớn
# 13           01   Bến Thành- BX Chợ Lớn
# 14           01   Bến Thành- BX Chợ Lớn
# 15           01   Bến Thành- BX Chợ Lớn
# 16           01   Bến Thành- BX Chợ Lớn
# 17           01   Bến Thành- BX Chợ Lớn
# 18           01   Bến Thành- BX Chợ Lớn
# 19           01   Bến Thành- BX Chợ Lớn
# 20           01   Bến Thành- BX Chợ Lớn
# 21           01   Bến Thành- BX Chợ Lớn
# 22           01   Bến Thành- BX Chợ Lớn
# 23           01   Bến Thành- BX Chợ Lớn
# 24           01   Bến Thành- BX Chợ Lớn
# 25           01   Bến Thành- BX Chợ Lớn
# 26           01   Bến Thành- BX Chợ Lớn
# 27           01   Bến Thành- BX Chợ Lớn
# 28           01   Bến Thành- BX Chợ Lớn
# 29           01   Bến Thành- BX Chợ Lớn
# 30           01   Bến Thành- BX Chợ Lớn
# 31           01   Bến Thành- BX Chợ Lớn
# 32           01   Bến Thành- BX Chợ Lớn
# 33           01   Bến Thành- BX Chợ Lớn
# 34           01   Bến Thành- BX Chợ Lớn
# 35           01   Bến Thành- BX Chợ Lớn
# 36           01   Bến Thành- BX Chợ Lớn
# 37           01   Bến Thành- BX Chợ Lớn
# 38           01   Bến Thành- BX Chợ Lớn
# 39           01   Bến Thành- BX Chợ Lớn
# 40           01   Bến Thành- BX Chợ Lớn
# 41           01   Bến Thành- BX Chợ Lớn
# 42           01   Bến Thành- BX Chợ Lớn
# 43           01   Bến Thành- BX Chợ Lớn
# 44           01   Bến Thành- BX Chợ Lớn
# 45           01   Bến Thành- BX Chợ Lớn
# 46           01   Bến Thành- BX Chợ Lớn
# 47           01   Bến Thành- BX Chợ Lớn
# 48           01   Bến Thành- BX Chợ Lớn
# 49           01   Bến Thành- BX Chợ Lớn
# 50           01   Bến Thành- BX Chợ Lớn
# 51           01   Bến Thành- BX Chợ Lớn
# 52           01   Bến Thành- BX Chợ Lớn
# 53           01   Bến Thành- BX Chợ Lớn
# 54           01   Bến Thành- BX Chợ Lớn
# 55           01   Bến Thành- BX Chợ Lớn
# 56           01   Bến Thành- BX Chợ Lớn
# 57           01   Bến Thành- BX Chợ Lớn
# 58           01   Bến Thành- BX Chợ Lớn
# 59           01   Bến Thành- BX Chợ Lớn
# 60           01   Bến Thành- BX Chợ Lớn
# 61           01   Bến Thành- BX Chợ Lớn
# 62           01   Bến Thành- BX Chợ Lớn
# 63           01   Bến Thành- BX Chợ Lớn
# 64           02  Bến Thành- BX Miền Tây
# 65           02  Bến Thành- BX Miền Tây
# 66           02  Bến Thành- BX Miền Tây
# 67           02  Bến Thành- BX Miền Tây
# 68           02  Bến Thành- BX Miền Tây
# 69           02  Bến Thành- BX Miền Tây
# 70           02  Bến Thành- BX Miền Tây
# 71           02  Bến Thành- BX Miền Tây
# 72           02  Bến Thành- BX Miền Tây
# 73           02  Bến Thành- BX Miền Tây
# 74           02  Bến Thành- BX Miền Tây
# 75           02  Bến Thành- BX Miền Tây
# 76           02  Bến Thành- BX Miền Tây
# 77           02  Bến Thành- BX Miền Tây
# 78           02  Bến Thành- BX Miền Tây
# 79           02  Bến Thành- BX Miền Tây
# 80           02  Bến Thành- BX Miền Tây
# 81           02  Bến Thành- BX Miền Tây
# 82           02  Bến Thành- BX Miền Tây
# 83           02  Bến Thành- BX Miền Tây
# 84           02  Bến Thành- BX Miền Tây
# 85           02  Bến Thành- BX Miền Tây
# 86           02  Bến Thành- BX Miền Tây
# 87           02  Bến Thành- BX Miền Tây
# 88           02  Bến Thành- BX Miền Tây
# 89           02  Bến Thành- BX Miền Tây
# 90           02  Bến Thành- BX Miền Tây
# 91           02  Bến Thành- BX Miền Tây
# 92           02  Bến Thành- BX Miền Tây
# 93           02  Bến Thành- BX Miền Tây
# 94           02  Bến Thành- BX Miền Tây
# 95           02  Bến Thành- BX Miền Tây
# 96           02  Bến Thành- BX Miền Tây
# 97           02  Bến Thành- BX Miền Tây
# 98           02  Bến Thành- BX Miền Tây
# 99           02  Bến Thành- BX Miền Tây
#
#                                                   URL       Direction  \
# 0    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 1    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 2    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 3    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 4    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 5    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 6    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 7    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 8    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 9    https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 10   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 11   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 12   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 13   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 14   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 15   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 16   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 17   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 18   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 19   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 20   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 21   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 22   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 23   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 24   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 25   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 26   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 27   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 28   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html   Đi BX Chợ Lớn
# 29   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 30   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 31   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 32   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 33   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 34   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 35   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 36   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 37   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 38   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 39   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 40   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 41   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 42   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 43   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 44   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 45   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 46   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 47   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 48   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 49   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 50   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 51   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 52   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 53   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 54   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 55   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 56   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 57   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 58   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 59   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 60   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 61   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 62   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 63   https://xebuyt.net/ben-thanh-ben-xe-cho-lon.html    Đi Bến Thành
# 64  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 65  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 66  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 67  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 68  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 69  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 70  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 71  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 72  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 73  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 74  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 75  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 76  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 77  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 78  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 79  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 80  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 81  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 82  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 83  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 84  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 85  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 86  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 87  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 88  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 89  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 90  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 91  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 92  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 93  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 94  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 95  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 96  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 97  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 98  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
# 99  https://xebuyt.net/ben-thanh-ben-xe-mien-tay.html  Đi BX Miền Tây
#
#    Stop_Order                          Stop_Name
# 0           A                Công Trường Mê Linh
# 1           1                      Bến Bạch Đằng
# 2           2             Cục Hải Quan Thành Phố
# 3           3                             Chợ Cũ
# 4           4                   Trường Cao Thắng
# 5           5                  Công ty Đường sắt
# 6           6                      Bến Thành B
# 7           7              Trường Ernst Thalmann
# 8           8                  KTX Trần Hưng Đạo
# 9           9                       Rạp Hưng Đạo
# 10         10             Bệnh viện Răng Hàm Mặt
# 11         11                       Trần Đình Xu
# 12         12                     Tổng Cty Samco
# 13         13                          Chợ Nanci
# 14         14                        Nguyễn Biểu
# 15         15  Trường Cao đẳng Kinh tế Đối ngoại
# 16         16                    Trần Bình Trọng
# 17         17   Bệnh viện Chấn thương Chỉnh hình
# 18         18                      Rạp Đồng Tháp
# 19         19                        Rạp Đống Đa
# 20         20                         Đồng Khánh
# 21         21                 Nhà Văn hóa Quận 5
# 22         22                          Ngô Quyền
# 23         23                             Tản Đà
# 24         24                   Triệu Quang Phục
# 25         25                    Bưu điện Quận 5
# 26         26                 Hải Thượng Lãn Ông
# 27         27                       Chợ Kim Biên
# 28          B                     Bến xe Chợ Lớn
# 29          A                     Bến xe Chợ Lớn
# 30          1                         Chu Văn An
# 31          2                          Tháp Mười
# 32          3                       Chợ Kim Biên
# 33          4                    Bưu điện Quận 5
# 34          5                      Rạp Đại Quang
# 35          6                      Lương Nhữ Học
# 36          7                   Triệu Quang Phục
# 37          8   Đại học Sư phạm Thể dục thể thao
# 38          9          Siêu thị Điện máy Chợ Lớn
# 39         10                          Ngô Quyền
# 40         11               Chung cư Nguyễn Trãi
# 41         12                  Siêu thị Điện máy
# 42         13                 Nhà Văn hóa Quận 5
# 43         14                         Đồng Khánh
# 44         15                            An Bình
# 45         16                      Rạp Đồng Tháp
# 46         17   Bệnh viện Chấn Thương Chỉnh hình
# 47         18                    Trần Bình Trọng
# 48         19                        Nguyễn Biểu
# 49         20                          Chợ Nanci
# 50         21                     Tổng Cty Samco
# 51         22                            Sở PCCC
# 52         23                         Hồ Hảo Hớn
# 53         24             Bệnh Viện Răng Hàm Mặt
# 54         25                  Rạp Trần Hưng Đạo
# 55         26                  KTX Trần Hưng Đạo
# 56         27                         Nguyễn Kim
# 57         28                      Bến Thành E
# 58         29                           Hàm Nghi
# 59         30                             Chợ Củ
# 60         31                        Hồ Tùng Mậu
# 61         32                      Bến Bạch Đằng
# 62         33                Công Trường Mê Linh
# 63          B                Công Trường Mê Linh
# 64          A                Công Trường Mê Linh
# 65          1                      Bến Bạch Đằng
# 66          2             Cục Hải Quan Thành Phố
# 67          3                             Chợ Cũ
# 68          4                   Trường Cao Thắng
# 69          5                  Công ty Đường sắt
# 70          6                      Bến Thành A
# 71          7              Trường Ernst Thalmann
# 72          8                Nguyễn Thị Nghĩa
# 73          9                     Ngã 6 Phù Đổng
# 74         10                      Tôn Thất Tùng
# 75         11                   Nhà thờ Huyện Sỹ
# 76         12                      Chợ Thái Bình
# 77         13        Hội Chữ thập đỏ thành phố
# 78         14               Nhà sách Minh Khai
# 79         15                         Chợ Bàn Cờ
# 80         16                          Cao Thắng
# 81         17                          Cao Thắng
# 82         18       Học viện hành chính quốc gia
# 83         19       Học viện hành chính quốc gia
# 84         20                   Nhà hát Hòa Bình
# 85         21                   Nhà thờ Vinh Sơn
# 86         22                 Bệnh viện nhi đồng
# 87         23                         Nguyễn Kim
# 88         24                   Nhà sách Phú Thọ
# 89         25                   Lãnh Binh Thăng
# 90         26                          Chợ Thiết
# 91         27                            Xóm Đất
# 92         28             Đội Giao Thông Phú Lâm
# 93         29                     Chùa Phụng Sơn
# 94         30                  Trường Nguyễn Thi
# 95         31                             Cây Gõ
# 96         32                     Chợ Minh Phụng
# 97         33                      Cầu Hậu Giang
# 98         34                            Chợ Hoa
# 99         35                   Nguyễn Văn Luông

# %% [markdown]
# # Lấy lộ trình - fixed

# %% [markdown]
# # Lấy biểu đồ giờ
